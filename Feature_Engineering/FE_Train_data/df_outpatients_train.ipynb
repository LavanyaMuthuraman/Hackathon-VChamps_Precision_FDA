# %%
#A class attribute that provides access to the TabularDatasetFactory methods for creating new TabularDataset objects. 
#Usage: Dataset.Tabular.from_delimited_files().
from azureml.core import Workspace, Dataset

subscription_id = 'bcfe0c62-8ebe-4df0-a46d-1efcf8739a5b' #check the launch studio there will get this id
resource_group = 'VChamp-Team3' # resource group name
workspace_name = 'vchamp-team3' # worksapce name


# storage account : Algorithmia, Resource group: VChamp-Team3 and workspace: vchamp-team3.
#Constructor
workspace = Workspace(subscription_id, resource_group, workspace_name)

# %%
import numpy as np                # Multi-Dimensional array object
import pandas as pd               # Data Manipulation
import matplotlib.pyplot as plt   # Data Visualization
import seaborn as sns             # Data Visualization 

# Allows the use of display() for DataFrames
from IPython.display import display 

# Handle warning messages that may occur during code execution
import warnings
warnings.filterwarnings('ignore')

# To increase memory allocation
from notebook.services.config import ConfigManager
cm = ConfigManager().update('notebook', {'max_buffer_size': 7294967296})

# %%
#['data_team3_synthetic_train']
datastore = workspace.datastores['data_team3_synthetic_train']

# %%
#from_delimited_files (Create a TabularDataset to represent tabular data in delimited files (e.g. CSV and TSV).

dataset = Dataset.Tabular.from_delimited_files(path = [(datastore, 'outpatient_visits_train.csv')])

# preview the first 3 rows of the dataset
# dataset.to_pandas_dataframe()

# %%
#Converting the dataset into data frame(default as dataset in Azure, thus we must convert the needed formate)
outpatient_train_data = dataset.to_pandas_dataframe()

# %%
outpatient_train_data.Internalpatientid.nunique()
# Out:
# 133252

# %% [markdown]
# # Elimination of the unnamed columns

# %%
# Remove unwanted columns 
outpatient_train_data.drop('Column1',axis=1,inplace=True)

# %%
outpatient_train_data
# Out:
#           Internalpatientid  Age at visit    Visit start date  \
# 0                         1     60.619995 2004-11-17 14:35:36
# 1                         1     61.032110 2005-04-17 05:40:07
# 2                         1     61.907075 2006-03-03 00:51:52
# 3                         1     62.296573 2006-07-23 09:32:16
# 4                         1     63.632066 2007-11-23 12:28:48
# ...                     ...           ...                 ...
# 82692715              99999     96.300251 2013-03-19 17:47:55
# 82692716              99999     96.322523 2013-03-27 21:10:33
# 82692717              99999     96.327503 2013-03-29 16:51:35
# 82692718              99999     96.360092 2013-04-10 14:43:53
# 82692719              99999     96.626156 2013-07-16 20:38:29
#
#          First listed diagnosis icd10 subcategory  \
# 0                                   Not specified
# 1                                   Not specified
# 2                                   Not specified
# 3                                   Not specified
# 4                                   Not specified
# ...                                           ...
# 82692715                            Not specified
# 82692716                            Not specified
# 82692717                            Not specified
# 82692718                            Not specified
# 82692719                            Not specified
#
#          Second listed diagnosis icd10 subcategory  \
# 0                                    Not specified
# 1                                    Not specified
# 2                                    Not specified
# 3                                    Not specified
# 4                                    Not specified
# ...                                            ...
# 82692715                             Not specified
# 82692716                             Not specified
# 82692717                             Not specified
# 82692718                             Not specified
# 82692719                             Not specified
#
#                                Stop code Agentorangeflag Combatflag  \
# 0                     TELEPHONE/MEDICINE            None       None
# 1                       TELEPHONE TRIAGE            None       None
# 2                             LABORATORY            None       None
# 3                               NO-COUNT            None       None
# 4              GENERAL INTERNAL MEDICINE            None       None
# ...                                  ...             ...        ...
# 82692715             TELEPHONE/ANCILLARY            None       None
# 82692716                       NEUROLOGY            None       None
# 82692717  RENAL/NEPHROL(EXCEPT DIALYSIS)            None       None
# 82692718       SPEECH-LANGUAGE PATHOLOGY            None       None
# 82692719        Not specified (no value)            None       None
#
#          Ionizingradiationflag Serviceconnectedflag Swasiaconditionsflag  \
# 0                         None                False                 None
# 1                         None                 True                 None
# 2                         None                 None                 None
# 3                         None                 None                 None
# 4                         None                False                 None
# ...                        ...                  ...                  ...
# 82692715                  None                False                 None
# 82692716                  None                False                 None
# 82692717                  None                 True                 None
# 82692718                  None                 None                 None
# 82692719                  None                 None                 None
#
#             State
# 0         Indiana
# 1         Indiana
# 2         Indiana
# 3         Indiana
# 4         Indiana
# ...           ...
# 82692715  Arizona
# 82692716  Arizona
# 82692717  Arizona
# 82692718  Arizona
# 82692719  Arizona
#
# [82692720 rows x 12 columns]

# %% [markdown]
# # sorting out patients id and age column

# %%
# Sort the dataset based on the patientsid and 'age' column in ascending order
outpatient_train_data.sort_values(["Internalpatientid","Age at visit"],inplace=True)

# %%
outpatient_train_data
# Out:
#           Internalpatientid  Age at visit    Visit start date  \
# 278047                    1     57.573116 2001-10-30 23:22:22
# 791                       1     57.840497 2002-02-05 16:50:30
# 39923                     1     57.912086 2002-03-03 20:49:01
# 22545                     1     57.912177 2002-03-03 21:37:12
# 792                       1     57.975498 2002-03-27 01:04:21
# ...                     ...           ...                 ...
# 29931363             169064     87.927745 2014-11-22 14:10:56
# 29876085             169064     87.927991 2014-11-22 16:20:05
# 59674056             169064     87.928316 2014-11-22 19:11:13
# 59427681             169064     87.933827 2014-11-24 19:31:49
# 29890345             169064     87.936775 2014-11-25 21:23:12
#
#          First listed diagnosis icd10 subcategory  \
# 278047                              Not specified
# 791                                 Not specified
# 39923                               Not specified
# 22545                               Not specified
# 792                                 Not specified
# ...                                           ...
# 29931363                            Not specified
# 29876085                            Not specified
# 59674056                            Not specified
# 59427681                            Not specified
# 29890345                            Not specified
#
#          Second listed diagnosis icd10 subcategory  \
# 278047                               Not specified
# 791                                  Not specified
# 39923                                Not specified
# 22545                                Not specified
# 792                                  Not specified
# ...                                            ...
# 29931363                             Not specified
# 29876085                             Not specified
# 59674056                             Not specified
# 59427681                             Not specified
# 29890345                             Not specified
#
#                                Stop code Agentorangeflag Combatflag  \
# 278047             PRIMARY CARE/MEDICINE            None       None
# 791                           LABORATORY            None       None
# 39923                         LABORATORY            None       None
# 22545              PRIMARY CARE/MEDICINE            None       None
# 792                          DERMATOLOGY            None       None
# ...                                  ...             ...        ...
# 29931363  ADMIN PAT ACTIVTIES (MASNONCT)            None       None
# 29876085  ADMIN PAT ACTIVTIES (MASNONCT)            None       None
# 59674056  ADMIN PAT ACTIVTIES (MASNONCT)            None       None
# 59427681  ADMIN PAT ACTIVTIES (MASNONCT)            None       None
# 29890345  ADMIN PAT ACTIVTIES (MASNONCT)            None       None
#
#          Ionizingradiationflag Serviceconnectedflag Swasiaconditionsflag  \
# 278047                    None                 True                 None
# 791                       None                 None                 None
# 39923                     None                 None                 None
# 22545                     None                 True                 None
# 792                       None                False                 None
# ...                        ...                  ...                  ...
# 29931363                  None                 None                 None
# 29876085                  None                 None                 None
# 59674056                  None                 None                 None
# 59427681                  None                 None                 None
# 29890345                  None                 None                 None
#
#             State
# 278047    Indiana
# 791       Indiana
# 39923     Indiana
# 22545     Indiana
# 792       Indiana
# ...           ...
# 29931363  Wyoming
# 29876085  Wyoming
# 59674056  Wyoming
# 59427681  Wyoming
# 29890345  Wyoming
#
# [82692720 rows x 12 columns]

# %% [markdown]
# # checking the missing valuses

# %%
print("set missing values:\n", outpatient_train_data.isna().sum())
# Out:
# set missing values:
#  Internalpatientid                                   0
# Age at visit                                        0
# Visit start date                                    0
# First listed diagnosis icd10 subcategory            0
# Second listed diagnosis icd10 subcategory           0
# Stop code                                           0
# Agentorangeflag                              79641724
# Combatflag                                   82560329
# Ionizingradiationflag                        82593660
# Serviceconnectedflag                         63719525
# Swasiaconditionsflag                         82416510
# State                                               0
# dtype: int64

# %% [markdown]
# * There is no missing value in the potential attributes,but lot of "Not specified" values in PA

# %%
#Checking the values each category in condition type

# Count the occurrences of each label
first_list = outpatient_train_data["First listed diagnosis icd10 subcategory"].value_counts().loc[lambda x: x>200]
first_list
# Out:
# Not specified                                                                  70603206
# Other specified counseling                                                       720331
# Encounter for other specified aftercare                                          539853
# Counseling, unspecified                                                          345595
# Essential (primary) hypertension                                                 313963
#                                                                                  ...
# Pemphigus, unspecified                                                              201
# Diverticulitis of intestine, part unspecified, with perforation and abscess         201
# Mechanical complication of urinary catheter                                         201
# Diverticular disease of small intestine without perforation or abscess              201
# Non-follicular (diffuse) lymphoma, unspecified                                      201
# Name: First listed diagnosis icd10 subcategory, Length: 1904, dtype: int64

# %%
#Checking the values each category in condition type

# Count the occurrences of each label
sec_list = outpatient_train_data["Second listed diagnosis icd10 subcategory"].value_counts().loc[lambda x: x>200]
sec_list
# Out:
# Not specified                                                                          78185197
# Essential (primary) hypertension                                                         207434
# Unspecified atrial fibrillation and atrial flutter                                       192069
# Long term (current) use of anticoagulants and antithrombotics/antiplatelets              142482
# Type 2 diabetes mellitus without complications                                           105136
#                                                                                          ...
# Pressure ulcer of contiguous site of back, buttock and hip                                  201
# Other and unspecified adhesions and disruptions of iris and ciliary body                    201
# Abnormal findings on diagnostic imaging of skull and head, not elsewhere classified         201
# Military activity                                                                           201
# Other symptoms and signs concerning food and fluid intake                                   201
# Name: Second listed diagnosis icd10 subcategory, Length: 1330, dtype: int64

# %%
# Remove the rows where both columns contain "Not Specified"

outpatient_train_data = outpatient_train_data.drop(outpatient_train_data[(outpatient_train_data['First listed diagnosis icd10 subcategory'] == 'Not specified') & (outpatient_train_data['Second listed diagnosis icd10 subcategory'] == 'Not specified')].index)

# %%
outpatient_train_data.Internalpatientid.nunique()
# Out:
# 68716

# %% [markdown]
# * **after removing "Not specified" will get the 12120949**

# %% [markdown]
# # Taking the digit in age coulmn

# %%
# Format 'Age at measurement' values in the format 00.00
outpatient_train_data["Age at visit"] = outpatient_train_data["Age at visit"].map("{:.2f}".format)

# %%
outpatient_train_data
# Out:
#           Internalpatientid Age at visit    Visit start date  \
# 37443                     1        73.51 2017-10-11 06:59:59
# 11723                     1        73.52 2017-10-16 07:57:07
# 49                        1        73.54 2017-10-22 09:33:20
# 37444                     1        73.56 2017-10-30 01:40:07
# 1672                      1        73.56 2017-10-30 02:00:25
# ...                     ...          ...                 ...
# 29876028             169061        79.98 2022-02-16 08:54:51
# 59256791             169061        80.03 2022-03-06 16:44:20
# 29956397             169061        80.59 2022-09-28 02:18:06
# 59087808             169061        81.14 2023-04-15 23:35:37
# 60569737             169061        81.38 2023-07-14 17:43:43
#
#                    First listed diagnosis icd10 subcategory  \
# 37443       Encounter for general adult medical examination
# 11723     Personal history of malignant neoplasm of urin...
# 49        Long term (current) use of anticoagulants and ...
# 37444                                           Sleep apnea
# 1672                             Encounter for immunization
# ...                                                     ...
# 29876028  Type 2 diabetes mellitus with other specified ...
# 59256791  Other specified diabetes mellitus without comp...
# 29956397                         Other specified counseling
# 59087808                Systolic (congestive) heart failure
# 60569737                         Other specified counseling
#
#                   Second listed diagnosis icd10 subcategory  \
# 37443                                         Not specified
# 11723                                         Not specified
# 49        Unspecified atrial fibrillation and atrial flu...
# 37444                                         Not specified
# 1672                                          Not specified
# ...                                                     ...
# 29876028                                      Not specified
# 59256791                                      Not specified
# 29956397                                      Not specified
# 59087808         Encounter for issue of repeat prescription
# 60569737                                      Not specified
#
#                           Stop code Agentorangeflag Combatflag  \
# 37443                    LABORATORY            None       None
# 11723      CYSTO ROOM IN UROLOGY CL            None       None
# 49                CLINICAL PHARMACY            None       None
# 37444                SLEEP MEDICINE            None       None
# 1672      GENERAL INTERNAL MEDICINE            None       None
# ...                             ...             ...        ...
# 29876028     TELEPHONE PRIMARY CARE           False       None
# 59256791     TELEPHONE PRIMARY CARE           False       None
# 29956397     TELEPHONE PRIMARY CARE           False       None
# 59087808     TELEPHONE PRIMARY CARE           False       None
# 60569737     TELEPHONE PRIMARY CARE           False       None
#
#          Ionizingradiationflag Serviceconnectedflag Swasiaconditionsflag  \
# 37443                     None                 True                 None
# 11723                     None                False                 None
# 49                        None                False                 None
# 37444                     None                False                 None
# 1672                      None                False                 None
# ...                        ...                  ...                  ...
# 29876028                  None                False                 None
# 59256791                  None                False                 None
# 29956397                  None                False                 None
# 59087808                  None                False                 None
# 60569737                  None                False                 None
#
#             State
# 37443     Indiana
# 11723     Indiana
# 49        Indiana
# 37444     Indiana
# 1672      Indiana
# ...           ...
# 29876028  Georgia
# 59256791  Georgia
# 29956397  Georgia
# 59087808  Georgia
# 60569737  Georgia
#
# [12120949 rows x 12 columns]

# %%
# Convert 'Age' column from object to float
outpatient_train_data["Age at visit"] = outpatient_train_data["Age at visit"].astype(float)

# %% [markdown]
# # Max age

# %%
# Find the maximum age for each internal patient id
max_ages = outpatient_train_data.groupby('Internalpatientid')['Age at visit'].max().reset_index()

# Merge with the original dataframe to get the rows with the highest age
outpatient_train_data = pd.merge(outpatient_train_data, max_ages, on =['Internalpatientid','Age at visit'], how = 'inner')

outpatient_train_data
# Out:
#         Internalpatientid  Age at visit    Visit start date  \
# 0                       1         80.21 2024-06-25 02:44:48
# 1                       1         80.21 2024-06-26 03:20:15
# 2                       2         69.48 2024-03-17 12:47:16
# 3                       2         69.48 2024-03-18 07:01:21
# 4                       4         84.19 2015-02-22 21:34:14
# ...                   ...           ...                 ...
# 112849             169057         86.14 2025-06-17 22:36:34
# 112850             169057         86.14 2025-06-18 23:18:37
# 112851             169057         86.14 2025-06-19 22:02:08
# 112852             169060         71.78 2017-09-25 05:57:56
# 112853             169061         81.38 2023-07-14 17:43:43
#
#                  First listed diagnosis icd10 subcategory  \
# 0             Other specified inflammatory liver diseases
# 1       Unspecified atrial fibrillation and atrial flu...
# 2       Encounter for screening for other specified di...
# 3       Encounter for screening for other specified di...
# 4                              Unspecified abdominal pain
# ...                                                   ...
# 112849                            Ischemic cardiomyopathy
# 112850  Type 2 diabetes mellitus with unspecified comp...
# 112851                      Presence of cardiac pacemaker
# 112852            Encounter for other specified aftercare
# 112853                         Other specified counseling
#
#              Second listed diagnosis icd10 subcategory  \
# 0       Type 2 diabetes mellitus without complications
# 1                                        Not specified
# 2                                        Not specified
# 3                                        Not specified
# 4                                        Not specified
# ...                                                ...
# 112849     Venous insufficiency (chronic) (peripheral)
# 112850     Venous insufficiency (chronic) (peripheral)
# 112851                                   Not specified
# 112852                                   Not specified
# 112853                                   Not specified
#
#                          Stop code Agentorangeflag Combatflag  \
# 0                HEPATOLOGY CLINIC            None       None
# 1              TELEPHONE/ANCILLARY            None       None
# 2                     TELEPHONE MH            None       None
# 3       MENTAL HEALTH CLINIC - IND            None       None
# 4              SOCIAL WORK SERVICE            None       None
# ...                            ...             ...        ...
# 112849                  CARDIOLOGY            None       None
# 112850                    PODIATRY            None       None
# 112851              KINESIOTHERAPY            None       None
# 112852      TELEPHONE PRIMARY CARE            None       None
# 112853      TELEPHONE PRIMARY CARE           False       None
#
#        Ionizingradiationflag Serviceconnectedflag Swasiaconditionsflag  \
# 0                       None                False                 None
# 1                       None                False                 None
# 2                       None                False                 None
# 3                       None                False                 None
# 4                       None                 None                 None
# ...                      ...                  ...                  ...
# 112849                  None                 True                 None
# 112850                  None                 True                 None
# 112851                  None                False                 None
# 112852                  None                 None                 None
# 112853                  None                False                 None
#
#               State
# 0           Indiana
# 1           Indiana
# 2             Texas
# 3             Texas
# 4       Puerto Rico
# ...             ...
# 112849   California
# 112850   California
# 112851   California
# 112852   California
# 112853      Georgia
#
# [112854 rows x 12 columns]

# %% [markdown]
# # Rounding off the Age

# %%
outpatient_train_data['Age at visit'] = outpatient_train_data['Age at visit'].apply(lambda x: round(x,))

# %%
outpatient_train_data.Internalpatientid.nunique()
# Out:
# 68716

# %%
df = outpatient_train_data["Internalpatientid"].value_counts().loc[lambda x: x>25].to_frame()

# %%
df = df.reset_index()

# %%
df.columns = ["Internalpatientid","count_outpatients"]

# %%
len(df)
# Out:
# 33

# %%
df.drop(["count_outpatients"],axis=1,inplace =True)

# %%
df
# Out:
#     Internalpatientid
# 0               75325
# 1              163132
# 2               59499
# 3              123727
# 4              151859
# 5               46626
# 6              161451
# 7              135209
# 8               93348
# 9               14924
# 10             143173
# 11             157368
# 12              16903
# 13             136585
# 14               3217
# 15             106288
# 16                481
# 17             163387
# 18              96256
# 19             100189
# 20              61384
# 21             130997
# 22              51207
# 23              46582
# 24             112220
# 25              90654
# 26              64250
# 27             116324
# 28             164637
# 29              95228
# 30             158619
# 31             164403
# 32              55145

# %%
# Merge the two dataframes based on 'Internalpatientid'
merged_df = outpatient_train_data.merge(df, on='Internalpatientid', how='left')

# Filter rows from DataFrame 1 that have matching values in DataFrame 2
filtered_df = merged_df[~merged_df['Internalpatientid'].isin(df['Internalpatientid'])]

# Print only the columns of DataFrame 1
filtered_df
# Out:
#         Internalpatientid  Age at visit    Visit start date  \
# 0                       1            80 2024-06-25 02:44:48
# 1                       1            80 2024-06-26 03:20:15
# 2                       2            69 2024-03-17 12:47:16
# 3                       2            69 2024-03-18 07:01:21
# 4                       4            84 2015-02-22 21:34:14
# ...                   ...           ...                 ...
# 112849             169057            86 2025-06-17 22:36:34
# 112850             169057            86 2025-06-18 23:18:37
# 112851             169057            86 2025-06-19 22:02:08
# 112852             169060            72 2017-09-25 05:57:56
# 112853             169061            81 2023-07-14 17:43:43
#
#                  First listed diagnosis icd10 subcategory  \
# 0             Other specified inflammatory liver diseases
# 1       Unspecified atrial fibrillation and atrial flu...
# 2       Encounter for screening for other specified di...
# 3       Encounter for screening for other specified di...
# 4                              Unspecified abdominal pain
# ...                                                   ...
# 112849                            Ischemic cardiomyopathy
# 112850  Type 2 diabetes mellitus with unspecified comp...
# 112851                      Presence of cardiac pacemaker
# 112852            Encounter for other specified aftercare
# 112853                         Other specified counseling
#
#              Second listed diagnosis icd10 subcategory  \
# 0       Type 2 diabetes mellitus without complications
# 1                                        Not specified
# 2                                        Not specified
# 3                                        Not specified
# 4                                        Not specified
# ...                                                ...
# 112849     Venous insufficiency (chronic) (peripheral)
# 112850     Venous insufficiency (chronic) (peripheral)
# 112851                                   Not specified
# 112852                                   Not specified
# 112853                                   Not specified
#
#                          Stop code Agentorangeflag Combatflag  \
# 0                HEPATOLOGY CLINIC            None       None
# 1              TELEPHONE/ANCILLARY            None       None
# 2                     TELEPHONE MH            None       None
# 3       MENTAL HEALTH CLINIC - IND            None       None
# 4              SOCIAL WORK SERVICE            None       None
# ...                            ...             ...        ...
# 112849                  CARDIOLOGY            None       None
# 112850                    PODIATRY            None       None
# 112851              KINESIOTHERAPY            None       None
# 112852      TELEPHONE PRIMARY CARE            None       None
# 112853      TELEPHONE PRIMARY CARE           False       None
#
#        Ionizingradiationflag Serviceconnectedflag Swasiaconditionsflag  \
# 0                       None                False                 None
# 1                       None                False                 None
# 2                       None                False                 None
# 3                       None                False                 None
# 4                       None                 None                 None
# ...                      ...                  ...                  ...
# 112849                  None                 True                 None
# 112850                  None                 True                 None
# 112851                  None                False                 None
# 112852                  None                 None                 None
# 112853                  None                False                 None
#
#               State
# 0           Indiana
# 1           Indiana
# 2             Texas
# 3             Texas
# 4       Puerto Rico
# ...             ...
# 112849   California
# 112850   California
# 112851   California
# 112852   California
# 112853      Georgia
#
# [111745 rows x 12 columns]

# %%
filtered_df.Internalpatientid.nunique()
# Out:
# 68683

# %%
outpatient_train_data = filtered_df  # Assinging new varible

# %% [markdown]
# # Adding  'Age at visit' & 'First listed diagnosis icd10 subcategory' columns with '_'

# %%
#In this code, we create a new column called 'Lab test description_Result numeric' by concatenating the values of the 'lab test description' column, underscore ('_'), and the 'lab test results' column
#converted to a string using the `astype(str)` function(because we cant't add differnt dtype)
outpatient_train_data['outpatients_First_listed_diagnosis_icd10_subcategory'] =  outpatient_train_data['Age at visit'].astype(str) + '_' +  outpatient_train_data['First listed diagnosis icd10 subcategory']

# %% [markdown]
# # Adding  'Age at visit' & 'Second listed diagnosis icd10 subcategory' columns with '_'

# %%
#In this code, we create a new column called 'Lab test description_Result numeric' by concatenating the values of the 'lab test description' column, underscore ('_'), and the 'lab test results' column
#converted to a string using the `astype(str)` function(because we cant't add differnt dtype)
outpatient_train_data['outpatients_Second_listed_diagnosis_icd10_subcategory'] =  outpatient_train_data['Age at visit'].astype(str) + '_' +  outpatient_train_data['Second listed diagnosis icd10 subcategory']

# %% [markdown]
# # Dropping all unnecessary columns

# %%
# Remove columns 
outpatient_train_data.drop(['Age at visit','Visit start date','First listed diagnosis icd10 subcategory','Second listed diagnosis icd10 subcategory',
                            'Stop code','Agentorangeflag','Combatflag','Ionizingradiationflag','Serviceconnectedflag','Swasiaconditionsflag','State'], axis=1,inplace=True)

# %%
outpatient_train_data = outpatient_train_data

# %%
outpatient_train_data
# Out:
#         Internalpatientid  \
# 0                       1
# 1                       1
# 2                       2
# 3                       2
# 4                       4
# ...                   ...
# 112849             169057
# 112850             169057
# 112851             169057
# 112852             169060
# 112853             169061
#
#        outpatients_First_listed_diagnosis_icd10_subcategory  \
# 0          80_Other specified inflammatory liver diseases
# 1       80_Unspecified atrial fibrillation and atrial ...
# 2       69_Encounter for screening for other specified...
# 3       69_Encounter for screening for other specified...
# 4                           84_Unspecified abdominal pain
# ...                                                   ...
# 112849                         86_Ischemic cardiomyopathy
# 112850  86_Type 2 diabetes mellitus with unspecified c...
# 112851                   86_Presence of cardiac pacemaker
# 112852         72_Encounter for other specified aftercare
# 112853                      81_Other specified counseling
#
#        outpatients_Second_listed_diagnosis_icd10_subcategory
# 0       80_Type 2 diabetes mellitus without complications
# 1                                        80_Not specified
# 2                                        69_Not specified
# 3                                        69_Not specified
# 4                                        84_Not specified
# ...                                                   ...
# 112849     86_Venous insufficiency (chronic) (peripheral)
# 112850     86_Venous insufficiency (chronic) (peripheral)
# 112851                                   86_Not specified
# 112852                                   72_Not specified
# 112853                                   81_Not specified
#
# [111745 rows x 3 columns]

# %%
# Group the DataFrame by 'Internalpatientid' and concatenate the icd10 values and
#The purpose of `x.dropna()` is to remove any missing values from the Series before applying a subsequent operation,
# such as concatenation using the `join` function. By dropping the missing values,
#we ensure that only non-null values are included in the resulting concatenated string.
df_grouped = outpatient_train_data.groupby('Internalpatientid').agg(lambda x: ','.join(x.dropna()))
df_grouped 

# Reset the index of the grouped DataFrame
df_grouped_outpatients = df_grouped.reset_index()
df_grouped_outpatients
# Out:
#        Internalpatientid outpatients_First_listed_diagnosis_icd10_subcategory  \
# 0                      1  80_Other specified inflammatory liver diseases...
# 1                      2  69_Encounter for screening for other specified...
# 2                      4  84_Unspecified abdominal pain,84_Problems rela...
# 3                      8  69_Essential (primary) hypertension,69_Essenti...
# 4                     10                                     72_Sleep apnea
# ...                  ...                                                ...
# 68678             169053  81_Abnormal weight loss,81_Delirium due to kno...
# 68679             169056        88_Peripheral vascular disease, unspecified
# 68680             169057  86_Presence of cardiac pacemaker,86_Ischemic c...
# 68681             169060         72_Encounter for other specified aftercare
# 68682             169061                      81_Other specified counseling
#
#       outpatients_Second_listed_diagnosis_icd10_subcategory
# 0      80_Type 2 diabetes mellitus without complicati...
# 1                      69_Not specified,69_Not specified
# 2      84_Not specified,84_Not specified,84_Not speci...
# 3                      69_Not specified,69_Not specified
# 4                                       72_Not specified
# ...                                                  ...
# 68678  81_Encounter for palliative care,81_Not specif...
# 68679                     88_Hyperlipidemia, unspecified
# 68680  86_Not specified,86_Venous insufficiency (chro...
# 68681                                   72_Not specified
# 68682                                   81_Not specified
#
# [68683 rows x 3 columns]

# %% [markdown]
# # Saving the CSV file

# %%
df_grouped_outpatients.to_csv('/mnt/batch/tasks/shared/LS_root/mounts/clusters/team-3-susai-gpu2/code/Users/900379/Output_files_train/df_outpatients_train.csv')

# %%
df_grouped_outpatients['outpatients_First_listed_diagnosis_icd10_subcategory'].values[1]
# Out:
# '69_Encounter for screening for other specified diseases and disorders,69_Encounter for screening for other specified diseases and disorders'

# %%
import os
cwd = os.getcwd()
cwd
# Out:
# '/mnt/batch/tasks/shared/LS_root/mounts/clusters/team-3-susai-gpu2/code/Users/2211575'
