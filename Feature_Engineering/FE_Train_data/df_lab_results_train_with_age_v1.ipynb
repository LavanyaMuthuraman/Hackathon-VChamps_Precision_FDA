# %% [markdown]
# # **Azure notebook Setup**

# %%
#A class attribute that provides access to the TabularDatasetFactory methods for creating new TabularDataset objects. 
#Usage: Dataset.Tabular.from_delimited_files().
from azureml.core import Workspace, Dataset

subscription_id = 'bcfe0c62-8ebe-4df0-a46d-1efcf8739a5b' #check the launch studio there will get this id
resource_group = 'VChamp-Team3' # resource group name
workspace_name = 'vchamp-team3' # worksapce name


# storage account : Algorithmia, Resource group: VChamp-Team3 and workspace: vchamp-team3.
#Constructor
workspace = Workspace(subscription_id, resource_group, workspace_name)

# %%
#['data_team3_synthetic_train']
datastore = workspace.datastores['data_team3_synthetic_train']

# %%
#from_delimited_files (Create a TabularDataset to represent tabular data in delimited files (e.g. CSV and TSV).

dataset = Dataset.Tabular.from_delimited_files(path = [(datastore, 'lab_results_train.csv')])

# preview the first 3 rows of the dataset
# dataset.to_pandas_dataframe()

# %%
#Converting the dataset into data frame(default as dataset in Azure, thus we must convert the needed formate)
lab_train_data = dataset.to_pandas_dataframe()

# %%
lab_train_data
# Out:
#              Column1  Internalpatientid  Age at lab test       Lab test date  \
# 0                  5               5166        79.946327 2015-12-10 09:11:04
# 1                  6               5166        81.160335 2017-02-26 02:27:18
# 2                  7               5166        81.160335 2017-02-26 02:27:18
# 3                  8               5166        81.160335 2017-02-26 02:27:18
# 4                  9               5166        81.160335 2017-02-26 02:27:18
# ...              ...                ...              ...                 ...
# 258527310  328853891              51662        53.534373 2012-05-07 19:31:20
# 258527311  328853892              51662        53.534373 2012-05-07 19:31:20
# 258527312  328853893              51662        53.534373 2012-05-07 19:31:20
# 258527313  328853894              51662        53.534373 2012-05-07 19:31:20
# 258527314  328853895              51662        53.534373 2012-05-07 19:31:20
#
#                                              Lab test  \
# 0          troponin i (d/c'd 02/02/2014)_ng/ml_plasma
# 1                                calcium_mg/dl_plasma
# 2                                sodium_mmol/l_plasma
# 3                             creatinine_mg/dl_plasma
# 4                           protein,total_g/dl_plasma
# ...                                               ...
# 258527310                  mono #_k/cu mm_no specimen
# 258527311                           wbc_k/cu mm_blood
# 258527312                                mch_pg_blood
# 258527313                                 rdw_%_blood
# 258527314                    ba #_k/cu mm_no specimen
#
#                     Lab test description  Result numeric Result textual  \
# 0          TROPONIN I (d/c'd 02/02/2014)        0.020761           None
# 1                                calcium        9.759563           None
# 2                                 SODIUM      130.000000           None
# 3                             CREATININE        1.397398           None
# 4                          PROTEIN,TOTAL        7.232604           None
# ...                                  ...             ...            ...
# 258527310                         MONO #        0.479895           None
# 258527311                            WBC        8.645974           None
# 258527312                            MCH       29.000000           None
# 258527313                            RDW       12.491520           None
# 258527314                           BA #        0.010013           None
#
#           Result range Result units Specimen source  State
# 0          0.01 - 0.04        ng/ml          plasma  Texas
# 1           8.7 - 10.5        mg/dl          plasma  Texas
# 2            136 - 145       mmol/L          plasma  Texas
# 3            0.6 - 1.3        mg/dl          plasma  Texas
# 4            6.2 - 8.0         g/dl          plasma  Texas
# ...                ...          ...             ...    ...
# 258527310       .1 - 1      K/cu mm            None  Texas
# 258527311       4 - 11      K/cu mm           blood  Texas
# 258527312      27 - 34           pg           blood  Texas
# 258527313      11 - 16            %           blood  Texas
# 258527314       0 - .3      K/cu mm            None  Texas
#
# [258527315 rows x 12 columns]

# %%
import numpy as np                # Multi-Dimensional array object
import pandas as pd               # Data Manipulation
import matplotlib.pyplot as plt   # Data Visualization
import seaborn as sns             # Data Visualization 

# Allows the use of display() for DataFrames
from IPython.display import display 

# Handle warning messages that may occur during code execution
import warnings
warnings.filterwarnings('ignore')

# To increase memory allocation
from notebook.services.config import ConfigManager
cm = ConfigManager().update('notebook', {'max_buffer_size': 7294967296})

# Set the maximum number of rows to be displayed to 1000
pd.set_option('display.max_rows', 1163)

# %% [markdown]
# # Elimination of the unnamed columns

# %%
# Remove unwanted columns 
lab_train_data.drop('Column1',axis=1,inplace=True)

# %%
lab_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258527315 entries, 0 to 258527314
# Data columns (total 11 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Internalpatientid     int64
#  1   Age at lab test       float64
#  2   Lab test date         datetime64[ns]
#  3   Lab test              object
#  4   Lab test description  object
#  5   Result numeric        float64
#  6   Result textual        object
#  7   Result range          object
#  8   Result units          object
#  9   Specimen source       object
#  10  State                 object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(7)
# memory usage: 21.2+ GB

# %% [markdown]
# # Sorting out patients id and age column

# %%
# Sort the dataset based on the patientsid and 'age' column in ascending order
lab_train_data.sort_values(["Internalpatientid","Age at lab test"],inplace=True)

# %%
lab_train_data
# Out:
#            Internalpatientid  Age at lab test       Lab test date  \
# 22564                      1        57.839843 2002-02-05 11:06:21
# 33601                      1        57.912086 2002-03-03 20:49:01
# 33602                      1        57.912086 2002-03-03 20:49:01
# 33603                      1        57.912086 2002-03-03 20:49:01
# 33604                      1        57.912086 2002-03-03 20:49:01
# ...                      ...              ...                 ...
# 118272447             169064        87.867074 2014-10-31 09:58:19
# 118272448             169064        87.867074 2014-10-31 09:58:19
# 118272449             169064        87.867074 2014-10-31 09:58:19
# 118272450             169064        87.867074 2014-10-31 09:58:19
# 118272451             169064        87.867074 2014-10-31 09:58:19
#
#                                            Lab test    Lab test description  \
# 22564            zzhemocult series_null_no specimen       ZZHEMOCULT SERIES
# 33601      ldl cholesterol - calc_mg/dl_no specimen  LDL CHOLESTEROL - CALC
# 33602                               sgpt_iu/l_serum                    SGPT
# 33603             hdl cholesterol_mg/dl_no specimen         HDL Cholesterol
# 33604                 cholesterol,total_mg/dl_serum       CHOLESTEROL,TOTAL
# ...                                             ...                     ...
# 118272447           zalpha-1 globulin_%_no specimen       zALPHA-1 GLOBULIN
# 118272448               zalbumin (ep)_%_no specimen           zALBUMIN (EP)
# 118272449                 zm-spike_null_no specimen                zM-SPIKE
# 118272450             zgamma globulin_%_no specimen         zGAMMA GLOBULIN
# 118272451           zalpha-2 globulin_%_no specimen       zALPHA-2 GLOBULIN
#
#            Result numeric Result textual Result range Result units  \
# 22564                 NaN            0/3         None         None
# 33601          130.000000           None         None        mg/dL
# 33602           46.000000           None       0 - 35         Iu/L
# 33603           53.000000           None      35 - 55        mg/dL
# 33604          213.000000           None         None        mg/dL
# ...                   ...            ...          ...          ...
# 118272447        1.671123           None         None            %
# 118272448       34.314524           None         None            %
# 118272449             NaN             NO         None         None
# 118272450       10.269399           None         None            %
# 118272451       13.777030           None         None            %
#
#           Specimen source    State
# 22564                None  Indiana
# 33601                None  Indiana
# 33602               serum  Indiana
# 33603                None  Indiana
# 33604               serum  Indiana
# ...                   ...      ...
# 118272447            None  Wyoming
# 118272448            None  Wyoming
# 118272449            None  Wyoming
# 118272450            None  Wyoming
# 118272451            None  Wyoming
#
# [258527315 rows x 11 columns]

# %% [markdown]
# # Round off the "Result numeric" columns with 2 digits

# %%
lab_train_data['Result numeric'] = lab_train_data['Result numeric'].apply(lambda x: round(x,2))

# %%
lab_train_data
# Out:
#            Internalpatientid  Age at lab test       Lab test date  \
# 22564                      1        57.839843 2002-02-05 11:06:21
# 33601                      1        57.912086 2002-03-03 20:49:01
# 33602                      1        57.912086 2002-03-03 20:49:01
# 33603                      1        57.912086 2002-03-03 20:49:01
# 33604                      1        57.912086 2002-03-03 20:49:01
# ...                      ...              ...                 ...
# 118272447             169064        87.867074 2014-10-31 09:58:19
# 118272448             169064        87.867074 2014-10-31 09:58:19
# 118272449             169064        87.867074 2014-10-31 09:58:19
# 118272450             169064        87.867074 2014-10-31 09:58:19
# 118272451             169064        87.867074 2014-10-31 09:58:19
#
#                                            Lab test    Lab test description  \
# 22564            zzhemocult series_null_no specimen       ZZHEMOCULT SERIES
# 33601      ldl cholesterol - calc_mg/dl_no specimen  LDL CHOLESTEROL - CALC
# 33602                               sgpt_iu/l_serum                    SGPT
# 33603             hdl cholesterol_mg/dl_no specimen         HDL Cholesterol
# 33604                 cholesterol,total_mg/dl_serum       CHOLESTEROL,TOTAL
# ...                                             ...                     ...
# 118272447           zalpha-1 globulin_%_no specimen       zALPHA-1 GLOBULIN
# 118272448               zalbumin (ep)_%_no specimen           zALBUMIN (EP)
# 118272449                 zm-spike_null_no specimen                zM-SPIKE
# 118272450             zgamma globulin_%_no specimen         zGAMMA GLOBULIN
# 118272451           zalpha-2 globulin_%_no specimen       zALPHA-2 GLOBULIN
#
#            Result numeric Result textual Result range Result units  \
# 22564                 NaN            0/3         None         None
# 33601              130.00           None         None        mg/dL
# 33602               46.00           None       0 - 35         Iu/L
# 33603               53.00           None      35 - 55        mg/dL
# 33604              213.00           None         None        mg/dL
# ...                   ...            ...          ...          ...
# 118272447            1.67           None         None            %
# 118272448           34.31           None         None            %
# 118272449             NaN             NO         None         None
# 118272450           10.27           None         None            %
# 118272451           13.78           None         None            %
#
#           Specimen source    State
# 22564                None  Indiana
# 33601                None  Indiana
# 33602               serum  Indiana
# 33603                None  Indiana
# 33604               serum  Indiana
# ...                   ...      ...
# 118272447            None  Wyoming
# 118272448            None  Wyoming
# 118272449            None  Wyoming
# 118272450            None  Wyoming
# 118272451            None  Wyoming
#
# [258527315 rows x 11 columns]

# %%
#checking the missing values
print("Training set missing values:\n", lab_train_data.isna().sum())
# Out:
# Training set missing values:
#  Internalpatientid               0
# Age at lab test                 0
# Lab test date                   0
# Lab test                        0
# Lab test description            0
# Result numeric           32490288
# Result textual          226143923
# Result range             49021868
# Result units             31460687
# Specimen source         109735139
# State                           0
# dtype: int64

# %% [markdown]
# * **There is an missing value are presented columns "Result numeric(32490288)","Result textual(226143923)","Result range(49021868)","Result units"(31460687) and "Specimen source(109735139)"**
#
# * **Note : I cross-checked the "Result numeric" and "Result textual" missing values, because some values from the lab test results are mentioned in numerical form and others are mentioned in textual form (wherever numerical lab results are missing that may exist in the textual lab results) If so, you can combine the "Result textual" and "Result numeric."**

# %% [markdown]
# # Replace NaN values in "Result numeric" with corresponding values from "Result textual"

# %%
# Replace NaN values in "Result numeric" with corresponding values from "Result textual"
lab_train_data['Result'] = lab_train_data['Result numeric'].fillna(lab_train_data['Result textual'])

# Print the updated DataFrame
lab_train_data
# Out:
#            Internalpatientid  Age at lab test       Lab test date  \
# 22564                      1        57.839843 2002-02-05 11:06:21
# 33601                      1        57.912086 2002-03-03 20:49:01
# 33602                      1        57.912086 2002-03-03 20:49:01
# 33603                      1        57.912086 2002-03-03 20:49:01
# 33604                      1        57.912086 2002-03-03 20:49:01
# ...                      ...              ...                 ...
# 118272447             169064        87.867074 2014-10-31 09:58:19
# 118272448             169064        87.867074 2014-10-31 09:58:19
# 118272449             169064        87.867074 2014-10-31 09:58:19
# 118272450             169064        87.867074 2014-10-31 09:58:19
# 118272451             169064        87.867074 2014-10-31 09:58:19
#
#                                            Lab test    Lab test description  \
# 22564            zzhemocult series_null_no specimen       ZZHEMOCULT SERIES
# 33601      ldl cholesterol - calc_mg/dl_no specimen  LDL CHOLESTEROL - CALC
# 33602                               sgpt_iu/l_serum                    SGPT
# 33603             hdl cholesterol_mg/dl_no specimen         HDL Cholesterol
# 33604                 cholesterol,total_mg/dl_serum       CHOLESTEROL,TOTAL
# ...                                             ...                     ...
# 118272447           zalpha-1 globulin_%_no specimen       zALPHA-1 GLOBULIN
# 118272448               zalbumin (ep)_%_no specimen           zALBUMIN (EP)
# 118272449                 zm-spike_null_no specimen                zM-SPIKE
# 118272450             zgamma globulin_%_no specimen         zGAMMA GLOBULIN
# 118272451           zalpha-2 globulin_%_no specimen       zALPHA-2 GLOBULIN
#
#            Result numeric Result textual Result range Result units  \
# 22564                 NaN            0/3         None         None
# 33601              130.00           None         None        mg/dL
# 33602               46.00           None       0 - 35         Iu/L
# 33603               53.00           None      35 - 55        mg/dL
# 33604              213.00           None         None        mg/dL
# ...                   ...            ...          ...          ...
# 118272447            1.67           None         None            %
# 118272448           34.31           None         None            %
# 118272449             NaN             NO         None         None
# 118272450           10.27           None         None            %
# 118272451           13.78           None         None            %
#
#           Specimen source    State Result
# 22564                None  Indiana    0/3
# 33601                None  Indiana    130
# 33602               serum  Indiana     46
# 33603                None  Indiana     53
# 33604               serum  Indiana    213
# ...                   ...      ...    ...
# 118272447            None  Wyoming   1.67
# 118272448            None  Wyoming  34.31
# 118272449            None  Wyoming     NO
# 118272450            None  Wyoming  10.27
# 118272451            None  Wyoming  13.78
#
# [258527315 rows x 12 columns]

# %%
# Check for missing or NaN values in the 'Result' column(before)
missing_data = lab_train_data['Result'].isnull().sum()


if missing_data > 0:
    print(f"There are {missing_data} missing or NaN values in the 'Result' column.")
else:
    print("No missing or NaN values found in the 'Result' column.")
# Out:
# There are 106896 missing or NaN values in the 'Result' column.

# %% [markdown]
# * **Since both "Result Numeric" and "Result Textual" are missing, we may really consider that value to be empty in the "Result"**( Actual test results are not available.)

# %%
# Remove rows missing values in the "result" column
lab_train_data.dropna(subset=["Result"],inplace=True)

# %%
lab_train_data = lab_train_data

# %%
lab_train_data
# Out:
#            Internalpatientid  Age at lab test       Lab test date  \
# 22564                      1        57.839843 2002-02-05 11:06:21
# 33601                      1        57.912086 2002-03-03 20:49:01
# 33602                      1        57.912086 2002-03-03 20:49:01
# 33603                      1        57.912086 2002-03-03 20:49:01
# 33604                      1        57.912086 2002-03-03 20:49:01
# ...                      ...              ...                 ...
# 118272447             169064        87.867074 2014-10-31 09:58:19
# 118272448             169064        87.867074 2014-10-31 09:58:19
# 118272449             169064        87.867074 2014-10-31 09:58:19
# 118272450             169064        87.867074 2014-10-31 09:58:19
# 118272451             169064        87.867074 2014-10-31 09:58:19
#
#                                            Lab test    Lab test description  \
# 22564            zzhemocult series_null_no specimen       ZZHEMOCULT SERIES
# 33601      ldl cholesterol - calc_mg/dl_no specimen  LDL CHOLESTEROL - CALC
# 33602                               sgpt_iu/l_serum                    SGPT
# 33603             hdl cholesterol_mg/dl_no specimen         HDL Cholesterol
# 33604                 cholesterol,total_mg/dl_serum       CHOLESTEROL,TOTAL
# ...                                             ...                     ...
# 118272447           zalpha-1 globulin_%_no specimen       zALPHA-1 GLOBULIN
# 118272448               zalbumin (ep)_%_no specimen           zALBUMIN (EP)
# 118272449                 zm-spike_null_no specimen                zM-SPIKE
# 118272450             zgamma globulin_%_no specimen         zGAMMA GLOBULIN
# 118272451           zalpha-2 globulin_%_no specimen       zALPHA-2 GLOBULIN
#
#            Result numeric Result textual Result range Result units  \
# 22564                 NaN            0/3         None         None
# 33601              130.00           None         None        mg/dL
# 33602               46.00           None       0 - 35         Iu/L
# 33603               53.00           None      35 - 55        mg/dL
# 33604              213.00           None         None        mg/dL
# ...                   ...            ...          ...          ...
# 118272447            1.67           None         None            %
# 118272448           34.31           None         None            %
# 118272449             NaN             NO         None         None
# 118272450           10.27           None         None            %
# 118272451           13.78           None         None            %
#
#           Specimen source    State Result
# 22564                None  Indiana    0/3
# 33601                None  Indiana    130
# 33602               serum  Indiana     46
# 33603                None  Indiana     53
# 33604               serum  Indiana    213
# ...                   ...      ...    ...
# 118272447            None  Wyoming   1.67
# 118272448            None  Wyoming  34.31
# 118272449            None  Wyoming     NO
# 118272450            None  Wyoming  10.27
# 118272451            None  Wyoming  13.78
#
# [258420419 rows x 12 columns]

# %%
# Check for missing or NaN values in the 'Result' column(after removing)
missing_data = lab_train_data['Result'].isnull().sum()


if missing_data > 0:
    print(f"There are {missing_data} missing or NaN values in the 'Result' column.")
else:
    print("No missing or NaN values found in the 'Result' column.")
# Out:
# No missing or NaN values found in the 'Result' column.

# %% [markdown]
# * **Missing values has been removed from the "Result" column**

# %% [markdown]
# # Taking the digits in age

# %%
# Format 'Age at measurement' values in the format 00.00
lab_train_data["Age at lab test"] =lab_train_data["Age at lab test"].map("{:.3f}".format)

# %%
lab_train_data
# Out:
#            Internalpatientid Age at lab test       Lab test date  \
# 22564                      1          57.840 2002-02-05 11:06:21
# 33601                      1          57.912 2002-03-03 20:49:01
# 33602                      1          57.912 2002-03-03 20:49:01
# 33603                      1          57.912 2002-03-03 20:49:01
# 33604                      1          57.912 2002-03-03 20:49:01
# ...                      ...             ...                 ...
# 118272447             169064          87.867 2014-10-31 09:58:19
# 118272448             169064          87.867 2014-10-31 09:58:19
# 118272449             169064          87.867 2014-10-31 09:58:19
# 118272450             169064          87.867 2014-10-31 09:58:19
# 118272451             169064          87.867 2014-10-31 09:58:19
#
#                                            Lab test    Lab test description  \
# 22564            zzhemocult series_null_no specimen       ZZHEMOCULT SERIES
# 33601      ldl cholesterol - calc_mg/dl_no specimen  LDL CHOLESTEROL - CALC
# 33602                               sgpt_iu/l_serum                    SGPT
# 33603             hdl cholesterol_mg/dl_no specimen         HDL Cholesterol
# 33604                 cholesterol,total_mg/dl_serum       CHOLESTEROL,TOTAL
# ...                                             ...                     ...
# 118272447           zalpha-1 globulin_%_no specimen       zALPHA-1 GLOBULIN
# 118272448               zalbumin (ep)_%_no specimen           zALBUMIN (EP)
# 118272449                 zm-spike_null_no specimen                zM-SPIKE
# 118272450             zgamma globulin_%_no specimen         zGAMMA GLOBULIN
# 118272451           zalpha-2 globulin_%_no specimen       zALPHA-2 GLOBULIN
#
#            Result numeric Result textual Result range Result units  \
# 22564                 NaN            0/3         None         None
# 33601              130.00           None         None        mg/dL
# 33602               46.00           None       0 - 35         Iu/L
# 33603               53.00           None      35 - 55        mg/dL
# 33604              213.00           None         None        mg/dL
# ...                   ...            ...          ...          ...
# 118272447            1.67           None         None            %
# 118272448           34.31           None         None            %
# 118272449             NaN             NO         None         None
# 118272450           10.27           None         None            %
# 118272451           13.78           None         None            %
#
#           Specimen source    State Result
# 22564                None  Indiana    0/3
# 33601                None  Indiana    130
# 33602               serum  Indiana     46
# 33603                None  Indiana     53
# 33604               serum  Indiana    213
# ...                   ...      ...    ...
# 118272447            None  Wyoming   1.67
# 118272448            None  Wyoming  34.31
# 118272449            None  Wyoming     NO
# 118272450            None  Wyoming  10.27
# 118272451            None  Wyoming  13.78
#
# [258420419 rows x 12 columns]

# %% [markdown]
# # max age

# %%
# Find the maximum age for each internal patient id
max_ages = lab_train_data.groupby('Internalpatientid')['Age at lab test'].max().reset_index()

# Merge with the original dataframe to get the rows with the highest age
lab_train_data = pd.merge(lab_train_data, max_ages, on =['Internalpatientid','Age at lab test'], how = 'inner')

lab_train_data
# Out:
#          Internalpatientid Age at lab test       Lab test date  \
# 0                        1          80.208 2024-06-25 01:47:33
# 1                        1          80.208 2024-06-25 01:47:34
# 2                        1          80.208 2024-06-25 01:47:34
# 3                        1          80.208 2024-06-25 01:47:35
# 4                        1          80.208 2024-06-25 01:47:35
# ...                    ...             ...                 ...
# 3465932             169064          87.867 2014-10-31 09:58:19
# 3465933             169064          87.867 2014-10-31 09:58:19
# 3465934             169064          87.867 2014-10-31 09:58:19
# 3465935             169064          87.867 2014-10-31 09:58:19
# 3465936             169064          87.867 2014-10-31 09:58:19
#
#                                        Lab test   Lab test description  \
# 0           alpha fetoprotein_ng/ml_no specimen      Alpha Fetoprotein
# 1                           inr -top_inr_plasma               INR -TOP
# 2        prothrombin time -top_sec._no specimen  PROTHROMBIN TIME -TOP
# 3                          hgb_g/dl_no specimen                    HGB
# 4                            mpv_fl_no specimen                    Mpv
# ...                                         ...                    ...
# 3465932         zalpha-1 globulin_%_no specimen      zALPHA-1 GLOBULIN
# 3465933             zalbumin (ep)_%_no specimen          zALBUMIN (EP)
# 3465934               zm-spike_null_no specimen               zM-SPIKE
# 3465935           zgamma globulin_%_no specimen        zGAMMA GLOBULIN
# 3465936         zalpha-2 globulin_%_no specimen      zALPHA-2 GLOBULIN
#
#          Result numeric Result textual Result range Result units  \
# 0                  3.00           None         None        ng/mL
# 1                  1.68           None         None          INR
# 2                 21.83           None  10.3 - 14.7         sec.
# 3                 13.77           None  13.0 - 17.1         g/dL
# 4                 10.68           None   8.7 - 12.3           fL
# ...                 ...            ...          ...          ...
# 3465932            1.67           None         None            %
# 3465933           34.31           None         None            %
# 3465934             NaN             NO         None         None
# 3465935           10.27           None         None            %
# 3465936           13.78           None         None            %
#
#         Specimen source    State Result
# 0                  None  Indiana      3
# 1                plasma  Indiana   1.68
# 2                  None  Indiana  21.83
# 3                  None  Indiana  13.77
# 4                  None  Indiana  10.68
# ...                 ...      ...    ...
# 3465932            None  Wyoming   1.67
# 3465933            None  Wyoming  34.31
# 3465934            None  Wyoming     NO
# 3465935            None  Wyoming  10.27
# 3465936            None  Wyoming  13.78
#
# [3465937 rows x 12 columns]

# %%
# Convert 'Age at measurement' column from object to float
lab_train_data["Age at lab test"] = lab_train_data["Age at lab test"].astype(float)

# %%
lab_train_data
# Out:
#          Internalpatientid  Age at lab test       Lab test date  \
# 0                        1           80.208 2024-06-25 01:47:33
# 1                        1           80.208 2024-06-25 01:47:34
# 2                        1           80.208 2024-06-25 01:47:34
# 3                        1           80.208 2024-06-25 01:47:35
# 4                        1           80.208 2024-06-25 01:47:35
# ...                    ...              ...                 ...
# 3465932             169064           87.867 2014-10-31 09:58:19
# 3465933             169064           87.867 2014-10-31 09:58:19
# 3465934             169064           87.867 2014-10-31 09:58:19
# 3465935             169064           87.867 2014-10-31 09:58:19
# 3465936             169064           87.867 2014-10-31 09:58:19
#
#                                        Lab test   Lab test description  \
# 0           alpha fetoprotein_ng/ml_no specimen      Alpha Fetoprotein
# 1                           inr -top_inr_plasma               INR -TOP
# 2        prothrombin time -top_sec._no specimen  PROTHROMBIN TIME -TOP
# 3                          hgb_g/dl_no specimen                    HGB
# 4                            mpv_fl_no specimen                    Mpv
# ...                                         ...                    ...
# 3465932         zalpha-1 globulin_%_no specimen      zALPHA-1 GLOBULIN
# 3465933             zalbumin (ep)_%_no specimen          zALBUMIN (EP)
# 3465934               zm-spike_null_no specimen               zM-SPIKE
# 3465935           zgamma globulin_%_no specimen        zGAMMA GLOBULIN
# 3465936         zalpha-2 globulin_%_no specimen      zALPHA-2 GLOBULIN
#
#          Result numeric Result textual Result range Result units  \
# 0                  3.00           None         None        ng/mL
# 1                  1.68           None         None          INR
# 2                 21.83           None  10.3 - 14.7         sec.
# 3                 13.77           None  13.0 - 17.1         g/dL
# 4                 10.68           None   8.7 - 12.3           fL
# ...                 ...            ...          ...          ...
# 3465932            1.67           None         None            %
# 3465933           34.31           None         None            %
# 3465934             NaN             NO         None         None
# 3465935           10.27           None         None            %
# 3465936           13.78           None         None            %
#
#         Specimen source    State Result
# 0                  None  Indiana      3
# 1                plasma  Indiana   1.68
# 2                  None  Indiana  21.83
# 3                  None  Indiana  13.77
# 4                  None  Indiana  10.68
# ...                 ...      ...    ...
# 3465932            None  Wyoming   1.67
# 3465933            None  Wyoming  34.31
# 3465934            None  Wyoming     NO
# 3465935            None  Wyoming  10.27
# 3465936            None  Wyoming  13.78
#
# [3465937 rows x 12 columns]

# %% [markdown]
# # Round off

# %%
lab_train_data['Age at lab test'] = lab_train_data['Age at lab test'].apply(lambda x: round(x,))

# %%
lab_train_data
# Out:
#          Internalpatientid  Age at lab test       Lab test date  \
# 0                        1               80 2024-06-25 01:47:33
# 1                        1               80 2024-06-25 01:47:34
# 2                        1               80 2024-06-25 01:47:34
# 3                        1               80 2024-06-25 01:47:35
# 4                        1               80 2024-06-25 01:47:35
# ...                    ...              ...                 ...
# 3465932             169064               88 2014-10-31 09:58:19
# 3465933             169064               88 2014-10-31 09:58:19
# 3465934             169064               88 2014-10-31 09:58:19
# 3465935             169064               88 2014-10-31 09:58:19
# 3465936             169064               88 2014-10-31 09:58:19
#
#                                        Lab test   Lab test description  \
# 0           alpha fetoprotein_ng/ml_no specimen      Alpha Fetoprotein
# 1                           inr -top_inr_plasma               INR -TOP
# 2        prothrombin time -top_sec._no specimen  PROTHROMBIN TIME -TOP
# 3                          hgb_g/dl_no specimen                    HGB
# 4                            mpv_fl_no specimen                    Mpv
# ...                                         ...                    ...
# 3465932         zalpha-1 globulin_%_no specimen      zALPHA-1 GLOBULIN
# 3465933             zalbumin (ep)_%_no specimen          zALBUMIN (EP)
# 3465934               zm-spike_null_no specimen               zM-SPIKE
# 3465935           zgamma globulin_%_no specimen        zGAMMA GLOBULIN
# 3465936         zalpha-2 globulin_%_no specimen      zALPHA-2 GLOBULIN
#
#          Result numeric Result textual Result range Result units  \
# 0                  3.00           None         None        ng/mL
# 1                  1.68           None         None          INR
# 2                 21.83           None  10.3 - 14.7         sec.
# 3                 13.77           None  13.0 - 17.1         g/dL
# 4                 10.68           None   8.7 - 12.3           fL
# ...                 ...            ...          ...          ...
# 3465932            1.67           None         None            %
# 3465933           34.31           None         None            %
# 3465934             NaN             NO         None         None
# 3465935           10.27           None         None            %
# 3465936           13.78           None         None            %
#
#         Specimen source    State Result
# 0                  None  Indiana      3
# 1                plasma  Indiana   1.68
# 2                  None  Indiana  21.83
# 3                  None  Indiana  13.77
# 4                  None  Indiana  10.68
# ...                 ...      ...    ...
# 3465932            None  Wyoming   1.67
# 3465933            None  Wyoming  34.31
# 3465934            None  Wyoming     NO
# 3465935            None  Wyoming  10.27
# 3465936            None  Wyoming  13.78
#
# [3465937 rows x 12 columns]

# %%
lab_train_data["Internalpatientid"].nunique()
# Out:
# 130445

# %%
df_3 = lab_train_data["Internalpatientid"].value_counts().loc[lambda x: x>80].to_frame()

# %%
df = df_3.reset_index()

# %%
df.columns = ["Internalpatientid","count"]

# %%
df.drop(["count"],axis=1,inplace =True)

# %%
df = df

# %%
df
# Out:
#       Internalpatientid
# 0                 44379
# 1                 81438
# 2                 92012
# 3                 52677
# 4                 36510
# ...                 ...
# 1602              10022
# 1603             138147
# 1604              65172
# 1605              78684
# 1606              97305
#
# [1607 rows x 1 columns]

# %%
# Merge the two dataframes based on 'Internalpatientid'
merged_df = lab_train_data.merge(df, on='Internalpatientid', how='left')

# Filter rows from DataFrame 1 that have matching values in DataFrame 2
filtered_df = merged_df[~merged_df['Internalpatientid'].isin(df['Internalpatientid'])]

# Print only the columns of DataFrame 1
filtered_df
# Out:
#          Internalpatientid  Age at lab test       Lab test date  \
# 0                        1               80 2024-06-25 01:47:33
# 1                        1               80 2024-06-25 01:47:34
# 2                        1               80 2024-06-25 01:47:34
# 3                        1               80 2024-06-25 01:47:35
# 4                        1               80 2024-06-25 01:47:35
# ...                    ...              ...                 ...
# 3465932             169064               88 2014-10-31 09:58:19
# 3465933             169064               88 2014-10-31 09:58:19
# 3465934             169064               88 2014-10-31 09:58:19
# 3465935             169064               88 2014-10-31 09:58:19
# 3465936             169064               88 2014-10-31 09:58:19
#
#                                        Lab test   Lab test description  \
# 0           alpha fetoprotein_ng/ml_no specimen      Alpha Fetoprotein
# 1                           inr -top_inr_plasma               INR -TOP
# 2        prothrombin time -top_sec._no specimen  PROTHROMBIN TIME -TOP
# 3                          hgb_g/dl_no specimen                    HGB
# 4                            mpv_fl_no specimen                    Mpv
# ...                                         ...                    ...
# 3465932         zalpha-1 globulin_%_no specimen      zALPHA-1 GLOBULIN
# 3465933             zalbumin (ep)_%_no specimen          zALBUMIN (EP)
# 3465934               zm-spike_null_no specimen               zM-SPIKE
# 3465935           zgamma globulin_%_no specimen        zGAMMA GLOBULIN
# 3465936         zalpha-2 globulin_%_no specimen      zALPHA-2 GLOBULIN
#
#          Result numeric Result textual Result range Result units  \
# 0                  3.00           None         None        ng/mL
# 1                  1.68           None         None          INR
# 2                 21.83           None  10.3 - 14.7         sec.
# 3                 13.77           None  13.0 - 17.1         g/dL
# 4                 10.68           None   8.7 - 12.3           fL
# ...                 ...            ...          ...          ...
# 3465932            1.67           None         None            %
# 3465933           34.31           None         None            %
# 3465934             NaN             NO         None         None
# 3465935           10.27           None         None            %
# 3465936           13.78           None         None            %
#
#         Specimen source    State Result
# 0                  None  Indiana      3
# 1                plasma  Indiana   1.68
# 2                  None  Indiana  21.83
# 3                  None  Indiana  13.77
# 4                  None  Indiana  10.68
# ...                 ...      ...    ...
# 3465932            None  Wyoming   1.67
# 3465933            None  Wyoming  34.31
# 3465934            None  Wyoming     NO
# 3465935            None  Wyoming  10.27
# 3465936            None  Wyoming  13.78
#
# [3314277 rows x 12 columns]

# %%
lab_train_data = filtered_df

# %%
lab_train_data
# Out:
#          Internalpatientid  Age at lab test       Lab test date  \
# 0                        1               80 2024-06-25 01:47:33
# 1                        1               80 2024-06-25 01:47:34
# 2                        1               80 2024-06-25 01:47:34
# 3                        1               80 2024-06-25 01:47:35
# 4                        1               80 2024-06-25 01:47:35
# ...                    ...              ...                 ...
# 3465932             169064               88 2014-10-31 09:58:19
# 3465933             169064               88 2014-10-31 09:58:19
# 3465934             169064               88 2014-10-31 09:58:19
# 3465935             169064               88 2014-10-31 09:58:19
# 3465936             169064               88 2014-10-31 09:58:19
#
#                                        Lab test   Lab test description  \
# 0           alpha fetoprotein_ng/ml_no specimen      Alpha Fetoprotein
# 1                           inr -top_inr_plasma               INR -TOP
# 2        prothrombin time -top_sec._no specimen  PROTHROMBIN TIME -TOP
# 3                          hgb_g/dl_no specimen                    HGB
# 4                            mpv_fl_no specimen                    Mpv
# ...                                         ...                    ...
# 3465932         zalpha-1 globulin_%_no specimen      zALPHA-1 GLOBULIN
# 3465933             zalbumin (ep)_%_no specimen          zALBUMIN (EP)
# 3465934               zm-spike_null_no specimen               zM-SPIKE
# 3465935           zgamma globulin_%_no specimen        zGAMMA GLOBULIN
# 3465936         zalpha-2 globulin_%_no specimen      zALPHA-2 GLOBULIN
#
#          Result numeric Result textual Result range Result units  \
# 0                  3.00           None         None        ng/mL
# 1                  1.68           None         None          INR
# 2                 21.83           None  10.3 - 14.7         sec.
# 3                 13.77           None  13.0 - 17.1         g/dL
# 4                 10.68           None   8.7 - 12.3           fL
# ...                 ...            ...          ...          ...
# 3465932            1.67           None         None            %
# 3465933           34.31           None         None            %
# 3465934             NaN             NO         None         None
# 3465935           10.27           None         None            %
# 3465936           13.78           None         None            %
#
#         Specimen source    State Result
# 0                  None  Indiana      3
# 1                plasma  Indiana   1.68
# 2                  None  Indiana  21.83
# 3                  None  Indiana  13.77
# 4                  None  Indiana  10.68
# ...                 ...      ...    ...
# 3465932            None  Wyoming   1.67
# 3465933            None  Wyoming  34.31
# 3465934            None  Wyoming     NO
# 3465935            None  Wyoming  10.27
# 3465936            None  Wyoming  13.78
#
# [3314277 rows x 12 columns]

# %%
lab_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3314277 entries, 0 to 3465936
# Data columns (total 12 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Internalpatientid     int64
#  1   Age at lab test       int64
#  2   Lab test date         datetime64[ns]
#  3   Lab test              object
#  4   Lab test description  object
#  5   Result numeric        float64
#  6   Result textual        object
#  7   Result range          object
#  8   Result units          object
#  9   Specimen source       object
#  10  State                 object
#  11  Result                object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(8)
# memory usage: 328.7+ MB

# %%
# lab_train_data['Result'] = lab_train_data['Result'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 lab_train_data['Result'] = lab_train_data['Result'].astype(float)
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/pandas/core/generic.py:5548, in NDFrame.astype(self, dtype, copy, errors)
#    5541     results = [
#    5542         self.iloc[:, i].astype(dtype, copy=copy)
#    5543         for i in range(len(self.columns))
#    5544     ]
#    5546 else:
#    5547     # else, only a single dtype is given
# -> 5548     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549     return self._constructor(new_data).__finalize__(self, method="astype")
#    5551 # GH 33113: handle empty frame or series
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/pandas/core/internals/managers.py:604, in BlockManager.astype(self, dtype, copy, errors)
#     601 def astype(
#     602     self, dtype, copy: bool = False, errors: str = "raise"
#     603 ) -> "BlockManager":
# --> 604     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/pandas/core/internals/managers.py:409, in BlockManager.apply(self, f, align_keys, **kwargs)
#     407         applied = b.apply(f, **kwargs)
#     408     else:
# --> 409         applied = getattr(b, f)(**kwargs)
#     410     result_blocks = _extend_blocks(applied, result_blocks)
#     412 if len(result_blocks) == 0:
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/pandas/core/internals/blocks.py:595, in Block.astype(self, dtype, copy, errors)
#     593 vals1d = values.ravel()
#     594 try:
# --> 595     values = astype_nansafe(vals1d, dtype, copy=True)
#     596 except (ValueError, TypeError):
#     597     # e.g. astype_nansafe can fail on object-dtype of strings
#     598     #  trying to convert to float
#     599     if errors == "raise":
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/pandas/core/dtypes/cast.py:997, in astype_nansafe(arr, dtype, copy, skipna)
#     993     raise ValueError(msg)
#     995 if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#     996     # Explicit copy, or required since NumPy can't view from / to object.
# --> 997     return arr.astype(dtype, copy=True)
#     999 return arr.view(dtype)
#
# ValueError: could not convert string to float: 'DONE'

# %% [markdown]
# # Adding  "Age at lab test",'Lab test description' & 'Result (Result numeric & Result textual)' columns with '_'

# %%
#In this code, we create a new column called 'Lab test description_Result numeric' by concatenating the values of the 'lab test description' column, underscore ('_'), and the 'lab test results' column
#converted to a string using the `astype(str)` function(because we cant't add differnt dtype)
lab_train_data ['Lab_test_description_Result'] = lab_train_data['Age at lab test'].astype(str) + '_' +  lab_train_data['Lab test description'] + '_' +  lab_train_data['Result'].astype(str)

# %%
lab_train_data
# Out:
#          Internalpatientid  Age at lab test       Lab test date  \
# 0                        1               80 2024-06-25 01:47:33
# 1                        1               80 2024-06-25 01:47:34
# 2                        1               80 2024-06-25 01:47:34
# 3                        1               80 2024-06-25 01:47:35
# 4                        1               80 2024-06-25 01:47:35
# ...                    ...              ...                 ...
# 3465932             169064               88 2014-10-31 09:58:19
# 3465933             169064               88 2014-10-31 09:58:19
# 3465934             169064               88 2014-10-31 09:58:19
# 3465935             169064               88 2014-10-31 09:58:19
# 3465936             169064               88 2014-10-31 09:58:19
#
#                                        Lab test   Lab test description  \
# 0           alpha fetoprotein_ng/ml_no specimen      Alpha Fetoprotein
# 1                           inr -top_inr_plasma               INR -TOP
# 2        prothrombin time -top_sec._no specimen  PROTHROMBIN TIME -TOP
# 3                          hgb_g/dl_no specimen                    HGB
# 4                            mpv_fl_no specimen                    Mpv
# ...                                         ...                    ...
# 3465932         zalpha-1 globulin_%_no specimen      zALPHA-1 GLOBULIN
# 3465933             zalbumin (ep)_%_no specimen          zALBUMIN (EP)
# 3465934               zm-spike_null_no specimen               zM-SPIKE
# 3465935           zgamma globulin_%_no specimen        zGAMMA GLOBULIN
# 3465936         zalpha-2 globulin_%_no specimen      zALPHA-2 GLOBULIN
#
#          Result numeric Result textual Result range Result units  \
# 0                  3.00           None         None        ng/mL
# 1                  1.68           None         None          INR
# 2                 21.83           None  10.3 - 14.7         sec.
# 3                 13.77           None  13.0 - 17.1         g/dL
# 4                 10.68           None   8.7 - 12.3           fL
# ...                 ...            ...          ...          ...
# 3465932            1.67           None         None            %
# 3465933           34.31           None         None            %
# 3465934             NaN             NO         None         None
# 3465935           10.27           None         None            %
# 3465936           13.78           None         None            %
#
#         Specimen source    State Result     Lab_test_description_Result
# 0                  None  Indiana      3        80_Alpha Fetoprotein_3.0
# 1                plasma  Indiana   1.68                80_INR -TOP_1.68
# 2                  None  Indiana  21.83  80_PROTHROMBIN TIME -TOP_21.83
# 3                  None  Indiana  13.77                    80_HGB_13.77
# 4                  None  Indiana  10.68                    80_Mpv_10.68
# ...                 ...      ...    ...                             ...
# 3465932            None  Wyoming   1.67       88_zALPHA-1 GLOBULIN_1.67
# 3465933            None  Wyoming  34.31          88_zALBUMIN (EP)_34.31
# 3465934            None  Wyoming     NO                  88_zM-SPIKE_NO
# 3465935            None  Wyoming  10.27        88_zGAMMA GLOBULIN_10.27
# 3465936            None  Wyoming  13.78      88_zALPHA-2 GLOBULIN_13.78
#
# [3314277 rows x 13 columns]

# %%
lab_train_data["Lab_test_description_Result"].values[0] # checking the one row
# Out:
# '80_Alpha Fetoprotein_3.0'

# %% [markdown]
# # Dropping all unnecessary columns

# %%
# Remove columns 
lab_train_data.drop(["Age at lab test","Lab test date","Lab test","Lab test description","Result numeric","Result textual",
                     "Result range","Result units","Specimen source","State","Result"], axis=1,inplace=True)

# %%
lab_train_data = lab_train_data

# %%
lab_train_data # After removing the unwanted column
# Out:
#          Internalpatientid     Lab_test_description_Result
# 0                        1        80_Alpha Fetoprotein_3.0
# 1                        1                80_INR -TOP_1.68
# 2                        1  80_PROTHROMBIN TIME -TOP_21.83
# 3                        1                    80_HGB_13.77
# 4                        1                    80_Mpv_10.68
# ...                    ...                             ...
# 3465932             169064       88_zALPHA-1 GLOBULIN_1.67
# 3465933             169064          88_zALBUMIN (EP)_34.31
# 3465934             169064                  88_zM-SPIKE_NO
# 3465935             169064        88_zGAMMA GLOBULIN_10.27
# 3465936             169064      88_zALPHA-2 GLOBULIN_13.78
#
# [3314277 rows x 2 columns]

# %%
# Group the DataFrame by 'Internalpatientid' and concatenate the icd10 values and
#The purpose of `x.dropna()` is to remove any missing values from the Series before applying a subsequent operation,
# such as concatenation using the `join` function. By dropping the missing values,
#we ensure that only non-null values are included in the resulting concatenated string.
df_grouped = lab_train_data.groupby('Internalpatientid').agg(lambda x: ','.join(x.dropna()))
df_grouped 

# Reset the index of the grouped DataFrame
df_grouped_lab = df_grouped.reset_index()
df_grouped_lab
# Out:
#         Internalpatientid                        Lab_test_description_Result
# 0                       1  80_Alpha Fetoprotein_3.0,80_INR -TOP_1.68,80_P...
# 1                       2  70_GLOBULIN, CALC._3.0,70_OSMOLALITY, CALC._30...
# 2                       3                       82_WHOLE BLOOD GLUCOSE_123.0
# 3                       4  84_MRSA SURVL NARES AGAR_NEGATIVE,84_ANCILLARY...
# 4                       5  77_PROTEIN, TOTAL_5.13,77_eGFR_49.0,77_POTASSI...
# ...                   ...                                                ...
# 128833             169057  86_POTASSIUM_3.77,86_UREA NITROGEN_32.0,86_SOD...
# 128834             169060  72_BILIRUBIN, DIRECT_0.7,72_SGPT_13.0,72_SODIU...
# 128835             169062  74_URINE WBC/HPF_36.0,74_URINE BLOOD_TR,74_URI...
# 128836             169063  76_PLT (V2)_140.0,76_HGB (V2)_10.31,76_MPV (V2...
# 128837             169064  88_zBETA GLOBULIN_39.0,88_PROTEIN,TOTAL(SENDOU...
#
# [128838 rows x 2 columns]

# %%
df_grouped_lab[df_grouped_lab["Internalpatientid"]==1]
# Out:
#    Internalpatientid                        Lab_test_description_Result
# 0                  1  80_Alpha Fetoprotein_3.0,80_INR -TOP_1.68,80_P...

# %%
df_grouped_lab["Lab_test_description_Result"].values[128837] # checking the one row
# Out:
# '88_zBETA GLOBULIN_39.0,88_PROTEIN,TOTAL(SENDOUT)_225.25,88_zALPHA-1 GLOBULIN_1.67,88_zALBUMIN (EP)_34.31,88_zM-SPIKE_NO,88_zGAMMA GLOBULIN_10.27,88_zALPHA-2 GLOBULIN_13.78'

# %% [markdown]
# # Saving the CSV file

# %%
# saving the csv file 

#df.to_csv('Path where you want to store the exported CSV file/File Name.csv')
df_grouped_lab.to_csv('/mnt/batch/tasks/shared/LS_root/mounts/clusters/team-3-susai-gpu2/code/Users/900379/Output_files_train/df_lab_results_train_with_age_v1.csv')

# %%
import os
cwd = os.getcwd()
cwd
# Out:
# '/mnt/batch/tasks/shared/LS_root/mounts/clusters/team-3-susai-gpu2/code/Users/2211575'

# %%
# df1 = pd.read_csv('/mnt/batch/tasks/shared/LS_root/mounts/clusters/team-3-susai-gpu2/code/Users/900379/Output_files_train/df_lab_results_train.csv')
