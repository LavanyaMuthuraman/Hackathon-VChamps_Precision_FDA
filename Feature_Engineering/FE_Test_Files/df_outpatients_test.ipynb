# %%
#A class attribute that provides access to the TabularDatasetFactory methods for creating new TabularDataset objects. 
#Usage: Dataset.Tabular.from_delimited_files().
from azureml.core import Workspace, Dataset

subscription_id = 'bcfe0c62-8ebe-4df0-a46d-1efcf8739a5b' #check the launch studio there will get this id
resource_group = 'VChamp-Team3' # resource group name
workspace_name = 'vchamp-team3' # worksapce name


# storage account : Algorithmia, Resource group: VChamp-Team3 and workspace: vchamp-team3.
#Constructor
workspace = Workspace(subscription_id, resource_group, workspace_name)

# %%
#['data_team3_synthetic_train']
datastore = workspace.datastores['data_team3_synthetic_test']

# %%
#from_delimited_files (Create a TabularDataset to represent tabular data in delimited files (e.g. CSV and TSV).

dataset = Dataset.Tabular.from_delimited_files(path = [(datastore, 'outpatient_visits_test.csv')])

# preview the first 3 rows of the dataset
# dataset.to_pandas_dataframe()

# %%
#Converting the dataset into data frame(default as dataset in Azure, thus we must convert the needed formate)
outpatient_test_data = dataset.to_pandas_dataframe()

# %%
outpatient_test_data
# Out:
#             Column1  Internalpatientid  Age at visit    Visit start date  \
# 0                93                100     52.560034 2014-04-19 16:37:04
# 1                94                100     52.898575 2014-08-21 10:17:59
# 2                95                100     53.184501 2014-12-03 22:26:25
# 3                96                100     54.002069 2015-09-28 18:09:01
# 4                97                100     54.337489 2016-01-29 08:27:08
# ...             ...                ...           ...                 ...
# 21906647  105227001              99997     86.874842 2016-01-06 18:07:06
# 21906648  105227002              99997     87.321281 2016-06-17 22:16:50
# 21906649  105227003              99997     88.378729 2017-07-09 10:12:41
# 21906650  105227004              99997     88.523673 2017-08-31 09:39:49
# 21906651  105227005              99997     89.902555 2019-01-17 09:12:40
#
#          First listed diagnosis icd10 subcategory  \
# 0                                   Not specified
# 1                                   Not specified
# 2                                   Not specified
# 3                                   Not specified
# 4                                   Not specified
# ...                                           ...
# 21906647                            Not specified
# 21906648                            Not specified
# 21906649            Bladder disorder, unspecified
# 21906650         Alzheimer's disease, unspecified
# 21906651                            Not specified
#
#          Second listed diagnosis icd10 subcategory  \
# 0                                    Not specified
# 1                                    Not specified
# 2                                    Not specified
# 3                                    Not specified
# 4                                    Not specified
# ...                                            ...
# 21906647                             Not specified
# 21906648                             Not specified
# 21906649                             Not specified
# 21906650                               Sleep apnea
# 21906651                             Not specified
#
#                                Stop code Agentorangeflag Combatflag  \
# 0                    RESPIRATORY THERAPY            None       None
# 1                 HBPC Nursing (RN / LP)            None       None
# 2         ADMIN PAT ACTIVTIES (MASNONCT)            None       None
# 3                   OCCUPATIONAL THERAPY            None       None
# 4                         TELEPHONE HBPC            None       None
# ...                                  ...             ...        ...
# 21906647           PRIMARY CARE/MEDICINE            None       None
# 21906648          TELEPHONE PRIMARY CARE            None       None
# 21906649               CLINICAL PHARMACY            None       None
# 21906650      MENTAL HEALTH CLINIC - IND            None       None
# 21906651        Not specified (no value)            None       None
#
#          Ionizingradiationflag Serviceconnectedflag Swasiaconditionsflag  \
# 0                         None                 True                 None
# 1                         None                 True                 None
# 2                         None                 None                 None
# 3                         None                 True                 None
# 4                         None                 True                 None
# ...                        ...                  ...                  ...
# 21906647                  None                 None                 None
# 21906648                  None                 None                 None
# 21906649                  None                 None                 None
# 21906650                  None                 None                 None
# 21906651                  None                 None                 None
#
#                    State
# 0               New York
# 1               New York
# 2               New York
# 3               New York
# 4               New York
# ...                  ...
# 21906647  North Carolina
# 21906648  North Carolina
# 21906649  North Carolina
# 21906650  North Carolina
# 21906651  North Carolina
#
# [21906652 rows x 13 columns]

# %%
import numpy as np                # Multi-Dimensional array object
import pandas as pd               # Data Manipulation
import matplotlib.pyplot as plt   # Data Visualization
import seaborn as sns             # Data Visualization 

# Allows the use of display() for DataFrames
from IPython.display import display 

# Handle warning messages that may occur during code execution
import warnings
warnings.filterwarnings('ignore')

# To increase memory allocation
from notebook.services.config import ConfigManager
cm = ConfigManager().update('notebook', {'max_buffer_size': 7294967296})

# %% [markdown]
# # Elimination of the unnamed columns

# %%
# Remove unwanted columns 
outpatient_test_data.drop('Column1',axis=1,inplace=True)

# %%
outpatient_test_data
# Out:
#           Internalpatientid  Age at visit    Visit start date  \
# 0                       100     52.560034 2014-04-19 16:37:04
# 1                       100     52.898575 2014-08-21 10:17:59
# 2                       100     53.184501 2014-12-03 22:26:25
# 3                       100     54.002069 2015-09-28 18:09:01
# 4                       100     54.337489 2016-01-29 08:27:08
# ...                     ...           ...                 ...
# 21906647              99997     86.874842 2016-01-06 18:07:06
# 21906648              99997     87.321281 2016-06-17 22:16:50
# 21906649              99997     88.378729 2017-07-09 10:12:41
# 21906650              99997     88.523673 2017-08-31 09:39:49
# 21906651              99997     89.902555 2019-01-17 09:12:40
#
#          First listed diagnosis icd10 subcategory  \
# 0                                   Not specified
# 1                                   Not specified
# 2                                   Not specified
# 3                                   Not specified
# 4                                   Not specified
# ...                                           ...
# 21906647                            Not specified
# 21906648                            Not specified
# 21906649            Bladder disorder, unspecified
# 21906650         Alzheimer's disease, unspecified
# 21906651                            Not specified
#
#          Second listed diagnosis icd10 subcategory  \
# 0                                    Not specified
# 1                                    Not specified
# 2                                    Not specified
# 3                                    Not specified
# 4                                    Not specified
# ...                                            ...
# 21906647                             Not specified
# 21906648                             Not specified
# 21906649                             Not specified
# 21906650                               Sleep apnea
# 21906651                             Not specified
#
#                                Stop code Agentorangeflag Combatflag  \
# 0                    RESPIRATORY THERAPY            None       None
# 1                 HBPC Nursing (RN / LP)            None       None
# 2         ADMIN PAT ACTIVTIES (MASNONCT)            None       None
# 3                   OCCUPATIONAL THERAPY            None       None
# 4                         TELEPHONE HBPC            None       None
# ...                                  ...             ...        ...
# 21906647           PRIMARY CARE/MEDICINE            None       None
# 21906648          TELEPHONE PRIMARY CARE            None       None
# 21906649               CLINICAL PHARMACY            None       None
# 21906650      MENTAL HEALTH CLINIC - IND            None       None
# 21906651        Not specified (no value)            None       None
#
#          Ionizingradiationflag Serviceconnectedflag Swasiaconditionsflag  \
# 0                         None                 True                 None
# 1                         None                 True                 None
# 2                         None                 None                 None
# 3                         None                 True                 None
# 4                         None                 True                 None
# ...                        ...                  ...                  ...
# 21906647                  None                 None                 None
# 21906648                  None                 None                 None
# 21906649                  None                 None                 None
# 21906650                  None                 None                 None
# 21906651                  None                 None                 None
#
#                    State
# 0               New York
# 1               New York
# 2               New York
# 3               New York
# 4               New York
# ...                  ...
# 21906647  North Carolina
# 21906648  North Carolina
# 21906649  North Carolina
# 21906650  North Carolina
# 21906651  North Carolina
#
# [21906652 rows x 12 columns]

# %% [markdown]
# # sorting out patients id and age column

# %%
# Sort the dataset based on the patientsid and 'age' column in ascending order
outpatient_test_data.sort_values(["Internalpatientid","Age at visit"],inplace=True)

# %%
outpatient_test_data
# Out:
#           Internalpatientid  Age at visit    Visit start date  \
# 19529781                  6     74.147397 2000-10-29 20:58:06
# 12754738                  6     74.228196 2000-11-28 09:43:53
# 19473351                  6     74.767093 2001-06-13 08:56:37
# 19510971                  6     74.767095 2001-06-13 08:57:38
# 19527214                  6     74.842250 2001-07-10 20:12:49
# ...                     ...           ...                 ...
# 7941106              169065     53.320187 2011-06-11 12:41:03
# 7947015              169065     53.320380 2011-06-11 14:22:18
# 7935580              169065     53.320650 2011-06-11 16:44:30
# 15972480             169065     53.323439 2011-06-12 17:12:37
# 15756596             169065     53.326285 2011-06-13 18:10:18
#
#          First listed diagnosis icd10 subcategory  \
# 19529781                            Not specified
# 12754738                            Not specified
# 19473351                            Not specified
# 19510971                            Not specified
# 19527214                            Not specified
# ...                                           ...
# 7941106                             Not specified
# 7947015                             Not specified
# 7935580                             Not specified
# 15972480                            Not specified
# 15756596                            Not specified
#
#          Second listed diagnosis icd10 subcategory  \
# 19529781                             Not specified
# 12754738                             Not specified
# 19473351                             Not specified
# 19510971                             Not specified
# 19527214                             Not specified
# ...                                            ...
# 7941106                              Not specified
# 7947015                              Not specified
# 7935580                              Not specified
# 15972480                             Not specified
# 15756596                             Not specified
#
#                                Stop code Agentorangeflag Combatflag  \
# 19529781        Not specified (no value)            None       None
# 12754738        Not specified (no value)            None       None
# 19473351             ADMITTING/SCREENING            None       None
# 19510971             ADMITTING/SCREENING            None       None
# 19527214                      LABORATORY            None       None
# ...                                  ...             ...        ...
# 7941106                   WARD STOP CODE            None       None
# 7947015                   UROLOGY CLINIC            None       None
# 7935580    CHAPLAIN SERVICE - INDIVIDUAL            None       None
# 15972480   CHAPLAIN SERVICE - INDIVIDUAL            None       None
# 15756596  ADMIN PAT ACTIVTIES (MASNONCT)            None       None
#
#          Ionizingradiationflag Serviceconnectedflag Swasiaconditionsflag  \
# 19529781                  None                 None                 None
# 12754738                  None                 None                 None
# 19473351                  None                 None                 None
# 19510971                  None                 None                 None
# 19527214                  None                 None                 None
# ...                        ...                  ...                  ...
# 7941106                   None                 None                 None
# 7947015                   None                False                 None
# 7935580                   None                 True                 None
# 15972480                  None                 None                 None
# 15756596                  None                 None                 None
#
#             State
# 19529781    Texas
# 12754738    Texas
# 19473351    Texas
# 19510971    Texas
# 19527214    Texas
# ...           ...
# 7941106   Arizona
# 7947015   Arizona
# 7935580   Arizona
# 15972480  Arizona
# 15756596  Arizona
#
# [21906652 rows x 12 columns]

# %% [markdown]
# # checking the missing valuses

# %%
print("set missing values:\n", outpatient_test_data.isna().sum())
# Out:
# set missing values:
#  Internalpatientid                                   0
# Age at visit                                        0
# Visit start date                                    0
# First listed diagnosis icd10 subcategory            0
# Second listed diagnosis icd10 subcategory           0
# Stop code                                           0
# Agentorangeflag                              21100085
# Combatflag                                   21875423
# Ionizingradiationflag                        21878519
# Serviceconnectedflag                         16911701
# Swasiaconditionsflag                         21836167
# State                                               0
# dtype: int64

# %%
# Remove the rows where both columns contain "Not Specified"

outpatient_test_data = outpatient_test_data.drop(outpatient_test_data[(outpatient_test_data['First listed diagnosis icd10 subcategory'] == 'Not specified') & (outpatient_test_data['Second listed diagnosis icd10 subcategory'] == 'Not specified')].index)

# %%
outpatient_test_data.Internalpatientid.nunique()
# Out:
# 18117

# %% [markdown]
# # Taking the digit in age coulmn

# %%
# Format 'Age at measurement' values in the format 00.00
outpatient_test_data["Age at visit"] = outpatient_test_data["Age at visit"].map("{:.2f}".format)

# %%
outpatient_test_data
# Out:
#           Internalpatientid Age at visit    Visit start date  \
# 20042738                  7        67.69 2014-03-16 01:53:21
# 13850759                  7        67.71 2014-03-23 08:46:01
# 20101814                  7        67.71 2014-03-23 23:33:03
# 13842251                  7        67.71 2014-03-24 01:44:26
# 20042740                  7        67.71 2014-03-25 00:19:11
# ...                     ...          ...                 ...
# 15969115             169045        97.00 2021-03-16 15:28:27
# 7944375              169045        97.27 2021-06-23 22:06:41
# 15663762             169045        97.29 2021-06-30 00:50:22
# 7922508              169045        97.36 2021-07-25 21:32:52
# 7952221              169045        97.80 2022-01-03 09:34:48
#
#                    First listed diagnosis icd10 subcategory  \
# 20042738              Post-traumatic stress disorder (PTSD)
# 13850759             Other long term (current) drug therapy
# 20101814            Encounter for other specified aftercare
# 13842251             Other long term (current) drug therapy
# 20042740             Other long term (current) drug therapy
# ...                                                     ...
# 15969115                Other specified cardiac arrhythmias
# 7944375       Encounter for examination of ears and hearing
# 15663762                         Encounter for immunization
# 7922508                          Encounter for immunization
# 7952221   Encounter for fitting and adjustment of hearin...
#
#                   Second listed diagnosis icd10 subcategory  \
# 20042738                                      Not specified
# 13850759       Other and unspecified intestinal obstruction
# 20101814             Other long term (current) drug therapy
# 13842251  Long term (current) use of anticoagulants and ...
# 20042740                                      Not specified
# ...                                                     ...
# 15969115      Hypertensive heart disease with heart failure
# 7944375               Sensorineural hearing loss, bilateral
# 15663762                                      Not specified
# 7922508                                       Not specified
# 7952221                                            Tinnitus
#
#                               Stop code Agentorangeflag Combatflag  \
# 20042738  PCT-POST TRAUMATIC STRESS-GRP            None       None
# 13850759              CLINICAL PHARMACY            None       None
# 20101814              CLINICAL PHARMACY             Yes       None
# 13842251              CLINICAL PHARMACY            None       None
# 20042740              CLINICAL PHARMACY             Yes       None
# ...                                 ...             ...        ...
# 15969115          PRIMARY CARE/MEDICINE            None       None
# 7944375                       AUDIOLOGY            None       None
# 15663762      GENERAL INTERNAL MEDICINE            None       None
# 7922508       GENERAL INTERNAL MEDICINE            None       None
# 7952221                       AUDIOLOGY            None       None
#
#          Ionizingradiationflag Serviceconnectedflag Swasiaconditionsflag  \
# 20042738                  None                 True                 None
# 13850759                  None                 True                 None
# 20101814                  None                False                 None
# 13842251                  None                 None                 None
# 20042740                  None                False                 None
# ...                        ...                  ...                  ...
# 15969115                  None                False                 None
# 7944375                   None                 True                 None
# 15663762                  None                False                 None
# 7922508                   None                False                 None
# 7952221                   None                 True                 None
#
#               State
# 20042738   Nebraska
# 13850759   Nebraska
# 20101814   Nebraska
# 13842251   Nebraska
# 20042740   Nebraska
# ...             ...
# 15969115  Minnesota
# 7944375   Minnesota
# 15663762  Minnesota
# 7922508   Minnesota
# 7952221   Minnesota
#
# [3234728 rows x 12 columns]

# %%
# Convert 'Age' column from object to float
outpatient_test_data["Age at visit"] = outpatient_test_data["Age at visit"].astype(float)

# %% [markdown]
# # Max age

# %%
# Find the maximum age for each internal patient id
max_ages = outpatient_test_data.groupby('Internalpatientid')['Age at visit'].max().reset_index()

# Merge with the original dataframe to get the rows with the highest age
outpatient_test_data = pd.merge(outpatient_test_data, max_ages, on =['Internalpatientid','Age at visit'], how = 'inner')

outpatient_test_data
# Out:
#        Internalpatientid  Age at visit    Visit start date  \
# 0                      7         74.37 2020-11-22 12:50:02
# 1                     25         70.12 2023-12-22 18:01:07
# 2                     31         69.05 2016-10-17 14:46:09
# 3                     41         63.94 2017-06-30 04:07:34
# 4                     41         63.94 2017-06-30 05:36:26
# ...                  ...           ...                 ...
# 29729             169037         87.74 2017-10-24 17:05:33
# 29730             169037         87.74 2017-10-24 20:00:40
# 29731             169037         87.74 2017-10-25 16:09:22
# 29732             169037         87.74 2017-10-25 16:33:01
# 29733             169045         97.80 2022-01-03 09:34:48
#
#                 First listed diagnosis icd10 subcategory  \
# 0                        Dental caries on smooth surface
# 1                Encounter for other specified aftercare
# 2                                Counseling, unspecified
# 3         Malignant neoplasm of lower third of esophagus
# 4                                Counseling, unspecified
# ...                                                  ...
# 29729  Chronic obstructive pulmonary disease with (ac...
# 29730  Other specified problems related to psychosoci...
# 29731    Dementia in other diseases classified elsewhere
# 29732                      Encounter for palliative care
# 29733  Encounter for fitting and adjustment of hearin...
#
#                Second listed diagnosis icd10 subcategory  \
# 0                                          Not specified
# 1      Unspecified atrial fibrillation and atrial flu...
# 2                                          Not specified
# 3      Secondary malignant neoplasm of liver and intr...
# 4                                          Not specified
# ...                                                  ...
# 29729                                      Not specified
# 29730                      Encounter for palliative care
# 29731                      Encounter for palliative care
# 29732    Dementia in other diseases classified elsewhere
# 29733                                           Tinnitus
#
#                     Stop code Agentorangeflag Combatflag  \
# 0                      DENTAL              No       None
# 1         TELEPHONE/ANCILLARY            None       None
# 2      TELEPHONE PRIMARY CARE            None       None
# 3              ONCOLOGY/TUMOR            None       None
# 4         SOCIAL WORK SERVICE            None       None
# ...                       ...             ...        ...
# 29729          TELEPHONE HBPC            None       None
# 29730    TELEPHONE/GERIATRICS            None       None
# 29731            HOSPICE CARE            None       None
# 29732    TELEPHONE/GERIATRICS            None       None
# 29733               AUDIOLOGY            None       None
#
#       Ionizingradiationflag Serviceconnectedflag Swasiaconditionsflag  \
# 0                      None                False                 None
# 1                      None                False                 None
# 2                      None                False                 None
# 3                      None                 None                 None
# 4                      None                 None                 None
# ...                     ...                  ...                  ...
# 29729                  None                 None                 None
# 29730                  None                 None                 None
# 29731                  None                 None                 None
# 29732                  None                 None                 None
# 29733                  None                 True                 None
#
#               State
# 0          Nebraska
# 1      Pennsylvania
# 2       Mississippi
# 3          Missouri
# 4          Missouri
# ...             ...
# 29729      Illinois
# 29730      Illinois
# 29731      Illinois
# 29732      Illinois
# 29733     Minnesota
#
# [29734 rows x 12 columns]

# %% [markdown]
# # Rounding off the Age

# %%
outpatient_test_data['Age at visit'] = outpatient_test_data['Age at visit'].apply(lambda x: round(x,))

# %%
outpatient_test_data.Internalpatientid.nunique()
# Out:
# 18117

# %%
df = outpatient_test_data["Internalpatientid"].value_counts().loc[lambda x: x>25].to_frame()

# %%
df = df.reset_index()

# %%
df.columns = ["Internalpatientid","count_outpatients"]

# %%
len(df)
# Out:
# 16

# %%
df.drop(["count_outpatients"],axis=1,inplace =True)

# %%
df
# Out:
#     Internalpatientid
# 0              101451
# 1              127264
# 2              113669
# 3               95558
# 4               85653
# 5              160044
# 6              140996
# 7              103630
# 8               27822
# 9                9741
# 10             153621
# 11               1978
# 12              45737
# 13              37934
# 14              33315
# 15             152635

# %%
# Merge the two dataframes based on 'Internalpatientid'
merged_df = outpatient_test_data.merge(df, on='Internalpatientid', how='left')

# Filter rows from DataFrame 1 that have matching values in DataFrame 2
filtered_df = merged_df[~merged_df['Internalpatientid'].isin(df['Internalpatientid'])]

# Print only the columns of DataFrame 1
filtered_df
# Out:
#        Internalpatientid  Age at visit    Visit start date  \
# 0                      7            74 2020-11-22 12:50:02
# 1                     25            70 2023-12-22 18:01:07
# 2                     31            69 2016-10-17 14:46:09
# 3                     41            64 2017-06-30 04:07:34
# 4                     41            64 2017-06-30 05:36:26
# ...                  ...           ...                 ...
# 29729             169037            88 2017-10-24 17:05:33
# 29730             169037            88 2017-10-24 20:00:40
# 29731             169037            88 2017-10-25 16:09:22
# 29732             169037            88 2017-10-25 16:33:01
# 29733             169045            98 2022-01-03 09:34:48
#
#                 First listed diagnosis icd10 subcategory  \
# 0                        Dental caries on smooth surface
# 1                Encounter for other specified aftercare
# 2                                Counseling, unspecified
# 3         Malignant neoplasm of lower third of esophagus
# 4                                Counseling, unspecified
# ...                                                  ...
# 29729  Chronic obstructive pulmonary disease with (ac...
# 29730  Other specified problems related to psychosoci...
# 29731    Dementia in other diseases classified elsewhere
# 29732                      Encounter for palliative care
# 29733  Encounter for fitting and adjustment of hearin...
#
#                Second listed diagnosis icd10 subcategory  \
# 0                                          Not specified
# 1      Unspecified atrial fibrillation and atrial flu...
# 2                                          Not specified
# 3      Secondary malignant neoplasm of liver and intr...
# 4                                          Not specified
# ...                                                  ...
# 29729                                      Not specified
# 29730                      Encounter for palliative care
# 29731                      Encounter for palliative care
# 29732    Dementia in other diseases classified elsewhere
# 29733                                           Tinnitus
#
#                     Stop code Agentorangeflag Combatflag  \
# 0                      DENTAL              No       None
# 1         TELEPHONE/ANCILLARY            None       None
# 2      TELEPHONE PRIMARY CARE            None       None
# 3              ONCOLOGY/TUMOR            None       None
# 4         SOCIAL WORK SERVICE            None       None
# ...                       ...             ...        ...
# 29729          TELEPHONE HBPC            None       None
# 29730    TELEPHONE/GERIATRICS            None       None
# 29731            HOSPICE CARE            None       None
# 29732    TELEPHONE/GERIATRICS            None       None
# 29733               AUDIOLOGY            None       None
#
#       Ionizingradiationflag Serviceconnectedflag Swasiaconditionsflag  \
# 0                      None                False                 None
# 1                      None                False                 None
# 2                      None                False                 None
# 3                      None                 None                 None
# 4                      None                 None                 None
# ...                     ...                  ...                  ...
# 29729                  None                 None                 None
# 29730                  None                 None                 None
# 29731                  None                 None                 None
# 29732                  None                 None                 None
# 29733                  None                 True                 None
#
#               State
# 0          Nebraska
# 1      Pennsylvania
# 2       Mississippi
# 3          Missouri
# 4          Missouri
# ...             ...
# 29729      Illinois
# 29730      Illinois
# 29731      Illinois
# 29732      Illinois
# 29733     Minnesota
#
# [29276 rows x 12 columns]

# %%
filtered_df.Internalpatientid.nunique()
# Out:
# 18101

# %%
outpatient_test_data = filtered_df  # Assinging new varible

# %% [markdown]
# # Adding  'Age at visit' & 'First listed diagnosis icd10 subcategory' columns with '_'

# %%
#In this code, we create a new column called 'Lab test description_Result numeric' by concatenating the values of the 'lab test description' column, underscore ('_'), and the 'lab test results' column
#converted to a string using the `astype(str)` function(because we cant't add differnt dtype)
outpatient_test_data['outpatients_First_listed_diagnosis_icd10_subcategory'] =  outpatient_test_data['Age at visit'].astype(str) + '_' +  outpatient_test_data['First listed diagnosis icd10 subcategory']

# %% [markdown]
# # Adding  'Age at visit' & 'Second listed diagnosis icd10 subcategory' columns with '_'

# %%
#In this code, we create a new column called 'Lab test description_Result numeric' by concatenating the values of the 'lab test description' column, underscore ('_'), and the 'lab test results' column
#converted to a string using the `astype(str)` function(because we cant't add differnt dtype)
outpatient_test_data['outpatients_Second_listed_diagnosis_icd10_subcategory'] =  outpatient_test_data['Age at visit'].astype(str) + '_' +  outpatient_test_data['Second listed diagnosis icd10 subcategory']

# %% [markdown]
# # Dropping all unnecessary columns

# %%
# Remove columns 
outpatient_test_data.drop(['Age at visit','Visit start date','First listed diagnosis icd10 subcategory','Second listed diagnosis icd10 subcategory',
                            'Stop code','Agentorangeflag','Combatflag','Ionizingradiationflag','Serviceconnectedflag','Swasiaconditionsflag','State'], axis=1,inplace=True)

# %%
outpatient_test_data = outpatient_test_data

# %%
outpatient_test_data
# Out:
#        Internalpatientid outpatients_First_listed_diagnosis_icd10_subcategory  \
# 0                      7                 74_Dental caries on smooth surface
# 1                     25         70_Encounter for other specified aftercare
# 2                     31                         69_Counseling, unspecified
# 3                     41  64_Malignant neoplasm of lower third of esophagus
# 4                     41                         64_Counseling, unspecified
# ...                  ...                                                ...
# 29729             169037  88_Chronic obstructive pulmonary disease with ...
# 29730             169037  88_Other specified problems related to psychos...
# 29731             169037  88_Dementia in other diseases classified elsew...
# 29732             169037                   88_Encounter for palliative care
# 29733             169045  98_Encounter for fitting and adjustment of hea...
#
#       outpatients_Second_listed_diagnosis_icd10_subcategory
# 0                                       74_Not specified
# 1      70_Unspecified atrial fibrillation and atrial ...
# 2                                       69_Not specified
# 3      64_Secondary malignant neoplasm of liver and i...
# 4                                       64_Not specified
# ...                                                  ...
# 29729                                   88_Not specified
# 29730                   88_Encounter for palliative care
# 29731                   88_Encounter for palliative care
# 29732  88_Dementia in other diseases classified elsew...
# 29733                                        98_Tinnitus
#
# [29276 rows x 3 columns]

# %%
# Group the DataFrame by 'Internalpatientid' and concatenate the icd10 values and
#The purpose of `x.dropna()` is to remove any missing values from the Series before applying a subsequent operation,
# such as concatenation using the `join` function. By dropping the missing values,
#we ensure that only non-null values are included in the resulting concatenated string.
df_grouped = outpatient_test_data.groupby('Internalpatientid').agg(lambda x: ','.join(x.dropna()))
df_grouped 

# Reset the index of the grouped DataFrame
df_grouped_outpatients = df_grouped.reset_index()
df_grouped_outpatients
# Out:
#        Internalpatientid outpatients_First_listed_diagnosis_icd10_subcategory  \
# 0                      7                 74_Dental caries on smooth surface
# 1                     25         70_Encounter for other specified aftercare
# 2                     31                         69_Counseling, unspecified
# 3                     41  64_Malignant neoplasm of lower third of esopha...
# 4                     42  68_Encounter for screening for cardiovascular ...
# ...                  ...                                                ...
# 18096             169000  80_Person consulting for explanation of examin...
# 18097             169011                      75_Heart failure, unspecified
# 18098             169020                                        64_COVID-19
# 18099             169037  88_Other forms of chronic ischemic heart disea...
# 18100             169045  98_Encounter for fitting and adjustment of hea...
#
#       outpatients_Second_listed_diagnosis_icd10_subcategory
# 0                                       74_Not specified
# 1      70_Unspecified atrial fibrillation and atrial ...
# 2                                       69_Not specified
# 3      64_Secondary malignant neoplasm of liver and i...
# 4      68_Not specified,68_Not specified,68_Encounter...
# ...                                                  ...
# 18096                                   80_Not specified
# 18097  75_Atherosclerotic heart disease of native cor...
# 18098                                   64_Not specified
# 18099  88_Chronic obstructive pulmonary disease, unsp...
# 18100                                        98_Tinnitus
#
# [18101 rows x 3 columns]

# %% [markdown]
# # Saving the CSV file

# %%
df_grouped_outpatients.to_csv('/mnt/batch/tasks/shared/LS_root/mounts/clusters/team-3-susai-gpu2/code/Users/900379/Output_files_test/df_outpatients_test.csv')

# %%
df_grouped_outpatients['outpatients_First_listed_diagnosis_icd10_subcategory'].values[1]
# Out:
# '69_Encounter for screening for other specified diseases and disorders,69_Encounter for screening for other specified diseases and disorders'

# %%
import os
cwd = os.getcwd()
cwd
# Out:
# '/mnt/batch/tasks/shared/LS_root/mounts/clusters/team-3-susai-gpu2/code/Users/2211575'
