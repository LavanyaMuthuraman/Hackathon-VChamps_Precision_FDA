# %% [markdown]
# # **Azure notebook Setup**

# %%
#A class attribute that provides access to the TabularDatasetFactory methods for creating new TabularDataset objects. 
#Usage: Dataset.Tabular.from_delimited_files().
from azureml.core import Workspace, Dataset

subscription_id = 'bcfe0c62-8ebe-4df0-a46d-1efcf8739a5b' #check the launch studio there will get this id
resource_group = 'VChamp-Team3' # resource group name
workspace_name = 'vchamp-team3' # worksapce name


# storage account : Algorithmia, Resource group: VChamp-Team3 and workspace: vchamp-team3.
#Constructor
workspace = Workspace(subscription_id, resource_group, workspace_name)

# %%
#['data_team3_synthetic_train']
datastore = workspace.datastores['data_team3_synthetic_test']

# %%
#from_delimited_files (Create a TabularDataset to represent tabular data in delimited files (e.g. CSV and TSV).

dataset = Dataset.Tabular.from_delimited_files(path = [(datastore, 'procedures_test.csv')])

# preview the first 3 rows of the dataset
# dataset.to_pandas_dataframe()

# %%
#Converting the dataset into data frame(default as dataset in Azure, thus we must convert the needed formate)
procedures_test_data = dataset.to_pandas_dataframe()

# %%
procedures_test_data
# Out:
#             Column1  Internalpatientid  Age at procedure      Procedure date  \
# 0               112                100         52.559428 2014-04-19 11:18:05
# 1               113                100         52.559428 2014-04-19 11:18:05
# 2               114                100         52.753358 2014-06-29 08:27:24
# 3               115                100         52.753358 2014-06-29 08:27:24
# 4               116                100         53.094739 2014-11-01 03:03:17
# ...             ...                ...               ...                 ...
# 27185595  130980476              99997         91.227044 2020-05-15 11:37:59
# 27185596  130980477              99997         91.227044 2020-05-15 11:37:59
# 27185597  130980478              99997         91.227044 2020-05-15 11:37:59
# 27185598  130980479              99997         91.227044 2020-05-15 11:37:59
# 27185599  130980480              99997         91.227044 2020-05-15 11:37:59
#
#          Procedure code                         Procedure code description  \
# 0                 99343  HOME VISIT FOR THE EVALUATION AND MANAGEMENT O...
# 1                 G0154  DIRECT SKILLED NURSING SERVICES OF A LICENSED ...
# 2                 97003                    OCCUPATIONAL THERAPY EVALUATION
# 3                 97535  SELF-CARE/HOME MANAGEMENT TRAINING (EG, ACTIVI...
# 4                 G0155  SERVICES OF CLINICAL SOCIAL WORKER IN HOME HEA...
# ...                 ...                                                ...
# 27185595          81001  URINALYSIS, BY DIP STICK OR TABLET REAGENT FOR...
# 27185596          82728                                           FERRITIN
# 27185597          85025  BLOOD COUNT; COMPLETE (CBC), AUTOMATED (HGB, H...
# 27185598          82746                                  FOLIC ACID; SERUM
# 27185599          84156     PROTEIN, TOTAL, EXCEPT BY REFRACTOMETRY; URINE
#
#                    State
# 0               New York
# 1               New York
# 2               New York
# 3               New York
# 4               New York
# ...                  ...
# 27185595  North Carolina
# 27185596  North Carolina
# 27185597  North Carolina
# 27185598  North Carolina
# 27185599  North Carolina
#
# [27185600 rows x 7 columns]

# %% [markdown]
# # Importing the necessary library

# %%
import numpy as np                # Multi-Dimensional array object
import pandas as pd               # Data Manipulation
import matplotlib.pyplot as plt   # Data Visualization
import seaborn as sns             # Data Visualization 

# Allows the use of display() for DataFrames
from IPython.display import display 

# Handle warning messages that may occur during code execution
import warnings
warnings.filterwarnings('ignore')

# To increase memory allocation
from notebook.services.config import ConfigManager
cm = ConfigManager().update('notebook', {'max_buffer_size': 7294967296})


# Set the maximum number of rows to be displayed to 1000
pd.set_option('display.max_rows', 1163)

# %% [markdown]
# # Elimination of the unnamed columns

# %%
# Remove unwanted columns 
procedures_test_data.drop('Column1',axis=1,inplace=True)

# %%
df_procedures = procedures_test_data

# %%
df_procedures
# Out:
#           Internalpatientid  Age at procedure      Procedure date  \
# 0                       100         52.559428 2014-04-19 11:18:05
# 1                       100         52.559428 2014-04-19 11:18:05
# 2                       100         52.753358 2014-06-29 08:27:24
# 3                       100         52.753358 2014-06-29 08:27:24
# 4                       100         53.094739 2014-11-01 03:03:17
# ...                     ...               ...                 ...
# 27185595              99997         91.227044 2020-05-15 11:37:59
# 27185596              99997         91.227044 2020-05-15 11:37:59
# 27185597              99997         91.227044 2020-05-15 11:37:59
# 27185598              99997         91.227044 2020-05-15 11:37:59
# 27185599              99997         91.227044 2020-05-15 11:37:59
#
#          Procedure code                         Procedure code description  \
# 0                 99343  HOME VISIT FOR THE EVALUATION AND MANAGEMENT O...
# 1                 G0154  DIRECT SKILLED NURSING SERVICES OF A LICENSED ...
# 2                 97003                    OCCUPATIONAL THERAPY EVALUATION
# 3                 97535  SELF-CARE/HOME MANAGEMENT TRAINING (EG, ACTIVI...
# 4                 G0155  SERVICES OF CLINICAL SOCIAL WORKER IN HOME HEA...
# ...                 ...                                                ...
# 27185595          81001  URINALYSIS, BY DIP STICK OR TABLET REAGENT FOR...
# 27185596          82728                                           FERRITIN
# 27185597          85025  BLOOD COUNT; COMPLETE (CBC), AUTOMATED (HGB, H...
# 27185598          82746                                  FOLIC ACID; SERUM
# 27185599          84156     PROTEIN, TOTAL, EXCEPT BY REFRACTOMETRY; URINE
#
#                    State
# 0               New York
# 1               New York
# 2               New York
# 3               New York
# 4               New York
# ...                  ...
# 27185595  North Carolina
# 27185596  North Carolina
# 27185597  North Carolina
# 27185598  North Carolina
# 27185599  North Carolina
#
# [27185600 rows x 6 columns]

# %% [markdown]
# # sorting out patients id and age column

# %%
# Sort the dataset based on the patientsid and 'age' column in ascending order
df_procedures.sort_values(["Internalpatientid","Age at procedure"],inplace=True)

# %%
df_procedures
# Out:
#           Internalpatientid  Age at procedure      Procedure date  \
# 17952646                  6         74.147397 2000-10-29 20:58:06
# 17914335                  6         74.228196 2000-11-28 09:43:53
# 25708445                  6         74.767093 2001-06-13 08:56:37
# 18044415                  6         74.767095 2001-06-13 08:57:38
# 17979814                  6         74.842250 2001-07-10 20:12:49
# ...                     ...               ...                 ...
# 11197211             169065         53.316365 2011-06-10 03:09:03
# 11197212             169065         53.316936 2011-06-10 08:09:33
# 11195318             169065         53.320380 2011-06-11 14:22:18
# 11195319             169065         53.320380 2011-06-11 14:22:18
# 11192059             169065         53.320650 2011-06-11 16:44:30
#
#          Procedure code                         Procedure code description  \
# 17952646          90718  TETANUS AND DIPHTHERIA TOXOIDS (TD) ADSORBED W...
# 17914335          90718  TETANUS AND DIPHTHERIA TOXOIDS (TD) ADSORBED W...
# 25708445          99203  OFFICE OR OTHER OUTPATIENT VISIT FOR THE EVALU...
# 18044415          99203  OFFICE OR OTHER OUTPATIENT VISIT FOR THE EVALU...
# 17979814          85999      UNLISTED HEMATOLOGY AND COAGULATION PROCEDURE
# ...                 ...                                                ...
# 11197211          71010  RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW, FR...
# 11197212          71010  RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW, FR...
# 11195318          99499         UNLISTED EVALUATION AND MANAGEMENT SERVICE
# 11195319          99211  OFFICE OR OTHER OUTPATIENT VISIT FOR THE EVALU...
# 11192059          99499         UNLISTED EVALUATION AND MANAGEMENT SERVICE
#
#             State
# 17952646    Texas
# 17914335    Texas
# 25708445    Texas
# 18044415    Texas
# 17979814    Texas
# ...           ...
# 11197211  Arizona
# 11197212  Arizona
# 11195318  Arizona
# 11195319  Arizona
# 11192059  Arizona
#
# [27185600 rows x 6 columns]

# %% [markdown]
# # Checking the missing value

# %%
print("Training set missing values:\n", df_procedures.isna().sum())
# Out:
# Training set missing values:
#  Internalpatientid             0
# Age at procedure              0
# Procedure date                0
# Procedure code                0
# Procedure code description    0
# State                         0
# dtype: int64

# %% [markdown]
# * * **The "Procedure code" column has 4 missing values.**
#
# * **Note:Here potiential attributes is "Procedure code description" ahs no missing value**

# %% [markdown]
# # Taking digit in age coulmn

# %%
# Format 'Age at measurement' values in the format 00.0
df_procedures["Age at procedure"] = df_procedures["Age at procedure"].map("{:.2f}".format)

# %%
df_procedures
# Out:
#           Internalpatientid Age at procedure      Procedure date  \
# 17952646                  6            74.15 2000-10-29 20:58:06
# 17914335                  6            74.23 2000-11-28 09:43:53
# 25708445                  6            74.77 2001-06-13 08:56:37
# 18044415                  6            74.77 2001-06-13 08:57:38
# 17979814                  6            74.84 2001-07-10 20:12:49
# ...                     ...              ...                 ...
# 11197211             169065            53.32 2011-06-10 03:09:03
# 11197212             169065            53.32 2011-06-10 08:09:33
# 11195318             169065            53.32 2011-06-11 14:22:18
# 11195319             169065            53.32 2011-06-11 14:22:18
# 11192059             169065            53.32 2011-06-11 16:44:30
#
#          Procedure code                         Procedure code description  \
# 17952646          90718  TETANUS AND DIPHTHERIA TOXOIDS (TD) ADSORBED W...
# 17914335          90718  TETANUS AND DIPHTHERIA TOXOIDS (TD) ADSORBED W...
# 25708445          99203  OFFICE OR OTHER OUTPATIENT VISIT FOR THE EVALU...
# 18044415          99203  OFFICE OR OTHER OUTPATIENT VISIT FOR THE EVALU...
# 17979814          85999      UNLISTED HEMATOLOGY AND COAGULATION PROCEDURE
# ...                 ...                                                ...
# 11197211          71010  RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW, FR...
# 11197212          71010  RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW, FR...
# 11195318          99499         UNLISTED EVALUATION AND MANAGEMENT SERVICE
# 11195319          99211  OFFICE OR OTHER OUTPATIENT VISIT FOR THE EVALU...
# 11192059          99499         UNLISTED EVALUATION AND MANAGEMENT SERVICE
#
#             State
# 17952646    Texas
# 17914335    Texas
# 25708445    Texas
# 18044415    Texas
# 17979814    Texas
# ...           ...
# 11197211  Arizona
# 11197212  Arizona
# 11195318  Arizona
# 11195319  Arizona
# 11192059  Arizona
#
# [27185600 rows x 6 columns]

# %%
# Convert 'Age at measurement' column from object to float
df_procedures ["Age at procedure"] = df_procedures ["Age at procedure"].astype(float)

# %%
df_procedures
# Out:
#           Internalpatientid  Age at procedure      Procedure date  \
# 17952646                  6             74.15 2000-10-29 20:58:06
# 17914335                  6             74.23 2000-11-28 09:43:53
# 25708445                  6             74.77 2001-06-13 08:56:37
# 18044415                  6             74.77 2001-06-13 08:57:38
# 17979814                  6             74.84 2001-07-10 20:12:49
# ...                     ...               ...                 ...
# 11197211             169065             53.32 2011-06-10 03:09:03
# 11197212             169065             53.32 2011-06-10 08:09:33
# 11195318             169065             53.32 2011-06-11 14:22:18
# 11195319             169065             53.32 2011-06-11 14:22:18
# 11192059             169065             53.32 2011-06-11 16:44:30
#
#          Procedure code                         Procedure code description  \
# 17952646          90718  TETANUS AND DIPHTHERIA TOXOIDS (TD) ADSORBED W...
# 17914335          90718  TETANUS AND DIPHTHERIA TOXOIDS (TD) ADSORBED W...
# 25708445          99203  OFFICE OR OTHER OUTPATIENT VISIT FOR THE EVALU...
# 18044415          99203  OFFICE OR OTHER OUTPATIENT VISIT FOR THE EVALU...
# 17979814          85999      UNLISTED HEMATOLOGY AND COAGULATION PROCEDURE
# ...                 ...                                                ...
# 11197211          71010  RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW, FR...
# 11197212          71010  RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW, FR...
# 11195318          99499         UNLISTED EVALUATION AND MANAGEMENT SERVICE
# 11195319          99211  OFFICE OR OTHER OUTPATIENT VISIT FOR THE EVALU...
# 11192059          99499         UNLISTED EVALUATION AND MANAGEMENT SERVICE
#
#             State
# 17952646    Texas
# 17914335    Texas
# 25708445    Texas
# 18044415    Texas
# 17979814    Texas
# ...           ...
# 11197211  Arizona
# 11197212  Arizona
# 11195318  Arizona
# 11195319  Arizona
# 11192059  Arizona
#
# [27185600 rows x 6 columns]

# %% [markdown]
# # Max age

# %%
# Find the maximum age for each internal patient id
max_ages = df_procedures.groupby('Internalpatientid')['Age at procedure'].max().reset_index()

# Merge with the original dataframe to get the rows with the highest age
df_procedures = pd.merge(df_procedures, max_ages, on =['Internalpatientid','Age at procedure'], how = 'inner')

df_procedures
# Out:
#         Internalpatientid  Age at procedure      Procedure date  \
# 0                       6             88.10 2014-10-16 01:23:22
# 1                       7             74.37 2020-11-22 12:50:02
# 2                       7             74.37 2020-11-22 12:50:02
# 3                       9             51.88 2000-04-25 20:51:31
# 4                       9             51.88 2000-04-25 20:51:31
# ...                   ...               ...                 ...
# 130057             169065             53.32 2011-06-10 03:09:03
# 130058             169065             53.32 2011-06-10 08:09:33
# 130059             169065             53.32 2011-06-11 14:22:18
# 130060             169065             53.32 2011-06-11 14:22:18
# 130061             169065             53.32 2011-06-11 16:44:30
#
#        Procedure code                         Procedure code description  \
# 0               98966  TELEPHONE ASSESSMENT AND MANAGEMENT SERVICE PR...
# 1               D1206  TOPICAL FLUORIDE VARNISH; THERAPEUTIC APPLICAT...
# 2               D2331                       RESIN-TWO SURFACES, ANTERIOR
# 3               37.78  INSERTION OF TEMPORARY TRANSVENOUS PACEMAKER S...
# 4               96.05              OTHER INTUBATION OF RESPIRATORY TRACT
# ...               ...                                                ...
# 130057          71010  RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW, FR...
# 130058          71010  RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW, FR...
# 130059          99499         UNLISTED EVALUATION AND MANAGEMENT SERVICE
# 130060          99211  OFFICE OR OTHER OUTPATIENT VISIT FOR THE EVALU...
# 130061          99499         UNLISTED EVALUATION AND MANAGEMENT SERVICE
#
#            State
# 0          Texas
# 1       Nebraska
# 2       Nebraska
# 3          Texas
# 4          Texas
# ...          ...
# 130057   Arizona
# 130058   Arizona
# 130059   Arizona
# 130060   Arizona
# 130061   Arizona
#
# [130062 rows x 6 columns]

# %% [markdown]
# # Rounding off the Age

# %%
df_procedures ['Age at procedure'] = df_procedures['Age at procedure'].apply(lambda x: round(x,))

# %%
df_procedures["Internalpatientid"].nunique()
# Out:
# 34812

# %%
df_procedures
# Out:
#         Internalpatientid  Age at procedure      Procedure date  \
# 0                       6                88 2014-10-16 01:23:22
# 1                       7                74 2020-11-22 12:50:02
# 2                       7                74 2020-11-22 12:50:02
# 3                       9                52 2000-04-25 20:51:31
# 4                       9                52 2000-04-25 20:51:31
# ...                   ...               ...                 ...
# 130057             169065                53 2011-06-10 03:09:03
# 130058             169065                53 2011-06-10 08:09:33
# 130059             169065                53 2011-06-11 14:22:18
# 130060             169065                53 2011-06-11 14:22:18
# 130061             169065                53 2011-06-11 16:44:30
#
#        Procedure code                         Procedure code description  \
# 0               98966  TELEPHONE ASSESSMENT AND MANAGEMENT SERVICE PR...
# 1               D1206  TOPICAL FLUORIDE VARNISH; THERAPEUTIC APPLICAT...
# 2               D2331                       RESIN-TWO SURFACES, ANTERIOR
# 3               37.78  INSERTION OF TEMPORARY TRANSVENOUS PACEMAKER S...
# 4               96.05              OTHER INTUBATION OF RESPIRATORY TRACT
# ...               ...                                                ...
# 130057          71010  RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW, FR...
# 130058          71010  RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW, FR...
# 130059          99499         UNLISTED EVALUATION AND MANAGEMENT SERVICE
# 130060          99211  OFFICE OR OTHER OUTPATIENT VISIT FOR THE EVALU...
# 130061          99499         UNLISTED EVALUATION AND MANAGEMENT SERVICE
#
#            State
# 0          Texas
# 1       Nebraska
# 2       Nebraska
# 3          Texas
# 4          Texas
# ...          ...
# 130057   Arizona
# 130058   Arizona
# 130059   Arizona
# 130060   Arizona
# 130061   Arizona
#
# [130062 rows x 6 columns]

# %%
# value counts
df3 = df_procedures["Internalpatientid"].value_counts().loc[lambda x: x>30].to_frame()

# %%
df3 = df3.reset_index()

# %%
df3.columns = ["Internalpatientid","count_procedures"]

# %%
df3.drop(["count_procedures"],axis=1,inplace =True)

# %%
len(df3)
# Out:
# 340

# %%
# Merge the two dataframes based on 'Internalpatientid'
merged_df = df_procedures.merge(df3, on='Internalpatientid', how='left')

# Filter rows from DataFrame 1 that have matching values in DataFrame 2
filtered_df = merged_df[~merged_df['Internalpatientid'].isin(df3['Internalpatientid'])]

# Print only the columns of DataFrame 1
filtered_df
# Out:
#         Internalpatientid  Age at procedure      Procedure date  \
# 0                       6                88 2014-10-16 01:23:22
# 1                       7                74 2020-11-22 12:50:02
# 2                       7                74 2020-11-22 12:50:02
# 3                       9                52 2000-04-25 20:51:31
# 4                       9                52 2000-04-25 20:51:31
# ...                   ...               ...                 ...
# 130057             169065                53 2011-06-10 03:09:03
# 130058             169065                53 2011-06-10 08:09:33
# 130059             169065                53 2011-06-11 14:22:18
# 130060             169065                53 2011-06-11 14:22:18
# 130061             169065                53 2011-06-11 16:44:30
#
#        Procedure code                         Procedure code description  \
# 0               98966  TELEPHONE ASSESSMENT AND MANAGEMENT SERVICE PR...
# 1               D1206  TOPICAL FLUORIDE VARNISH; THERAPEUTIC APPLICAT...
# 2               D2331                       RESIN-TWO SURFACES, ANTERIOR
# 3               37.78  INSERTION OF TEMPORARY TRANSVENOUS PACEMAKER S...
# 4               96.05              OTHER INTUBATION OF RESPIRATORY TRACT
# ...               ...                                                ...
# 130057          71010  RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW, FR...
# 130058          71010  RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW, FR...
# 130059          99499         UNLISTED EVALUATION AND MANAGEMENT SERVICE
# 130060          99211  OFFICE OR OTHER OUTPATIENT VISIT FOR THE EVALU...
# 130061          99499         UNLISTED EVALUATION AND MANAGEMENT SERVICE
#
#            State
# 0          Texas
# 1       Nebraska
# 2       Nebraska
# 3          Texas
# 4          Texas
# ...          ...
# 130057   Arizona
# 130058   Arizona
# 130059   Arizona
# 130060   Arizona
# 130061   Arizona
#
# [115073 rows x 6 columns]

# %%
filtered_df.Internalpatientid.nunique()
# Out:
# 34472

# %%
df_procedures = filtered_df

# %%
df_procedures
# Out:
#         Internalpatientid  Age at procedure      Procedure date  \
# 0                       6                88 2014-10-16 01:23:22
# 1                       7                74 2020-11-22 12:50:02
# 2                       7                74 2020-11-22 12:50:02
# 3                       9                52 2000-04-25 20:51:31
# 4                       9                52 2000-04-25 20:51:31
# ...                   ...               ...                 ...
# 130057             169065                53 2011-06-10 03:09:03
# 130058             169065                53 2011-06-10 08:09:33
# 130059             169065                53 2011-06-11 14:22:18
# 130060             169065                53 2011-06-11 14:22:18
# 130061             169065                53 2011-06-11 16:44:30
#
#        Procedure code                         Procedure code description  \
# 0               98966  TELEPHONE ASSESSMENT AND MANAGEMENT SERVICE PR...
# 1               D1206  TOPICAL FLUORIDE VARNISH; THERAPEUTIC APPLICAT...
# 2               D2331                       RESIN-TWO SURFACES, ANTERIOR
# 3               37.78  INSERTION OF TEMPORARY TRANSVENOUS PACEMAKER S...
# 4               96.05              OTHER INTUBATION OF RESPIRATORY TRACT
# ...               ...                                                ...
# 130057          71010  RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW, FR...
# 130058          71010  RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW, FR...
# 130059          99499         UNLISTED EVALUATION AND MANAGEMENT SERVICE
# 130060          99211  OFFICE OR OTHER OUTPATIENT VISIT FOR THE EVALU...
# 130061          99499         UNLISTED EVALUATION AND MANAGEMENT SERVICE
#
#            State
# 0          Texas
# 1       Nebraska
# 2       Nebraska
# 3          Texas
# 4          Texas
# ...          ...
# 130057   Arizona
# 130058   Arizona
# 130059   Arizona
# 130060   Arizona
# 130061   Arizona
#
# [115073 rows x 6 columns]

# %% [markdown]
# # Adding  'Age at procedure' & 'Procedure code description' columns with '_'

# %%
#In this code, we create a new column called 'Lab test description_Result numeric' by concatenating the values of the 'lab test description' column, underscore ('_'), and the 'lab test results' column
#converted to a string using the `astype(str)` function(because we cant't add differnt dtype)
df_procedures['procedures_code_description'] = df_procedures['Age at procedure'].astype(str) + '_' +  df_procedures['Procedure code description']

# %%
df_procedures
# Out:
#         Internalpatientid  Age at procedure      Procedure date  \
# 0                       6                88 2014-10-16 01:23:22
# 1                       7                74 2020-11-22 12:50:02
# 2                       7                74 2020-11-22 12:50:02
# 3                       9                52 2000-04-25 20:51:31
# 4                       9                52 2000-04-25 20:51:31
# ...                   ...               ...                 ...
# 130057             169065                53 2011-06-10 03:09:03
# 130058             169065                53 2011-06-10 08:09:33
# 130059             169065                53 2011-06-11 14:22:18
# 130060             169065                53 2011-06-11 14:22:18
# 130061             169065                53 2011-06-11 16:44:30
#
#        Procedure code                         Procedure code description  \
# 0               98966  TELEPHONE ASSESSMENT AND MANAGEMENT SERVICE PR...
# 1               D1206  TOPICAL FLUORIDE VARNISH; THERAPEUTIC APPLICAT...
# 2               D2331                       RESIN-TWO SURFACES, ANTERIOR
# 3               37.78  INSERTION OF TEMPORARY TRANSVENOUS PACEMAKER S...
# 4               96.05              OTHER INTUBATION OF RESPIRATORY TRACT
# ...               ...                                                ...
# 130057          71010  RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW, FR...
# 130058          71010  RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW, FR...
# 130059          99499         UNLISTED EVALUATION AND MANAGEMENT SERVICE
# 130060          99211  OFFICE OR OTHER OUTPATIENT VISIT FOR THE EVALU...
# 130061          99499         UNLISTED EVALUATION AND MANAGEMENT SERVICE
#
#            State                        procedures_code_description
# 0          Texas  88_TELEPHONE ASSESSMENT AND MANAGEMENT SERVICE...
# 1       Nebraska  74_TOPICAL FLUORIDE VARNISH; THERAPEUTIC APPLI...
# 2       Nebraska                    74_RESIN-TWO SURFACES, ANTERIOR
# 3          Texas  52_INSERTION OF TEMPORARY TRANSVENOUS PACEMAKE...
# 4          Texas           52_OTHER INTUBATION OF RESPIRATORY TRACT
# ...          ...                                                ...
# 130057   Arizona  53_RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW,...
# 130058   Arizona  53_RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW,...
# 130059   Arizona      53_UNLISTED EVALUATION AND MANAGEMENT SERVICE
# 130060   Arizona  53_OFFICE OR OTHER OUTPATIENT VISIT FOR THE EV...
# 130061   Arizona      53_UNLISTED EVALUATION AND MANAGEMENT SERVICE
#
# [115073 rows x 7 columns]

# %% [markdown]
# # Dropping all unnecessary columns

# %%
# Remove columns 
df_procedures.drop(["Age at procedure","Procedure date","Procedure code",
                         "Procedure code description","State"], axis=1,inplace=True)

# %%
df_procedures = df_procedures

# %%
df_procedures
# Out:
#         Internalpatientid                        procedures_code_description
# 0                       6  88_TELEPHONE ASSESSMENT AND MANAGEMENT SERVICE...
# 1                       7  74_TOPICAL FLUORIDE VARNISH; THERAPEUTIC APPLI...
# 2                       7                    74_RESIN-TWO SURFACES, ANTERIOR
# 3                       9  52_INSERTION OF TEMPORARY TRANSVENOUS PACEMAKE...
# 4                       9           52_OTHER INTUBATION OF RESPIRATORY TRACT
# ...                   ...                                                ...
# 130057             169065  53_RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW,...
# 130058             169065  53_RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW,...
# 130059             169065      53_UNLISTED EVALUATION AND MANAGEMENT SERVICE
# 130060             169065  53_OFFICE OR OTHER OUTPATIENT VISIT FOR THE EV...
# 130061             169065      53_UNLISTED EVALUATION AND MANAGEMENT SERVICE
#
# [115073 rows x 2 columns]

# %%
# Group the DataFrame by 'Internalpatientid' and concatenate the icd10 values and
#The purpose of `x.dropna()` is to remove any missing values from the Series before applying a subsequent operation,
# such as concatenation using the `join` function. By dropping the missing values,
#we ensure that only non-null values are included in the resulting concatenated string.
df_grouped = df_procedures.groupby('Internalpatientid').agg(lambda x: ','.join(x.dropna()))
df_grouped 

# Reset the index of the grouped DataFrame
df_grouped_procedures = df_grouped.reset_index()
df_grouped_procedures
# Out:
#        Internalpatientid                        procedures_code_description
# 0                      6  88_TELEPHONE ASSESSMENT AND MANAGEMENT SERVICE...
# 1                      7  74_TOPICAL FLUORIDE VARNISH; THERAPEUTIC APPLI...
# 2                      9  52_INSERTION OF TEMPORARY TRANSVENOUS PACEMAKE...
# 3                     12  74_LIPID PANELTHIS PANEL MUST INCLUDE THE FOLL...
# 4                     17  82_TREATMENT OF SWALLOWING DYSFUNCTION AND/OR ...
# ...                  ...                                                ...
# 34467             169037  88_TELEPHONE ASSESSMENT AND MANAGEMENT SERVICE...
# 34468             169045  98_EDUCATION AND TRAINING FOR PATIENT SELF-MAN...
# 34469             169058  79_OFFICE OR OTHER OUTPATIENT VISIT FOR THE EV...
# 34470             169059  91_TELEPHONE ASSESSMENT AND MANAGEMENT SERVICE...
# 34471             169065  53_RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW,...
#
# [34472 rows x 2 columns]

# %% [markdown]
# # Saving the csv file

# %%
df_grouped_procedures.to_csv('/mnt/batch/tasks/shared/LS_root/mounts/clusters/team-3-susai-gpu2/code/Users/900379/Output_files_test/df_procedures_test.csv')

# %%
df_grouped_procedures['procedures_code_description'].values[34471]
# Out:
# '53_RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW, FRONTAL,53_RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW, FRONTAL,53_UNLISTED EVALUATION AND MANAGEMENT SERVICE,53_OFFICE OR OTHER OUTPATIENT VISIT FOR THE EVALUATION AND MANAGEMENT OF ANESTABLISHED PATIENT, THAT MAY NOT REQUIRE THE PRESENCE OF A PHYSICIAN OR OTHERQUALIFIED HEALTH CARE PROFESSIONAL. USUALLY, THE PRESENTING PROBLEM(S) AREMINIMAL.,53_UNLISTED EVALUATION AND MANAGEMENT SERVICE'
