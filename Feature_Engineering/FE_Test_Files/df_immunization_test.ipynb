# %% [markdown]
# # **Immunization Notebook**

# %%
#A class attribute that provides access to the TabularDatasetFactory methods for creating new TabularDataset objects. 
#Usage: Dataset.Tabular.from_delimited_files().
from azureml.core import Workspace, Dataset

subscription_id = 'bcfe0c62-8ebe-4df0-a46d-1efcf8739a5b' #check the launch studio there will get this id
resource_group = 'VChamp-Team3' # resource group name
workspace_name = 'vchamp-team3' # worksapce name


# storage account : Algorithmia, Resource group: VChamp-Team3 and workspace: vchamp-team3.
#Constructor
workspace = Workspace(subscription_id, resource_group, workspace_name)

# %%
#['data_team3_synthetic_test']
datastore = workspace.datastores['data_team3_synthetic_test']

# %%
#from_delimited_files (Create a TabularDataset to represent tabular data in delimited files (e.g. CSV and TSV).

dataset = Dataset.Tabular.from_delimited_files(path = [(datastore, 'immunization_test.csv')])

# preview the first 3 rows of the dataset
# dataset.to_pandas_dataframe()

# %%
#Converting the dataset into data frame(default as dataset in Azure, thus we must convert the needed formate)
immunizations_test = dataset.to_pandas_dataframe()

# %%
immunizations_test
# Out:
#         Column1  Internalpatientid  Age at immunization   Immunization date  \
# 0             0                100            52.898575 2014-08-21 10:17:59
# 1             1                100            52.898575 2014-08-21 10:17:59
# 2             2                100            52.898575 2014-08-21 10:17:59
# 3            28             100041            88.331313 2013-08-05 02:16:33
# 4            29             100041            88.331313 2013-08-05 02:16:33
# ...         ...                ...                  ...                 ...
# 486629  2347834              99958            79.600992 2005-09-15 03:54:19
# 486630  2347835              99958            79.600992 2005-09-15 03:54:19
# 486631  2347849              99979            57.915172 2005-04-04 23:53:11
# 486632  2347859              99997            85.682957 2014-10-28 02:53:46
# 486633  2347860              99997            87.109014 2016-04-01 08:16:07
#
#                                              Immunization Dose quantity  \
# 0                   PNEUMOCOCCAL, UNSPECIFIED FORMULATION          None
# 1                                  FLU,3 YRS (HISTORICAL)          None
# 2                      INFLUENZA, UNSPECIFIED FORMULATION          None
# 3                       TD(ADULT) UNSPECIFIED FORMULATION          None
# 4               NOVEL INFLUENZA-H1N1-09, ALL FORMULATIONS          None
# ...                                                   ...           ...
# 486629                                   INFLUENZA, WHOLE          None
# 486630                 INFLUENZA, UNSPECIFIED FORMULATION          None
# 486631                  TD(ADULT) UNSPECIFIED FORMULATION          None
# 486632                                        ZOSTER LIVE          None
# 486633  INFLUENZA, SEASONAL, INJECTABLE, PRESERVATIVE ...          None
#
#        Dose unit Administered elsewhere  Cvx code              Series doses  \
# 0           None                   None     109.0  Not specified (no value)
# 1           None                   None      88.0  Not specified (no value)
# 2           None                   None      88.0  Not specified (no value)
# 3           None                   None     139.0  Not specified (no value)
# 4           None                   None     128.0  Not specified (no value)
# ...          ...                    ...       ...                       ...
# 486629      None                   None      16.0  Not specified (no value)
# 486630      None                   None      88.0  Not specified (no value)
# 486631      None                   None     139.0  Not specified (no value)
# 486632      None                   None     121.0  Not specified (no value)
# 486633      None                   None     140.0  Not specified (no value)
#
#                  State
# 0             New York
# 1             New York
# 2             New York
# 3            Minnesota
# 4            Minnesota
# ...                ...
# 486629        New York
# 486630        New York
# 486631  North Carolina
# 486632  North Carolina
# 486633  North Carolina
#
# [486634 rows x 11 columns]

# %% [markdown]
# # Importing library

# %%
import numpy as np                # Multi-Dimensional array object
import pandas as pd               # Data Manipulation
import matplotlib.pyplot as plt   # Data Visualization
import seaborn as sns             # Data Visualization 

# Allows the use of display() for DataFrames
from IPython.display import display 

# Handle warning messages that may occur during code execution
import warnings
warnings.filterwarnings('ignore')

# To increase memory allocation
from notebook.services.config import ConfigManager
cm = ConfigManager().update('notebook', {'max_buffer_size': 7294967296})

# Set the maximum number of rows to be displayed to 1000
pd.set_option('display.max_rows', 1163)

# %% [markdown]
# # Elimination of the unnamed columns

# %%
# Remove unwanted columns 
immunizations_test.drop('Column1',axis=1,inplace=True)

# %%
immunizations_test = immunizations_test

# %%
immunizations_test
# Out:
#         Internalpatientid  Age at immunization   Immunization date  \
# 0                     100            52.898575 2014-08-21 10:17:59
# 1                     100            52.898575 2014-08-21 10:17:59
# 2                     100            52.898575 2014-08-21 10:17:59
# 3                  100041            88.331313 2013-08-05 02:16:33
# 4                  100041            88.331313 2013-08-05 02:16:33
# ...                   ...                  ...                 ...
# 486629              99958            79.600992 2005-09-15 03:54:19
# 486630              99958            79.600992 2005-09-15 03:54:19
# 486631              99979            57.915172 2005-04-04 23:53:11
# 486632              99997            85.682957 2014-10-28 02:53:46
# 486633              99997            87.109014 2016-04-01 08:16:07
#
#                                              Immunization Dose quantity  \
# 0                   PNEUMOCOCCAL, UNSPECIFIED FORMULATION          None
# 1                                  FLU,3 YRS (HISTORICAL)          None
# 2                      INFLUENZA, UNSPECIFIED FORMULATION          None
# 3                       TD(ADULT) UNSPECIFIED FORMULATION          None
# 4               NOVEL INFLUENZA-H1N1-09, ALL FORMULATIONS          None
# ...                                                   ...           ...
# 486629                                   INFLUENZA, WHOLE          None
# 486630                 INFLUENZA, UNSPECIFIED FORMULATION          None
# 486631                  TD(ADULT) UNSPECIFIED FORMULATION          None
# 486632                                        ZOSTER LIVE          None
# 486633  INFLUENZA, SEASONAL, INJECTABLE, PRESERVATIVE ...          None
#
#        Dose unit Administered elsewhere  Cvx code              Series doses  \
# 0           None                   None     109.0  Not specified (no value)
# 1           None                   None      88.0  Not specified (no value)
# 2           None                   None      88.0  Not specified (no value)
# 3           None                   None     139.0  Not specified (no value)
# 4           None                   None     128.0  Not specified (no value)
# ...          ...                    ...       ...                       ...
# 486629      None                   None      16.0  Not specified (no value)
# 486630      None                   None      88.0  Not specified (no value)
# 486631      None                   None     139.0  Not specified (no value)
# 486632      None                   None     121.0  Not specified (no value)
# 486633      None                   None     140.0  Not specified (no value)
#
#                  State
# 0             New York
# 1             New York
# 2             New York
# 3            Minnesota
# 4            Minnesota
# ...                ...
# 486629        New York
# 486630        New York
# 486631  North Carolina
# 486632  North Carolina
# 486633  North Carolina
#
# [486634 rows x 10 columns]

# %% [markdown]
# # Sorting out patients id and age column

# %%
# Sort the dataset based on the patientsid and 'age' column in ascending order
immunizations_test.sort_values(["Internalpatientid","Age at immunization"],inplace=True)

# %%
immunizations_test
# Out:
#         Internalpatientid  Age at immunization   Immunization date  \
# 307933                  6            74.147397 2000-10-29 20:58:06
# 448383                  6            74.228196 2000-11-28 09:43:53
# 312369                  6            74.842469 2001-07-10 22:08:13
# 312370                  6            74.842469 2001-07-10 22:08:13
# 312371                  6            74.842469 2001-07-10 22:08:13
# ...                   ...                  ...                 ...
# 389580             169065            50.864468 2008-12-25 23:06:38
# 360795             169065            50.981669 2009-02-06 19:12:02
# 200927             169065            51.861766 2009-12-25 11:24:29
# 192639             169065            52.864184 2010-12-26 20:37:16
# 200480             169065            52.928328 2011-01-19 07:17:49
#
#                                              Immunization Dose quantity  \
# 307933                  TD(ADULT) UNSPECIFIED FORMULATION          None
# 448383                  TD(ADULT) UNSPECIFIED FORMULATION          None
# 312369              PNEUMOCOCCAL, UNSPECIFIED FORMULATION          None
# 312370                 INFLUENZA, UNSPECIFIED FORMULATION          None
# 312371                             FLU,3 YRS (HISTORICAL)          None
# ...                                                   ...           ...
# 389580  INFLUENZA VIRUS VACCINE, 3YR AND OLDER (HISTOR...          None
# 360795                 INFLUENZA, UNSPECIFIED FORMULATION          None
# 200927                 INFLUENZA, UNSPECIFIED FORMULATION          None
# 192639                 INFLUENZA, UNSPECIFIED FORMULATION          None
# 200480                 INFLUENZA, UNSPECIFIED FORMULATION          None
#
#        Dose unit Administered elsewhere  Cvx code              Series doses  \
# 307933      None                   None     139.0  Not specified (no value)
# 448383      None                   None     139.0  Not specified (no value)
# 312369      None                   None     109.0                  Complete
# 312370      None                   None      88.0                  Complete
# 312371      None                   None      88.0  Not specified (no value)
# ...          ...                    ...       ...                       ...
# 389580      None                   None      88.0  Not specified (no value)
# 360795      None                   None      88.0  Not specified (no value)
# 200927      None                   None      88.0  Not specified (no value)
# 192639      None                   None      88.0  Not specified (no value)
# 200480      None                   None      88.0  Not specified (no value)
#
#              State
# 307933       Texas
# 448383       Texas
# 312369       Texas
# 312370       Texas
# 312371       Texas
# ...            ...
# 389580  California
# 360795     Arizona
# 200927     Arizona
# 192639     Arizona
# 200480     Arizona
#
# [486634 rows x 10 columns]

# %% [markdown]
# # Checking the missing value

# %%
print("Training set missing values:\n", immunizations_test.isna().sum())
# Out:
# Training set missing values:
#  Internalpatientid              0
# Age at immunization            0
# Immunization date              0
# Immunization                   4
# Dose quantity             483403
# Dose unit                 483404
# Administered elsewhere    417411
# Cvx code                    4768
# Series doses                   0
# State                          0
# dtype: int64

# %% [markdown]
# # Removing the missing value from "Immunization" column

# %%
# Remove rows missing values in the "Immunization" column
immunizations_test.dropna(subset=["Immunization"],inplace=True)

# %%
immunizations_test = immunizations_test

# %%
immunizations_test
# Out:
#         Internalpatientid  Age at immunization   Immunization date  \
# 307933                  6            74.147397 2000-10-29 20:58:06
# 448383                  6            74.228196 2000-11-28 09:43:53
# 312369                  6            74.842469 2001-07-10 22:08:13
# 312370                  6            74.842469 2001-07-10 22:08:13
# 312371                  6            74.842469 2001-07-10 22:08:13
# ...                   ...                  ...                 ...
# 389580             169065            50.864468 2008-12-25 23:06:38
# 360795             169065            50.981669 2009-02-06 19:12:02
# 200927             169065            51.861766 2009-12-25 11:24:29
# 192639             169065            52.864184 2010-12-26 20:37:16
# 200480             169065            52.928328 2011-01-19 07:17:49
#
#                                              Immunization Dose quantity  \
# 307933                  TD(ADULT) UNSPECIFIED FORMULATION          None
# 448383                  TD(ADULT) UNSPECIFIED FORMULATION          None
# 312369              PNEUMOCOCCAL, UNSPECIFIED FORMULATION          None
# 312370                 INFLUENZA, UNSPECIFIED FORMULATION          None
# 312371                             FLU,3 YRS (HISTORICAL)          None
# ...                                                   ...           ...
# 389580  INFLUENZA VIRUS VACCINE, 3YR AND OLDER (HISTOR...          None
# 360795                 INFLUENZA, UNSPECIFIED FORMULATION          None
# 200927                 INFLUENZA, UNSPECIFIED FORMULATION          None
# 192639                 INFLUENZA, UNSPECIFIED FORMULATION          None
# 200480                 INFLUENZA, UNSPECIFIED FORMULATION          None
#
#        Dose unit Administered elsewhere  Cvx code              Series doses  \
# 307933      None                   None     139.0  Not specified (no value)
# 448383      None                   None     139.0  Not specified (no value)
# 312369      None                   None     109.0                  Complete
# 312370      None                   None      88.0                  Complete
# 312371      None                   None      88.0  Not specified (no value)
# ...          ...                    ...       ...                       ...
# 389580      None                   None      88.0  Not specified (no value)
# 360795      None                   None      88.0  Not specified (no value)
# 200927      None                   None      88.0  Not specified (no value)
# 192639      None                   None      88.0  Not specified (no value)
# 200480      None                   None      88.0  Not specified (no value)
#
#              State
# 307933       Texas
# 448383       Texas
# 312369       Texas
# 312370       Texas
# 312371       Texas
# ...            ...
# 389580  California
# 360795     Arizona
# 200927     Arizona
# 192639     Arizona
# 200480     Arizona
#
# [486630 rows x 10 columns]

# %%
# Checking the missing value after removing 
print("Training set missing values:\n", immunizations_test.isna().sum())
# Out:
# Training set missing values:
#  Internalpatientid              0
# Age at immunization            0
# Immunization date              0
# Immunization                   0
# Dose quantity             483399
# Dose unit                 483400
# Administered elsewhere    417407
# Cvx code                    4765
# Series doses                   0
# State                          0
# dtype: int64

# %% [markdown]
# # Taking the one digit in age coulmn

# %%
# Format 'Age at immunizations' values in the format 00.00
immunizations_test["Age at immunization"] = immunizations_test["Age at immunization"].map("{:.2f}".format)

# %%
immunizations_test
# Out:
#         Internalpatientid Age at immunization   Immunization date  \
# 307933                  6               74.15 2000-10-29 20:58:06
# 448383                  6               74.23 2000-11-28 09:43:53
# 312369                  6               74.84 2001-07-10 22:08:13
# 312370                  6               74.84 2001-07-10 22:08:13
# 312371                  6               74.84 2001-07-10 22:08:13
# ...                   ...                 ...                 ...
# 389580             169065               50.86 2008-12-25 23:06:38
# 360795             169065               50.98 2009-02-06 19:12:02
# 200927             169065               51.86 2009-12-25 11:24:29
# 192639             169065               52.86 2010-12-26 20:37:16
# 200480             169065               52.93 2011-01-19 07:17:49
#
#                                              Immunization Dose quantity  \
# 307933                  TD(ADULT) UNSPECIFIED FORMULATION          None
# 448383                  TD(ADULT) UNSPECIFIED FORMULATION          None
# 312369              PNEUMOCOCCAL, UNSPECIFIED FORMULATION          None
# 312370                 INFLUENZA, UNSPECIFIED FORMULATION          None
# 312371                             FLU,3 YRS (HISTORICAL)          None
# ...                                                   ...           ...
# 389580  INFLUENZA VIRUS VACCINE, 3YR AND OLDER (HISTOR...          None
# 360795                 INFLUENZA, UNSPECIFIED FORMULATION          None
# 200927                 INFLUENZA, UNSPECIFIED FORMULATION          None
# 192639                 INFLUENZA, UNSPECIFIED FORMULATION          None
# 200480                 INFLUENZA, UNSPECIFIED FORMULATION          None
#
#        Dose unit Administered elsewhere  Cvx code              Series doses  \
# 307933      None                   None     139.0  Not specified (no value)
# 448383      None                   None     139.0  Not specified (no value)
# 312369      None                   None     109.0                  Complete
# 312370      None                   None      88.0                  Complete
# 312371      None                   None      88.0  Not specified (no value)
# ...          ...                    ...       ...                       ...
# 389580      None                   None      88.0  Not specified (no value)
# 360795      None                   None      88.0  Not specified (no value)
# 200927      None                   None      88.0  Not specified (no value)
# 192639      None                   None      88.0  Not specified (no value)
# 200480      None                   None      88.0  Not specified (no value)
#
#              State
# 307933       Texas
# 448383       Texas
# 312369       Texas
# 312370       Texas
# 312371       Texas
# ...            ...
# 389580  California
# 360795     Arizona
# 200927     Arizona
# 192639     Arizona
# 200480     Arizona
#
# [486630 rows x 10 columns]

# %%
# Convert 'Age at immunization' column from object to float
immunizations_test["Age at immunization"] = immunizations_test["Age at immunization"].astype(float)

# %%
immunizations_test
# Out:
#         Internalpatientid  Age at immunization   Immunization date  \
# 307933                  6                74.15 2000-10-29 20:58:06
# 448383                  6                74.23 2000-11-28 09:43:53
# 312369                  6                74.84 2001-07-10 22:08:13
# 312370                  6                74.84 2001-07-10 22:08:13
# 312371                  6                74.84 2001-07-10 22:08:13
# ...                   ...                  ...                 ...
# 389580             169065                50.86 2008-12-25 23:06:38
# 360795             169065                50.98 2009-02-06 19:12:02
# 200927             169065                51.86 2009-12-25 11:24:29
# 192639             169065                52.86 2010-12-26 20:37:16
# 200480             169065                52.93 2011-01-19 07:17:49
#
#                                              Immunization Dose quantity  \
# 307933                  TD(ADULT) UNSPECIFIED FORMULATION          None
# 448383                  TD(ADULT) UNSPECIFIED FORMULATION          None
# 312369              PNEUMOCOCCAL, UNSPECIFIED FORMULATION          None
# 312370                 INFLUENZA, UNSPECIFIED FORMULATION          None
# 312371                             FLU,3 YRS (HISTORICAL)          None
# ...                                                   ...           ...
# 389580  INFLUENZA VIRUS VACCINE, 3YR AND OLDER (HISTOR...          None
# 360795                 INFLUENZA, UNSPECIFIED FORMULATION          None
# 200927                 INFLUENZA, UNSPECIFIED FORMULATION          None
# 192639                 INFLUENZA, UNSPECIFIED FORMULATION          None
# 200480                 INFLUENZA, UNSPECIFIED FORMULATION          None
#
#        Dose unit Administered elsewhere  Cvx code              Series doses  \
# 307933      None                   None     139.0  Not specified (no value)
# 448383      None                   None     139.0  Not specified (no value)
# 312369      None                   None     109.0                  Complete
# 312370      None                   None      88.0                  Complete
# 312371      None                   None      88.0  Not specified (no value)
# ...          ...                    ...       ...                       ...
# 389580      None                   None      88.0  Not specified (no value)
# 360795      None                   None      88.0  Not specified (no value)
# 200927      None                   None      88.0  Not specified (no value)
# 192639      None                   None      88.0  Not specified (no value)
# 200480      None                   None      88.0  Not specified (no value)
#
#              State
# 307933       Texas
# 448383       Texas
# 312369       Texas
# 312370       Texas
# 312371       Texas
# ...            ...
# 389580  California
# 360795     Arizona
# 200927     Arizona
# 192639     Arizona
# 200480     Arizona
#
# [486630 rows x 10 columns]

# %% [markdown]
# # Taking the Max age

# %%
# Find the latest record for each internal patient id
max_ages = immunizations_test.groupby('Internalpatientid')['Age at immunization'].max().reset_index()

# Merge with the original dataframe to get the rows with the highest age
immunizations_test = pd.merge(immunizations_test, max_ages, on =['Internalpatientid','Age at immunization'], how = 'inner')

immunizations_test
# Out:
#        Internalpatientid  Age at immunization   Immunization date  \
# 0                      6                87.82 2014-07-04 12:50:01
# 1                      7                72.70 2019-03-21 20:17:01
# 2                     12                71.47 2001-11-29 07:13:25
# 3                     17                82.22 2004-05-13 14:18:11
# 4                     17                82.22 2004-05-13 14:18:11
# ...                  ...                  ...                 ...
# 39967             169024                71.44 2010-12-01 00:05:07
# 39968             169037                87.41 2017-06-23 16:37:46
# 39969             169045                97.36 2021-07-25 21:32:52
# 39970             169059                90.22 2013-06-28 10:41:26
# 39971             169065                52.93 2011-01-19 07:17:49
#
#                                             Immunization Dose quantity  \
# 0                                 FLU,3 YRS (HISTORICAL)          None
# 1      INFLUENZA, INJECTABLE, QUADRIVALENT, PRESERVAT...          None
# 2                                 FLU,3 YRS (HISTORICAL)          None
# 3                                 INFLUENZA (HISTORICAL)          None
# 4                                       INFLUENZA, WHOLE          None
# ...                                                  ...           ...
# 39967                             INFLUENZA (HISTORICAL)          None
# 39968                                 ZOSTER RECOMBINANT          None
# 39969  COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/0.3...          None
# 39970                 INFLUENZA, UNSPECIFIED FORMULATION          None
# 39971                 INFLUENZA, UNSPECIFIED FORMULATION          None
#
#       Dose unit Administered elsewhere  Cvx code              Series doses  \
# 0          None                   None      88.0  Not specified (no value)
# 1          None                   None     150.0  Not specified (no value)
# 2          None                   None      88.0  Not specified (no value)
# 3          None                   None      88.0  Not specified (no value)
# 4          None                   None      16.0  Not specified (no value)
# ...         ...                    ...       ...                       ...
# 39967      None                   None      88.0  Not specified (no value)
# 39968      None                   None     187.0                         2
# 39969      None                   None     208.0                         2
# 39970      None                   None      88.0  Not specified (no value)
# 39971      None                   None      88.0  Not specified (no value)
#
#            State
# 0          Texas
# 1      Wisconsin
# 2       Colorado
# 3       Maryland
# 4       Maryland
# ...          ...
# 39967    Alabama
# 39968   Illinois
# 39969  Minnesota
# 39970    Arizona
# 39971    Arizona
#
# [39972 rows x 10 columns]

# %% [markdown]
# # Rounding off the Age column

# %%
immunizations_test['Age at immunization'] = immunizations_test['Age at immunization'].apply(lambda x: round(x,))

# %%
immunizations_test
# Out:
#        Internalpatientid  Age at immunization   Immunization date  \
# 0                      6                   88 2014-07-04 12:50:01
# 1                      7                   73 2019-03-21 20:17:01
# 2                     12                   71 2001-11-29 07:13:25
# 3                     17                   82 2004-05-13 14:18:11
# 4                     17                   82 2004-05-13 14:18:11
# ...                  ...                  ...                 ...
# 39967             169024                   71 2010-12-01 00:05:07
# 39968             169037                   87 2017-06-23 16:37:46
# 39969             169045                   97 2021-07-25 21:32:52
# 39970             169059                   90 2013-06-28 10:41:26
# 39971             169065                   53 2011-01-19 07:17:49
#
#                                             Immunization Dose quantity  \
# 0                                 FLU,3 YRS (HISTORICAL)          None
# 1      INFLUENZA, INJECTABLE, QUADRIVALENT, PRESERVAT...          None
# 2                                 FLU,3 YRS (HISTORICAL)          None
# 3                                 INFLUENZA (HISTORICAL)          None
# 4                                       INFLUENZA, WHOLE          None
# ...                                                  ...           ...
# 39967                             INFLUENZA (HISTORICAL)          None
# 39968                                 ZOSTER RECOMBINANT          None
# 39969  COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/0.3...          None
# 39970                 INFLUENZA, UNSPECIFIED FORMULATION          None
# 39971                 INFLUENZA, UNSPECIFIED FORMULATION          None
#
#       Dose unit Administered elsewhere  Cvx code              Series doses  \
# 0          None                   None      88.0  Not specified (no value)
# 1          None                   None     150.0  Not specified (no value)
# 2          None                   None      88.0  Not specified (no value)
# 3          None                   None      88.0  Not specified (no value)
# 4          None                   None      16.0  Not specified (no value)
# ...         ...                    ...       ...                       ...
# 39967      None                   None      88.0  Not specified (no value)
# 39968      None                   None     187.0                         2
# 39969      None                   None     208.0                         2
# 39970      None                   None      88.0  Not specified (no value)
# 39971      None                   None      88.0  Not specified (no value)
#
#            State
# 0          Texas
# 1      Wisconsin
# 2       Colorado
# 3       Maryland
# 4       Maryland
# ...          ...
# 39967    Alabama
# 39968   Illinois
# 39969  Minnesota
# 39970    Arizona
# 39971    Arizona
#
# [39972 rows x 10 columns]

# %%
immunizations_test["Internalpatientid"].value_counts()
# Out:
# 35686     22
# 73986     14
# 79654     13
# 118861    13
# 82946     13
#           ..
# 150141     1
# 164343     1
# 154239     1
# 80714      1
# 131072     1
# Name: Internalpatientid, Length: 32784, dtype: int64

# %% [markdown]
# # Adding  'Age at immunization' & 'Immunization' columns with '_'

# %%
#In this code, we create a new column called 'Lab test description_Result numeric' by concatenating the values of the 'lab test description' column, underscore ('_'), and the 'lab test results' column
#converted to a string using the `astype(str)` function(because we cant't add differnt dtype)
immunizations_test['immunization'] =  immunizations_test['Age at immunization'].astype(str) + '_' +  immunizations_test['Immunization']

# %%
immunizations_test
# Out:
#        Internalpatientid  Age at immunization   Immunization date  \
# 0                      6                   88 2014-07-04 12:50:01
# 1                      7                   73 2019-03-21 20:17:01
# 2                     12                   71 2001-11-29 07:13:25
# 3                     17                   82 2004-05-13 14:18:11
# 4                     17                   82 2004-05-13 14:18:11
# ...                  ...                  ...                 ...
# 39967             169024                   71 2010-12-01 00:05:07
# 39968             169037                   87 2017-06-23 16:37:46
# 39969             169045                   97 2021-07-25 21:32:52
# 39970             169059                   90 2013-06-28 10:41:26
# 39971             169065                   53 2011-01-19 07:17:49
#
#                                             Immunization Dose quantity  \
# 0                                 FLU,3 YRS (HISTORICAL)          None
# 1      INFLUENZA, INJECTABLE, QUADRIVALENT, PRESERVAT...          None
# 2                                 FLU,3 YRS (HISTORICAL)          None
# 3                                 INFLUENZA (HISTORICAL)          None
# 4                                       INFLUENZA, WHOLE          None
# ...                                                  ...           ...
# 39967                             INFLUENZA (HISTORICAL)          None
# 39968                                 ZOSTER RECOMBINANT          None
# 39969  COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/0.3...          None
# 39970                 INFLUENZA, UNSPECIFIED FORMULATION          None
# 39971                 INFLUENZA, UNSPECIFIED FORMULATION          None
#
#       Dose unit Administered elsewhere  Cvx code              Series doses  \
# 0          None                   None      88.0  Not specified (no value)
# 1          None                   None     150.0  Not specified (no value)
# 2          None                   None      88.0  Not specified (no value)
# 3          None                   None      88.0  Not specified (no value)
# 4          None                   None      16.0  Not specified (no value)
# ...         ...                    ...       ...                       ...
# 39967      None                   None      88.0  Not specified (no value)
# 39968      None                   None     187.0                         2
# 39969      None                   None     208.0                         2
# 39970      None                   None      88.0  Not specified (no value)
# 39971      None                   None      88.0  Not specified (no value)
#
#            State                                       immunization
# 0          Texas                          88_FLU,3 YRS (HISTORICAL)
# 1      Wisconsin  73_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 2       Colorado                          71_FLU,3 YRS (HISTORICAL)
# 3       Maryland                          82_INFLUENZA (HISTORICAL)
# 4       Maryland                                82_INFLUENZA, WHOLE
# ...          ...                                                ...
# 39967    Alabama                          71_INFLUENZA (HISTORICAL)
# 39968   Illinois                              87_ZOSTER RECOMBINANT
# 39969  Minnesota  97_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 39970    Arizona              90_INFLUENZA, UNSPECIFIED FORMULATION
# 39971    Arizona              53_INFLUENZA, UNSPECIFIED FORMULATION
#
# [39972 rows x 11 columns]

# %% [markdown]
# # Dropping all unnecessary columns

# %%
# Remove columns 
immunizations_test.drop(['Age at immunization','Immunization date','Immunization','Dose quantity','Dose unit','Administered elsewhere','Cvx code','Series doses','State'], axis=1,inplace=True)

# %%
immunizations_test = immunizations_test

# %%
immunizations_test
# Out:
#        Internalpatientid                                       immunization
# 0                      6                          88_FLU,3 YRS (HISTORICAL)
# 1                      7  73_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 2                     12                          71_FLU,3 YRS (HISTORICAL)
# 3                     17                          82_INFLUENZA (HISTORICAL)
# 4                     17                                82_INFLUENZA, WHOLE
# ...                  ...                                                ...
# 39967             169024                          71_INFLUENZA (HISTORICAL)
# 39968             169037                              87_ZOSTER RECOMBINANT
# 39969             169045  97_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 39970             169059              90_INFLUENZA, UNSPECIFIED FORMULATION
# 39971             169065              53_INFLUENZA, UNSPECIFIED FORMULATION
#
# [39972 rows x 2 columns]

# %%
# Group the DataFrame by 'Internalpatientid' and concatenate the icd10 values and
#The purpose of `x.dropna()` is to remove any missing values from the Series before applying a subsequent operation,
# such as concatenation using the `join` function. By dropping the missing values,
#we ensure that only non-null values are included in the resulting concatenated string.
df_grouped = immunizations_test.groupby('Internalpatientid').agg(lambda x: ','.join(x.dropna()))
df_grouped 

# Reset the index of the grouped DataFrame
df_grouped_imm = df_grouped.reset_index()
df_grouped_imm
# Out:
#        Internalpatientid                                       immunization
# 0                      6                          88_FLU,3 YRS (HISTORICAL)
# 1                      7  73_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 2                     12                          71_FLU,3 YRS (HISTORICAL)
# 3                     17      82_INFLUENZA (HISTORICAL),82_INFLUENZA, WHOLE
# 4                     22           55_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# ...                  ...                                                ...
# 32779             169024                          71_INFLUENZA (HISTORICAL)
# 32780             169037                              87_ZOSTER RECOMBINANT
# 32781             169045  97_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 32782             169059              90_INFLUENZA, UNSPECIFIED FORMULATION
# 32783             169065              53_INFLUENZA, UNSPECIFIED FORMULATION
#
# [32784 rows x 2 columns]

# %%
# Checking row values if it is correctly printed like A, B, C...
column_value = df_grouped_imm['immunization'].values[5]
print(column_value)
# Out:
# 70_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MCG/0.5ML DOSE OR 50 MCG/0.25ML DOSE

# %% [markdown]
# # Saving the file

# %%
df_grouped_imm.to_csv('/mnt/batch/tasks/shared/LS_root/mounts/clusters/team-3-susai-gpu2/code/Users/900379/Output_files_test/df_immunizations_test.csv')
