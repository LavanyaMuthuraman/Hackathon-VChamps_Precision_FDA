# %% [markdown]
# # **Lab Results Notebook**

# %% [markdown]
# # **Azure notebook Setup**

# %%
#A class attribute that provides access to the TabularDatasetFactory methods for creating new TabularDataset objects. 
#Usage: Dataset.Tabular.from_delimited_files().
from azureml.core import Workspace, Dataset

subscription_id = 'bcfe0c62-8ebe-4df0-a46d-1efcf8739a5b' #check the launch studio there will get this id
resource_group = 'VChamp-Team3' # resource group name
workspace_name = 'vchamp-team3' # worksapce name


# storage account : Algorithmia, Resource group: VChamp-Team3 and workspace: vchamp-team3.
#Constructor
workspace = Workspace(subscription_id, resource_group, workspace_name)

# %%
#['data_team3_synthetic_test']
datastore = workspace.datastores['data_team3_synthetic_test']

# %%
#from_delimited_files (Create a TabularDataset to represent tabular data in delimited files (e.g. CSV and TSV).

dataset = Dataset.Tabular.from_delimited_files(path = [(datastore, 'lab_results_test.csv')])

# preview the first 3 rows of the dataset
# dataset.to_pandas_dataframe()

# %%
#Converting the dataset into data frame(default as dataset in Azure, thus we must convert the needed formate)
lab_train_data = dataset.to_pandas_dataframe()

# %%
lab_train_data
# Out:
#             Column1  Internalpatientid  Age at lab test       Lab test date  \
# 0                 0              51658        85.044326 2012-02-26 16:49:42
# 1                 1              51658        85.044326 2012-02-26 16:49:42
# 2                 2              51658        85.044326 2012-02-26 16:49:42
# 3                 3              51658        85.044326 2012-02-26 16:49:42
# 4                 4              51658        85.044326 2012-02-26 16:49:42
# ...             ...                ...              ...                 ...
# 68356045  328853762              51661        55.489201 2021-09-27 07:16:26
# 68356046  328853763              51661        55.489201 2021-09-27 07:16:26
# 68356047  328853764              51661        55.489201 2021-09-27 07:16:26
# 68356048  328853765              51661        55.489201 2021-09-27 07:16:26
# 68356049  328853766              51661        55.489201 2021-09-27 07:16:26
#
#                             Lab test Lab test description  Result numeric  \
# 0                     ly#_k/ul_blood                  LY#        1.316318
# 1                        eo%_%_blood                  EO%        1.992369
# 2                       mch_pg_blood                  MCH       30.505044
# 3              mchc_g/dl_no specimen                 Mchc       33.261005
# 4                     wbc_k/ul_blood                  WBC        7.170170
# ...                              ...                  ...             ...
# 68356045  urea nitrogen_mg/dl_plasma        UREA NITROGEN       42.000000
# 68356046     potassium_mmol/l_plasma            POTASSIUM        5.136107
# 68356047     creatinine_mg/dl_plasma           CREATININE        2.339546
# 68356048  anion gap_null_no specimen            Anion gap        9.000000
# 68356049        calcium_mg/dl_plasma              calcium        8.432028
#
#          Result textual Result range Result units Specimen source     State
# 0                  None    1.0 - 3.7         K/uL           blood   Florida
# 1                  None    0.4 - 7.6            %           blood   Florida
# 2                  None  25.5 - 33.6           pg           blood   Florida
# 3                  None  30.9 - 35.1         g/dL            None   Florida
# 4                  None   4.0 - 10.6         K/uL           blood   Florida
# ...                 ...          ...          ...             ...       ...
# 68356045           None     7.0 - 21        mg/dL          plasma  Michigan
# 68356046           None    3.5 - 4.7       mmol/L          plasma  Michigan
# 68356047           None   .67 - 1.17        mg/dL          plasma  Michigan
# 68356048           None      10 - 20         None            None  Michigan
# 68356049           None   8.5 - 10.1        mg/dL          plasma  Michigan
#
# [68356050 rows x 12 columns]

# %% [markdown]
# # Importing the library

# %%
import numpy as np                # Multi-Dimensional array object
import pandas as pd               # Data Manipulation
import matplotlib.pyplot as plt   # Data Visualization
import seaborn as sns             # Data Visualization 

# Allows the use of display() for DataFrames
from IPython.display import display 

# Handle warning messages that may occur during code execution
import warnings
warnings.filterwarnings('ignore')

# To increase memory allocation
from notebook.services.config import ConfigManager
cm = ConfigManager().update('notebook', {'max_buffer_size': 7294967296})

# Set the maximum number of rows to be displayed to 1000
pd.set_option('display.max_rows', 1163)

# %% [markdown]
# # Elimination of the unnamed columns

# %%
# Remove unwanted columns 
lab_train_data.drop('Column1',axis=1,inplace=True)

# %%
lab_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68356050 entries, 0 to 68356049
# Data columns (total 11 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Internalpatientid     int64
#  1   Age at lab test       float64
#  2   Lab test date         datetime64[ns]
#  3   Lab test              object
#  4   Lab test description  object
#  5   Result numeric        float64
#  6   Result textual        object
#  7   Result range          object
#  8   Result units          object
#  9   Specimen source       object
#  10  State                 object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(7)
# memory usage: 5.6+ GB

# %% [markdown]
# # Sorting out patients id and age column

# %%
# Sort the dataset based on the patientsid and 'age' column in ascending order
lab_train_data.sort_values(["Internalpatientid","Age at lab test"],inplace=True)

# %%
lab_train_data
# Out:
#           Internalpatientid  Age at lab test       Lab test date  \
# 6739711                   6         74.84225 2001-07-10 20:13:05
# 6739712                   6         74.84225 2001-07-10 20:13:05
# 6739713                   6         74.84225 2001-07-10 20:13:05
# 6739714                   6         74.84225 2001-07-10 20:13:05
# 6739715                   6         74.84225 2001-07-10 20:13:05
# ...                     ...              ...                 ...
# 51731557             169065         53.31840 2011-06-10 21:00:09
# 51731558             169065         53.31840 2011-06-10 21:00:09
# 51731559             169065         53.31840 2011-06-10 21:00:09
# 51731560             169065         53.31840 2011-06-10 21:00:09
# 51731561             169065         53.31840 2011-06-10 21:00:09
#
#                                       Lab test Lab test description  \
# 6739711              baso #_k/cumm_no specimen               BASO #
# 6739712                            hct_%_blood                  Hct
# 6739713                        rbc_m/cmm_blood                  RBC
# 6739714               eos #_k/cumm_no specimen                EOS #
# 6739715                   neut %_%_no specimen               Neut %
# ...                                        ...                  ...
# 51731557    po2(t) (rapidlab)_mmhg_no specimen    pO2(T) (RAPIDLAB)
# 51731558  glucose (rapidlab)_mg/dl_no specimen   GLUCOSE (RAPIDLAB)
# 51731559        ph (rapidlab)_null_no specimen        pH (RAPIDLAB)
# 51731560         fio2 (rapidlab)_%_no specimen      FiO2 (RAPIDLAB)
# 51731561       fmethb (rapidlab)_%_no specimen    FMetHb (RAPIDLAB)
#
#           Result numeric Result textual Result range Result units  \
# 6739711         0.097043           None       0 - .5       k/cumm
# 6739712        39.104958           None      42 - 52            %
# 6739713         4.538197           None    4.7 - 6.1        M/cmm
# 6739714         0.196141           None        0 - 7       K/cumm
# 6739715        60.180934           None      37 - 73            %
# ...                  ...            ...          ...          ...
# 51731557      106.638117           None  70.0 - 90.0         mmHg
# 51731558      109.000000           None     60 - 105        mg/dL
# 51731559        7.413492           None  7.35 - 7.45         None
# 51731560       50.000000           None         None            %
# 51731561        0.409584           None         None            %
#
#          Specimen source    State
# 6739711             None    Texas
# 6739712            blood    Texas
# 6739713            blood    Texas
# 6739714             None    Texas
# 6739715             None    Texas
# ...                  ...      ...
# 51731557            None  Arizona
# 51731558            None  Arizona
# 51731559            None  Arizona
# 51731560            None  Arizona
# 51731561            None  Arizona
#
# [68356050 rows x 11 columns]

# %% [markdown]
# # Round off the "Result numeric" columns with 2 digits

# %%
lab_train_data['Result numeric'] = lab_train_data['Result numeric'].apply(lambda x: round(x,2))

# %%
lab_train_data
# Out:
#           Internalpatientid  Age at lab test       Lab test date  \
# 6739711                   6         74.84225 2001-07-10 20:13:05
# 6739712                   6         74.84225 2001-07-10 20:13:05
# 6739713                   6         74.84225 2001-07-10 20:13:05
# 6739714                   6         74.84225 2001-07-10 20:13:05
# 6739715                   6         74.84225 2001-07-10 20:13:05
# ...                     ...              ...                 ...
# 51731557             169065         53.31840 2011-06-10 21:00:09
# 51731558             169065         53.31840 2011-06-10 21:00:09
# 51731559             169065         53.31840 2011-06-10 21:00:09
# 51731560             169065         53.31840 2011-06-10 21:00:09
# 51731561             169065         53.31840 2011-06-10 21:00:09
#
#                                       Lab test Lab test description  \
# 6739711              baso #_k/cumm_no specimen               BASO #
# 6739712                            hct_%_blood                  Hct
# 6739713                        rbc_m/cmm_blood                  RBC
# 6739714               eos #_k/cumm_no specimen                EOS #
# 6739715                   neut %_%_no specimen               Neut %
# ...                                        ...                  ...
# 51731557    po2(t) (rapidlab)_mmhg_no specimen    pO2(T) (RAPIDLAB)
# 51731558  glucose (rapidlab)_mg/dl_no specimen   GLUCOSE (RAPIDLAB)
# 51731559        ph (rapidlab)_null_no specimen        pH (RAPIDLAB)
# 51731560         fio2 (rapidlab)_%_no specimen      FiO2 (RAPIDLAB)
# 51731561       fmethb (rapidlab)_%_no specimen    FMetHb (RAPIDLAB)
#
#           Result numeric Result textual Result range Result units  \
# 6739711             0.10           None       0 - .5       k/cumm
# 6739712            39.10           None      42 - 52            %
# 6739713             4.54           None    4.7 - 6.1        M/cmm
# 6739714             0.20           None        0 - 7       K/cumm
# 6739715            60.18           None      37 - 73            %
# ...                  ...            ...          ...          ...
# 51731557          106.64           None  70.0 - 90.0         mmHg
# 51731558          109.00           None     60 - 105        mg/dL
# 51731559            7.41           None  7.35 - 7.45         None
# 51731560           50.00           None         None            %
# 51731561            0.41           None         None            %
#
#          Specimen source    State
# 6739711             None    Texas
# 6739712            blood    Texas
# 6739713            blood    Texas
# 6739714             None    Texas
# 6739715             None    Texas
# ...                  ...      ...
# 51731557            None  Arizona
# 51731558            None  Arizona
# 51731559            None  Arizona
# 51731560            None  Arizona
# 51731561            None  Arizona
#
# [68356050 rows x 11 columns]

# %%
#checking the missing values
print("Training set missing values:\n", lab_train_data.isna().sum())
# Out:
# Training set missing values:
#  Internalpatientid              0
# Age at lab test                0
# Lab test date                  0
# Lab test                       0
# Lab test description           0
# Result numeric           8529467
# Result textual          59854531
# Result range            12856109
# Result units             8265710
# Specimen source         29142239
# State                          0
# dtype: int64

# %% [markdown]
# # Replace NaN values in "Result numeric" with corresponding values from "Result textual"

# %%
# Replace NaN values in "Result numeric" with corresponding values from "Result textual"
lab_train_data['Result'] = lab_train_data['Result numeric'].fillna(lab_train_data['Result textual'])

# Print the updated DataFrame
lab_train_data
# Out:
#           Internalpatientid  Age at lab test       Lab test date  \
# 6739711                   6         74.84225 2001-07-10 20:13:05
# 6739712                   6         74.84225 2001-07-10 20:13:05
# 6739713                   6         74.84225 2001-07-10 20:13:05
# 6739714                   6         74.84225 2001-07-10 20:13:05
# 6739715                   6         74.84225 2001-07-10 20:13:05
# ...                     ...              ...                 ...
# 51731557             169065         53.31840 2011-06-10 21:00:09
# 51731558             169065         53.31840 2011-06-10 21:00:09
# 51731559             169065         53.31840 2011-06-10 21:00:09
# 51731560             169065         53.31840 2011-06-10 21:00:09
# 51731561             169065         53.31840 2011-06-10 21:00:09
#
#                                       Lab test Lab test description  \
# 6739711              baso #_k/cumm_no specimen               BASO #
# 6739712                            hct_%_blood                  Hct
# 6739713                        rbc_m/cmm_blood                  RBC
# 6739714               eos #_k/cumm_no specimen                EOS #
# 6739715                   neut %_%_no specimen               Neut %
# ...                                        ...                  ...
# 51731557    po2(t) (rapidlab)_mmhg_no specimen    pO2(T) (RAPIDLAB)
# 51731558  glucose (rapidlab)_mg/dl_no specimen   GLUCOSE (RAPIDLAB)
# 51731559        ph (rapidlab)_null_no specimen        pH (RAPIDLAB)
# 51731560         fio2 (rapidlab)_%_no specimen      FiO2 (RAPIDLAB)
# 51731561       fmethb (rapidlab)_%_no specimen    FMetHb (RAPIDLAB)
#
#           Result numeric Result textual Result range Result units  \
# 6739711             0.10           None       0 - .5       k/cumm
# 6739712            39.10           None      42 - 52            %
# 6739713             4.54           None    4.7 - 6.1        M/cmm
# 6739714             0.20           None        0 - 7       K/cumm
# 6739715            60.18           None      37 - 73            %
# ...                  ...            ...          ...          ...
# 51731557          106.64           None  70.0 - 90.0         mmHg
# 51731558          109.00           None     60 - 105        mg/dL
# 51731559            7.41           None  7.35 - 7.45         None
# 51731560           50.00           None         None            %
# 51731561            0.41           None         None            %
#
#          Specimen source    State  Result
# 6739711             None    Texas     0.1
# 6739712            blood    Texas    39.1
# 6739713            blood    Texas    4.54
# 6739714             None    Texas     0.2
# 6739715             None    Texas   60.18
# ...                  ...      ...     ...
# 51731557            None  Arizona  106.64
# 51731558            None  Arizona     109
# 51731559            None  Arizona    7.41
# 51731560            None  Arizona      50
# 51731561            None  Arizona    0.41
#
# [68356050 rows x 12 columns]

# %%
# Check for missing or NaN values in the 'Result' column(before)
missing_data = lab_train_data['Result'].isnull().sum()


if missing_data > 0:
    print(f"There are {missing_data} missing or NaN values in the 'Result' column.")
else:
    print("No missing or NaN values found in the 'Result' column.")
# Out:
# There are 27948 missing or NaN values in the 'Result' column.

# %% [markdown]
# * **Since both "Result Numeric" and "Result Textual" are missing, we may really consider that value to be empty in the "Result"**( Actual test results are not available.)

# %%
# Remove rows missing values in the "result" column
lab_train_data.dropna(subset=["Result"],inplace=True)

# %%
lab_train_data = lab_train_data

# %%
lab_train_data
# Out:
#           Internalpatientid  Age at lab test       Lab test date  \
# 6739711                   6         74.84225 2001-07-10 20:13:05
# 6739712                   6         74.84225 2001-07-10 20:13:05
# 6739713                   6         74.84225 2001-07-10 20:13:05
# 6739714                   6         74.84225 2001-07-10 20:13:05
# 6739715                   6         74.84225 2001-07-10 20:13:05
# ...                     ...              ...                 ...
# 51731557             169065         53.31840 2011-06-10 21:00:09
# 51731558             169065         53.31840 2011-06-10 21:00:09
# 51731559             169065         53.31840 2011-06-10 21:00:09
# 51731560             169065         53.31840 2011-06-10 21:00:09
# 51731561             169065         53.31840 2011-06-10 21:00:09
#
#                                       Lab test Lab test description  \
# 6739711              baso #_k/cumm_no specimen               BASO #
# 6739712                            hct_%_blood                  Hct
# 6739713                        rbc_m/cmm_blood                  RBC
# 6739714               eos #_k/cumm_no specimen                EOS #
# 6739715                   neut %_%_no specimen               Neut %
# ...                                        ...                  ...
# 51731557    po2(t) (rapidlab)_mmhg_no specimen    pO2(T) (RAPIDLAB)
# 51731558  glucose (rapidlab)_mg/dl_no specimen   GLUCOSE (RAPIDLAB)
# 51731559        ph (rapidlab)_null_no specimen        pH (RAPIDLAB)
# 51731560         fio2 (rapidlab)_%_no specimen      FiO2 (RAPIDLAB)
# 51731561       fmethb (rapidlab)_%_no specimen    FMetHb (RAPIDLAB)
#
#           Result numeric Result textual Result range Result units  \
# 6739711             0.10           None       0 - .5       k/cumm
# 6739712            39.10           None      42 - 52            %
# 6739713             4.54           None    4.7 - 6.1        M/cmm
# 6739714             0.20           None        0 - 7       K/cumm
# 6739715            60.18           None      37 - 73            %
# ...                  ...            ...          ...          ...
# 51731557          106.64           None  70.0 - 90.0         mmHg
# 51731558          109.00           None     60 - 105        mg/dL
# 51731559            7.41           None  7.35 - 7.45         None
# 51731560           50.00           None         None            %
# 51731561            0.41           None         None            %
#
#          Specimen source    State  Result
# 6739711             None    Texas     0.1
# 6739712            blood    Texas    39.1
# 6739713            blood    Texas    4.54
# 6739714             None    Texas     0.2
# 6739715             None    Texas   60.18
# ...                  ...      ...     ...
# 51731557            None  Arizona  106.64
# 51731558            None  Arizona     109
# 51731559            None  Arizona    7.41
# 51731560            None  Arizona      50
# 51731561            None  Arizona    0.41
#
# [68328102 rows x 12 columns]

# %%
# Check for missing or NaN values in the 'Result' column(after removing)
missing_data = lab_train_data['Result'].isnull().sum()


if missing_data > 0:
    print(f"There are {missing_data} missing or NaN values in the 'Result' column.")
else:
    print("No missing or NaN values found in the 'Result' column.")
# Out:
# No missing or NaN values found in the 'Result' column.

# %% [markdown]
# * **Missing values has been removed from the "Result" column**

# %% [markdown]
# # Taking the three digits in age column

# %%
# Format 'Age at lab test' values in the format 00.00
lab_train_data["Age at lab test"] =lab_train_data["Age at lab test"].map("{:.3f}".format)

# %%
lab_train_data
# Out:
#           Internalpatientid Age at lab test       Lab test date  \
# 6739711                   6          74.842 2001-07-10 20:13:05
# 6739712                   6          74.842 2001-07-10 20:13:05
# 6739713                   6          74.842 2001-07-10 20:13:05
# 6739714                   6          74.842 2001-07-10 20:13:05
# 6739715                   6          74.842 2001-07-10 20:13:05
# ...                     ...             ...                 ...
# 51731557             169065          53.318 2011-06-10 21:00:09
# 51731558             169065          53.318 2011-06-10 21:00:09
# 51731559             169065          53.318 2011-06-10 21:00:09
# 51731560             169065          53.318 2011-06-10 21:00:09
# 51731561             169065          53.318 2011-06-10 21:00:09
#
#                                       Lab test Lab test description  \
# 6739711              baso #_k/cumm_no specimen               BASO #
# 6739712                            hct_%_blood                  Hct
# 6739713                        rbc_m/cmm_blood                  RBC
# 6739714               eos #_k/cumm_no specimen                EOS #
# 6739715                   neut %_%_no specimen               Neut %
# ...                                        ...                  ...
# 51731557    po2(t) (rapidlab)_mmhg_no specimen    pO2(T) (RAPIDLAB)
# 51731558  glucose (rapidlab)_mg/dl_no specimen   GLUCOSE (RAPIDLAB)
# 51731559        ph (rapidlab)_null_no specimen        pH (RAPIDLAB)
# 51731560         fio2 (rapidlab)_%_no specimen      FiO2 (RAPIDLAB)
# 51731561       fmethb (rapidlab)_%_no specimen    FMetHb (RAPIDLAB)
#
#           Result numeric Result textual Result range Result units  \
# 6739711             0.10           None       0 - .5       k/cumm
# 6739712            39.10           None      42 - 52            %
# 6739713             4.54           None    4.7 - 6.1        M/cmm
# 6739714             0.20           None        0 - 7       K/cumm
# 6739715            60.18           None      37 - 73            %
# ...                  ...            ...          ...          ...
# 51731557          106.64           None  70.0 - 90.0         mmHg
# 51731558          109.00           None     60 - 105        mg/dL
# 51731559            7.41           None  7.35 - 7.45         None
# 51731560           50.00           None         None            %
# 51731561            0.41           None         None            %
#
#          Specimen source    State  Result
# 6739711             None    Texas     0.1
# 6739712            blood    Texas    39.1
# 6739713            blood    Texas    4.54
# 6739714             None    Texas     0.2
# 6739715             None    Texas   60.18
# ...                  ...      ...     ...
# 51731557            None  Arizona  106.64
# 51731558            None  Arizona     109
# 51731559            None  Arizona    7.41
# 51731560            None  Arizona      50
# 51731561            None  Arizona    0.41
#
# [68328102 rows x 12 columns]

# %% [markdown]
# # Taking the Max age

# %%
# Find the latest record for each internal patient id
max_ages = lab_train_data.groupby('Internalpatientid')['Age at lab test'].max().reset_index()

# Merge with the original dataframe to get the rows with the highest age
lab_train_data = pd.merge(lab_train_data, max_ages, on =['Internalpatientid','Age at lab test'], how = 'inner')

lab_train_data
# Out:
#         Internalpatientid Age at lab test       Lab test date  \
# 0                       6          87.815 2014-07-04 12:23:03
# 1                       6          87.815 2014-07-04 12:23:03
# 2                       7          74.156 2020-09-04 21:15:42
# 3                       7          74.156 2020-09-04 21:15:42
# 4                       7          74.156 2020-09-04 21:15:42
# ...                   ...             ...                 ...
# 900143             169065          53.318 2011-06-10 21:00:09
# 900144             169065          53.318 2011-06-10 21:00:09
# 900145             169065          53.318 2011-06-10 21:00:09
# 900146             169065          53.318 2011-06-10 21:00:09
# 900147             169065          53.318 2011-06-10 21:00:09
#
#                                          Lab test  \
# 0           fingerstick inr (coaguchek)_inr_blood
# 1       fingerstick protime (coaguchek)_sec_blood
# 2                            rbc_m/ul_no specimen
# 3                   abs monocyte_k/ul_no specimen
# 4                        basophil %_%_no specimen
# ...                                           ...
# 900143         po2(t) (rapidlab)_mmhg_no specimen
# 900144       glucose (rapidlab)_mg/dl_no specimen
# 900145             ph (rapidlab)_null_no specimen
# 900146              fio2 (rapidlab)_%_no specimen
# 900147            fmethb (rapidlab)_%_no specimen
#
#                    Lab test description  Result numeric Result textual  \
# 0           FINGERSTICK INR (COAGUCHEK)            2.57           None
# 1       FINGERSTICK PROTIME (COAGUCHEK)           29.00           None
# 2                                   RBC            4.79           None
# 3                          ABS MONOCYTE            0.71           None
# 4                            BASOPHIL %            0.29           None
# ...                                 ...             ...            ...
# 900143                pO2(T) (RAPIDLAB)          106.64           None
# 900144               GLUCOSE (RAPIDLAB)          109.00           None
# 900145                    pH (RAPIDLAB)            7.41           None
# 900146                  FiO2 (RAPIDLAB)           50.00           None
# 900147                FMetHb (RAPIDLAB)            0.41           None
#
#        Result range Result units Specimen source     State  Result
# 0         0.9 - 4.4          INR           blood     Texas    2.57
# 1              None          SEC           blood     Texas      29
# 2         4.0 - 6.0         M/uL            None  Nebraska    4.79
# 3         0.2 - 1.1         K/uL            None  Nebraska    0.71
# 4         0.0 - 1.0            %            None  Nebraska    0.29
# ...             ...          ...             ...       ...     ...
# 900143  70.0 - 90.0         mmHg            None   Arizona  106.64
# 900144     60 - 105        mg/dL            None   Arizona     109
# 900145  7.35 - 7.45         None            None   Arizona    7.41
# 900146         None            %            None   Arizona      50
# 900147         None            %            None   Arizona    0.41
#
# [900148 rows x 12 columns]

# %%
# Convert 'Age at lab test' column from object to float
lab_train_data["Age at lab test"] = lab_train_data["Age at lab test"].astype(float)

# %%
lab_train_data
# Out:
#         Internalpatientid  Age at lab test       Lab test date  \
# 0                       6           87.815 2014-07-04 12:23:03
# 1                       6           87.815 2014-07-04 12:23:03
# 2                       7           74.156 2020-09-04 21:15:42
# 3                       7           74.156 2020-09-04 21:15:42
# 4                       7           74.156 2020-09-04 21:15:42
# ...                   ...              ...                 ...
# 900143             169065           53.318 2011-06-10 21:00:09
# 900144             169065           53.318 2011-06-10 21:00:09
# 900145             169065           53.318 2011-06-10 21:00:09
# 900146             169065           53.318 2011-06-10 21:00:09
# 900147             169065           53.318 2011-06-10 21:00:09
#
#                                          Lab test  \
# 0           fingerstick inr (coaguchek)_inr_blood
# 1       fingerstick protime (coaguchek)_sec_blood
# 2                            rbc_m/ul_no specimen
# 3                   abs monocyte_k/ul_no specimen
# 4                        basophil %_%_no specimen
# ...                                           ...
# 900143         po2(t) (rapidlab)_mmhg_no specimen
# 900144       glucose (rapidlab)_mg/dl_no specimen
# 900145             ph (rapidlab)_null_no specimen
# 900146              fio2 (rapidlab)_%_no specimen
# 900147            fmethb (rapidlab)_%_no specimen
#
#                    Lab test description  Result numeric Result textual  \
# 0           FINGERSTICK INR (COAGUCHEK)            2.57           None
# 1       FINGERSTICK PROTIME (COAGUCHEK)           29.00           None
# 2                                   RBC            4.79           None
# 3                          ABS MONOCYTE            0.71           None
# 4                            BASOPHIL %            0.29           None
# ...                                 ...             ...            ...
# 900143                pO2(T) (RAPIDLAB)          106.64           None
# 900144               GLUCOSE (RAPIDLAB)          109.00           None
# 900145                    pH (RAPIDLAB)            7.41           None
# 900146                  FiO2 (RAPIDLAB)           50.00           None
# 900147                FMetHb (RAPIDLAB)            0.41           None
#
#        Result range Result units Specimen source     State  Result
# 0         0.9 - 4.4          INR           blood     Texas    2.57
# 1              None          SEC           blood     Texas      29
# 2         4.0 - 6.0         M/uL            None  Nebraska    4.79
# 3         0.2 - 1.1         K/uL            None  Nebraska    0.71
# 4         0.0 - 1.0            %            None  Nebraska    0.29
# ...             ...          ...             ...       ...     ...
# 900143  70.0 - 90.0         mmHg            None   Arizona  106.64
# 900144     60 - 105        mg/dL            None   Arizona     109
# 900145  7.35 - 7.45         None            None   Arizona    7.41
# 900146         None            %            None   Arizona      50
# 900147         None            %            None   Arizona    0.41
#
# [900148 rows x 12 columns]

# %% [markdown]
# # Round off the Age column

# %%
lab_train_data['Age at lab test'] = lab_train_data['Age at lab test'].apply(lambda x: round(x,))

# %%
lab_train_data
# Out:
#         Internalpatientid  Age at lab test       Lab test date  \
# 0                       6               88 2014-07-04 12:23:03
# 1                       6               88 2014-07-04 12:23:03
# 2                       7               74 2020-09-04 21:15:42
# 3                       7               74 2020-09-04 21:15:42
# 4                       7               74 2020-09-04 21:15:42
# ...                   ...              ...                 ...
# 900143             169065               53 2011-06-10 21:00:09
# 900144             169065               53 2011-06-10 21:00:09
# 900145             169065               53 2011-06-10 21:00:09
# 900146             169065               53 2011-06-10 21:00:09
# 900147             169065               53 2011-06-10 21:00:09
#
#                                          Lab test  \
# 0           fingerstick inr (coaguchek)_inr_blood
# 1       fingerstick protime (coaguchek)_sec_blood
# 2                            rbc_m/ul_no specimen
# 3                   abs monocyte_k/ul_no specimen
# 4                        basophil %_%_no specimen
# ...                                           ...
# 900143         po2(t) (rapidlab)_mmhg_no specimen
# 900144       glucose (rapidlab)_mg/dl_no specimen
# 900145             ph (rapidlab)_null_no specimen
# 900146              fio2 (rapidlab)_%_no specimen
# 900147            fmethb (rapidlab)_%_no specimen
#
#                    Lab test description  Result numeric Result textual  \
# 0           FINGERSTICK INR (COAGUCHEK)            2.57           None
# 1       FINGERSTICK PROTIME (COAGUCHEK)           29.00           None
# 2                                   RBC            4.79           None
# 3                          ABS MONOCYTE            0.71           None
# 4                            BASOPHIL %            0.29           None
# ...                                 ...             ...            ...
# 900143                pO2(T) (RAPIDLAB)          106.64           None
# 900144               GLUCOSE (RAPIDLAB)          109.00           None
# 900145                    pH (RAPIDLAB)            7.41           None
# 900146                  FiO2 (RAPIDLAB)           50.00           None
# 900147                FMetHb (RAPIDLAB)            0.41           None
#
#        Result range Result units Specimen source     State  Result
# 0         0.9 - 4.4          INR           blood     Texas    2.57
# 1              None          SEC           blood     Texas      29
# 2         4.0 - 6.0         M/uL            None  Nebraska    4.79
# 3         0.2 - 1.1         K/uL            None  Nebraska    0.71
# 4         0.0 - 1.0            %            None  Nebraska    0.29
# ...             ...          ...             ...       ...     ...
# 900143  70.0 - 90.0         mmHg            None   Arizona  106.64
# 900144     60 - 105        mg/dL            None   Arizona     109
# 900145  7.35 - 7.45         None            None   Arizona    7.41
# 900146         None            %            None   Arizona      50
# 900147         None            %            None   Arizona    0.41
#
# [900148 rows x 12 columns]

# %%
lab_train_data["Internalpatientid"].nunique()
# Out:
# 34055

# %%
df_3 = lab_train_data["Internalpatientid"].value_counts().loc[lambda x: x>80].to_frame()

# %%
df = df_3.reset_index()

# %%
df.columns = ["Internalpatientid","count"]

# %%
df.drop(["count"],axis=1,inplace =True)

# %%
df = df

# %%
len(df)
# Out:
# 421

# %%
# Merge the two dataframes based on 'Internalpatientid'
merged_df = lab_train_data.merge(df, on='Internalpatientid', how='left')

# Filter rows from DataFrame 1 that have matching values in DataFrame 2
filtered_df = merged_df[~merged_df['Internalpatientid'].isin(df['Internalpatientid'])]

# Print only the columns of DataFrame 1
filtered_df
# Out:
#         Internalpatientid  Age at lab test       Lab test date  \
# 0                       6               88 2014-07-04 12:23:03
# 1                       6               88 2014-07-04 12:23:03
# 2                       7               74 2020-09-04 21:15:42
# 3                       7               74 2020-09-04 21:15:42
# 4                       7               74 2020-09-04 21:15:42
# ...                   ...              ...                 ...
# 900143             169065               53 2011-06-10 21:00:09
# 900144             169065               53 2011-06-10 21:00:09
# 900145             169065               53 2011-06-10 21:00:09
# 900146             169065               53 2011-06-10 21:00:09
# 900147             169065               53 2011-06-10 21:00:09
#
#                                          Lab test  \
# 0           fingerstick inr (coaguchek)_inr_blood
# 1       fingerstick protime (coaguchek)_sec_blood
# 2                            rbc_m/ul_no specimen
# 3                   abs monocyte_k/ul_no specimen
# 4                        basophil %_%_no specimen
# ...                                           ...
# 900143         po2(t) (rapidlab)_mmhg_no specimen
# 900144       glucose (rapidlab)_mg/dl_no specimen
# 900145             ph (rapidlab)_null_no specimen
# 900146              fio2 (rapidlab)_%_no specimen
# 900147            fmethb (rapidlab)_%_no specimen
#
#                    Lab test description  Result numeric Result textual  \
# 0           FINGERSTICK INR (COAGUCHEK)            2.57           None
# 1       FINGERSTICK PROTIME (COAGUCHEK)           29.00           None
# 2                                   RBC            4.79           None
# 3                          ABS MONOCYTE            0.71           None
# 4                            BASOPHIL %            0.29           None
# ...                                 ...             ...            ...
# 900143                pO2(T) (RAPIDLAB)          106.64           None
# 900144               GLUCOSE (RAPIDLAB)          109.00           None
# 900145                    pH (RAPIDLAB)            7.41           None
# 900146                  FiO2 (RAPIDLAB)           50.00           None
# 900147                FMetHb (RAPIDLAB)            0.41           None
#
#        Result range Result units Specimen source     State  Result
# 0         0.9 - 4.4          INR           blood     Texas    2.57
# 1              None          SEC           blood     Texas      29
# 2         4.0 - 6.0         M/uL            None  Nebraska    4.79
# 3         0.2 - 1.1         K/uL            None  Nebraska    0.71
# 4         0.0 - 1.0            %            None  Nebraska    0.29
# ...             ...          ...             ...       ...     ...
# 900143  70.0 - 90.0         mmHg            None   Arizona  106.64
# 900144     60 - 105        mg/dL            None   Arizona     109
# 900145  7.35 - 7.45         None            None   Arizona    7.41
# 900146         None            %            None   Arizona      50
# 900147         None            %            None   Arizona    0.41
#
# [860485 rows x 12 columns]

# %%
lab_train_data = filtered_df

# %%
lab_train_data
# Out:
#         Internalpatientid  Age at lab test       Lab test date  \
# 0                       6               88 2014-07-04 12:23:03
# 1                       6               88 2014-07-04 12:23:03
# 2                       7               74 2020-09-04 21:15:42
# 3                       7               74 2020-09-04 21:15:42
# 4                       7               74 2020-09-04 21:15:42
# ...                   ...              ...                 ...
# 900143             169065               53 2011-06-10 21:00:09
# 900144             169065               53 2011-06-10 21:00:09
# 900145             169065               53 2011-06-10 21:00:09
# 900146             169065               53 2011-06-10 21:00:09
# 900147             169065               53 2011-06-10 21:00:09
#
#                                          Lab test  \
# 0           fingerstick inr (coaguchek)_inr_blood
# 1       fingerstick protime (coaguchek)_sec_blood
# 2                            rbc_m/ul_no specimen
# 3                   abs monocyte_k/ul_no specimen
# 4                        basophil %_%_no specimen
# ...                                           ...
# 900143         po2(t) (rapidlab)_mmhg_no specimen
# 900144       glucose (rapidlab)_mg/dl_no specimen
# 900145             ph (rapidlab)_null_no specimen
# 900146              fio2 (rapidlab)_%_no specimen
# 900147            fmethb (rapidlab)_%_no specimen
#
#                    Lab test description  Result numeric Result textual  \
# 0           FINGERSTICK INR (COAGUCHEK)            2.57           None
# 1       FINGERSTICK PROTIME (COAGUCHEK)           29.00           None
# 2                                   RBC            4.79           None
# 3                          ABS MONOCYTE            0.71           None
# 4                            BASOPHIL %            0.29           None
# ...                                 ...             ...            ...
# 900143                pO2(T) (RAPIDLAB)          106.64           None
# 900144               GLUCOSE (RAPIDLAB)          109.00           None
# 900145                    pH (RAPIDLAB)            7.41           None
# 900146                  FiO2 (RAPIDLAB)           50.00           None
# 900147                FMetHb (RAPIDLAB)            0.41           None
#
#        Result range Result units Specimen source     State  Result
# 0         0.9 - 4.4          INR           blood     Texas    2.57
# 1              None          SEC           blood     Texas      29
# 2         4.0 - 6.0         M/uL            None  Nebraska    4.79
# 3         0.2 - 1.1         K/uL            None  Nebraska    0.71
# 4         0.0 - 1.0            %            None  Nebraska    0.29
# ...             ...          ...             ...       ...     ...
# 900143  70.0 - 90.0         mmHg            None   Arizona  106.64
# 900144     60 - 105        mg/dL            None   Arizona     109
# 900145  7.35 - 7.45         None            None   Arizona    7.41
# 900146         None            %            None   Arizona      50
# 900147         None            %            None   Arizona    0.41
#
# [860485 rows x 12 columns]

# %% [markdown]
# # Adding  "Age at lab test",'Lab test description' & 'Result (Result numeric & Result textual)' columns with '_'

# %%
#In this code, we create a new column called 'Lab test description_Result numeric' by concatenating the values of the 'lab test description' column, underscore ('_'), and the 'lab test results' column
#converted to a string using the `astype(str)` function(because we cant't add differnt dtype)
lab_train_data ['Lab_test_description_Result'] = lab_train_data['Age at lab test'].astype(str) + '_' +  lab_train_data['Lab test description'] + '_' +  lab_train_data['Result'].astype(str)

# %%
lab_train_data
# Out:
#         Internalpatientid  Age at lab test       Lab test date  \
# 0                       6               88 2014-07-04 12:23:03
# 1                       6               88 2014-07-04 12:23:03
# 2                       7               74 2020-09-04 21:15:42
# 3                       7               74 2020-09-04 21:15:42
# 4                       7               74 2020-09-04 21:15:42
# ...                   ...              ...                 ...
# 900143             169065               53 2011-06-10 21:00:09
# 900144             169065               53 2011-06-10 21:00:09
# 900145             169065               53 2011-06-10 21:00:09
# 900146             169065               53 2011-06-10 21:00:09
# 900147             169065               53 2011-06-10 21:00:09
#
#                                          Lab test  \
# 0           fingerstick inr (coaguchek)_inr_blood
# 1       fingerstick protime (coaguchek)_sec_blood
# 2                            rbc_m/ul_no specimen
# 3                   abs monocyte_k/ul_no specimen
# 4                        basophil %_%_no specimen
# ...                                           ...
# 900143         po2(t) (rapidlab)_mmhg_no specimen
# 900144       glucose (rapidlab)_mg/dl_no specimen
# 900145             ph (rapidlab)_null_no specimen
# 900146              fio2 (rapidlab)_%_no specimen
# 900147            fmethb (rapidlab)_%_no specimen
#
#                    Lab test description  Result numeric Result textual  \
# 0           FINGERSTICK INR (COAGUCHEK)            2.57           None
# 1       FINGERSTICK PROTIME (COAGUCHEK)           29.00           None
# 2                                   RBC            4.79           None
# 3                          ABS MONOCYTE            0.71           None
# 4                            BASOPHIL %            0.29           None
# ...                                 ...             ...            ...
# 900143                pO2(T) (RAPIDLAB)          106.64           None
# 900144               GLUCOSE (RAPIDLAB)          109.00           None
# 900145                    pH (RAPIDLAB)            7.41           None
# 900146                  FiO2 (RAPIDLAB)           50.00           None
# 900147                FMetHb (RAPIDLAB)            0.41           None
#
#        Result range Result units Specimen source     State  Result  \
# 0         0.9 - 4.4          INR           blood     Texas    2.57
# 1              None          SEC           blood     Texas      29
# 2         4.0 - 6.0         M/uL            None  Nebraska    4.79
# 3         0.2 - 1.1         K/uL            None  Nebraska    0.71
# 4         0.0 - 1.0            %            None  Nebraska    0.29
# ...             ...          ...             ...       ...     ...
# 900143  70.0 - 90.0         mmHg            None   Arizona  106.64
# 900144     60 - 105        mg/dL            None   Arizona     109
# 900145  7.35 - 7.45         None            None   Arizona    7.41
# 900146         None            %            None   Arizona      50
# 900147         None            %            None   Arizona    0.41
#
#                     Lab_test_description_Result
# 0           88_FINGERSTICK INR (COAGUCHEK)_2.57
# 1       88_FINGERSTICK PROTIME (COAGUCHEK)_29.0
# 2                                   74_RBC_4.79
# 3                          74_ABS MONOCYTE_0.71
# 4                            74_BASOPHIL %_0.29
# ...                                         ...
# 900143              53_pO2(T) (RAPIDLAB)_106.64
# 900144              53_GLUCOSE (RAPIDLAB)_109.0
# 900145                    53_pH (RAPIDLAB)_7.41
# 900146                  53_FiO2 (RAPIDLAB)_50.0
# 900147                53_FMetHb (RAPIDLAB)_0.41
#
# [860485 rows x 13 columns]

# %% [markdown]
# # Dropping all unnecessary columns

# %%
# Remove columns 
lab_train_data.drop(["Age at lab test","Lab test date","Lab test","Lab test description","Result numeric","Result textual",
                     "Result range","Result units","Specimen source","State","Result"], axis=1,inplace=True)

# %%
lab_train_data = lab_train_data

# %%
lab_train_data # After removing the unwanted column
# Out:
#         Internalpatientid              Lab_test_description_Result
# 0                       6      88_FINGERSTICK INR (COAGUCHEK)_2.57
# 1                       6  88_FINGERSTICK PROTIME (COAGUCHEK)_29.0
# 2                       7                              74_RBC_4.79
# 3                       7                     74_ABS MONOCYTE_0.71
# 4                       7                       74_BASOPHIL %_0.29
# ...                   ...                                      ...
# 900143             169065              53_pO2(T) (RAPIDLAB)_106.64
# 900144             169065              53_GLUCOSE (RAPIDLAB)_109.0
# 900145             169065                    53_pH (RAPIDLAB)_7.41
# 900146             169065                  53_FiO2 (RAPIDLAB)_50.0
# 900147             169065                53_FMetHb (RAPIDLAB)_0.41
#
# [860485 rows x 2 columns]

# %%
# Group the DataFrame by 'Internalpatientid' and concatenate the icd10 values and
#The purpose of `x.dropna()` is to remove any missing values from the Series before applying a subsequent operation,
# such as concatenation using the `join` function. By dropping the missing values,
#we ensure that only non-null values are included in the resulting concatenated string.
df_grouped = lab_train_data.groupby('Internalpatientid').agg(lambda x: ','.join(x.dropna()))
df_grouped 

# Reset the index of the grouped DataFrame
df_grouped_lab = df_grouped.reset_index()
df_grouped_lab
# Out:
#        Internalpatientid                        Lab_test_description_Result
# 0                      6  88_FINGERSTICK INR (COAGUCHEK)_2.57,88_FINGERS...
# 1                      7  74_RBC_4.79,74_ABS MONOCYTE_0.71,74_BASOPHIL %...
# 2                      9  52_Bands_3.0,52_RDW_21.2*,52_ZZZAUTO ANISO_++,...
# 3                     12  74_LDL-CHOL CALCULATION_69.74,74_SODIUM (blood...
# 4                     17  82_HCO3-_12.0,82_ICTERUS INDEX_2.0,82_SODIUM_1...
# ...                  ...                                                ...
# 33629             169037  88_Mch_30.38,88_RBC_4.2,88_WBC_6.91,88_RDW-CV_...
# 33630             169045  86_UREA NITROGEN_28.0,86_NON HDL CHOLESTEROL_1...
# 33631             169058  79_GLUCOSE,BLOOD-poct  (STL)_151.0,79_GLUCOSE,...
# 33632             169059  91_SODIUM_133.0,91_LDL CALCULATION_106.0,91_AL...
# 33633             169065  53_CALCIUM, IONIZED (RAPIDLAB)_1.32,53_pO2(T) ...
#
# [33634 rows x 2 columns]

# %%
df_grouped_lab["Lab_test_description_Result"].values[33632] # checking the one row
# Out:
# '91_SODIUM_133.0,91_LDL CALCULATION_106.0,91_ALBUMIN_3.73,91_POTASSIUM_4.04,91_GLUCOSE_106.0,91_CREATININE_1.0,91_TRIGLYCERIDE_235.0,91_CHOLESTEROL_214.0,91_BILIRUBIN, TOTAL_0.68,91_ALANINE AMINOTRANSFERASE_12.0,91_CARBON DIOXIDE_20.0,91_Anion gap_11.0,91_TSH_1.94,91_CHLORIDE_106.0,91_DIRECT HDL_53.0,91_eGFR_52.0,91_CALCIUM_9.44,91_UREA NITROGEN_26.0,91_TOTAL PROTEIN_7.79,91_ALKALINE PHOSPHATASE_52.0,91_ASPARTATE AMINOTRANSFERASE_16.0,91_NEUT %_57.85,91_Lymph %_29.3,91_LYMPH #_1.5,91_RDW_15.98,91_MCHC_32.34,91_RBC_4.09,91_NEUT #_3.0,91_BASO #_0.0,91_MONO #_0.3,91_MPV_10.08,91_EOS #_0.29,91_WBC_5.0,91_Eos %_5.29,91_Mono %_5.27,91_Hct_41.75,91_MCH_32.18,91_Baso %_0.52,91_PLATELET_191.0,91_MCV_98.7,91_Hgb_13.9'

# %% [markdown]
# # Saving the CSV file

# %%
# saving the csv file 

#df.to_csv('Path where you want to store the exported CSV file/File Name.csv')
df_grouped_lab.to_csv('/mnt/batch/tasks/shared/LS_root/mounts/clusters/team-3-susai-gpu2/code/Users/900379/Output_files_test/df_lab_results_test_with_age_v1.csv')
