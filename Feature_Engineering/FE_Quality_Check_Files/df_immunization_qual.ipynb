# %%
#A class attribute that provides access to the TabularDatasetFactory methods for creating new TabularDataset objects. 
#Usage: Dataset.Tabular.from_delimited_files().
from azureml.core import Workspace, Dataset

subscription_id = 'bcfe0c62-8ebe-4df0-a46d-1efcf8739a5b' #check the launch studio there will get this id
resource_group = 'VChamp-Team3' # resource group name
workspace_name = 'vchamp-team3' # worksapce name


# storage account : Algorithmia, Resource group: VChamp-Team3 and workspace: vchamp-team3.
#Constructor
workspace = Workspace(subscription_id, resource_group, workspace_name)

# %%
#['data_team3_synthetic_train']
datastore = workspace.datastores['data_team3_synthetic_quality_check']

# %%
#from_delimited_files (Create a TabularDataset to represent tabular data in delimited files (e.g. CSV and TSV).

dataset = Dataset.Tabular.from_delimited_files(path = [(datastore, 'immunization_qual.csv')])

# preview the first 3 rows of the dataset
# dataset.to_pandas_dataframe()

# %%
#Converting the dataset into data frame(default as dataset in Azure, thus we must convert the needed formate)
immunizations_train = dataset.to_pandas_dataframe()

# %%
immunizations_train
# Out:
#        Column1  Internalpatientid  Age at immunization   Immunization date  \
# 0          194             100229            68.021827 2000-09-25 23:27:52
# 1          195             100229            68.021827 2000-09-25 23:27:52
# 2          253             100314            64.986914 2011-07-04 17:12:36
# 3          302             100399            77.128884 2001-08-23 14:34:16
# 4          303             100399            78.234635 2002-10-01 18:13:15
# ...        ...                ...                  ...                 ...
# 13580  2346260              99143            90.632019 2012-01-15 00:04:27
# 13581  2346516               9947            67.200942 2010-10-16 22:39:38
# 13582  2346517               9947            67.200942 2010-10-16 22:39:38
# 13583  2346878              99941            76.400998 2018-12-19 13:33:08
# 13584  2346881              99944            80.397951 2012-12-01 10:49:45
#
#                                 Immunization Dose quantity Dose unit  \
# 0      PNEUMOCOCCAL, UNSPECIFIED FORMULATION          None      None
# 1         INFLUENZA, UNSPECIFIED FORMULATION          None      None
# 2         INFLUENZA, UNSPECIFIED FORMULATION          None      None
# 3         INFLUENZA, UNSPECIFIED FORMULATION          None      None
# 4          TD(ADULT) UNSPECIFIED FORMULATION          None      None
# ...                                      ...           ...       ...
# 13580     INFLUENZA, UNSPECIFIED FORMULATION          None      None
# 13581     INFLUENZA, UNSPECIFIED FORMULATION          None      None
# 13582                 INFLUENZA (HISTORICAL)          None      None
# 13583        INFLUENZA, SEASONAL, INJECTABLE          None      None
# 13584  PNEUMOCOCCAL, UNSPECIFIED FORMULATION          None      None
#
#       Administered elsewhere  Cvx code              Series doses  \
# 0                       None     109.0  Not specified (no value)
# 1                       None      88.0  Not specified (no value)
# 2                       None      88.0  Not specified (no value)
# 3                       None      88.0  Not specified (no value)
# 4                       None     139.0  Not specified (no value)
# ...                      ...       ...                       ...
# 13580                   None      88.0  Not specified (no value)
# 13581                   None      88.0  Not specified (no value)
# 13582                   None      88.0  Not specified (no value)
# 13583                   None     141.0  Not specified (no value)
# 13584                   None     109.0  Not specified (no value)
#
#                State
# 0            Arizona
# 1            Arizona
# 2           Missouri
# 3          Minnesota
# 4          Minnesota
# ...              ...
# 13580        Florida
# 13581           Ohio
# 13582           Ohio
# 13583          Maine
# 13584  Massachusetts
#
# [13585 rows x 11 columns]

# %%
import numpy as np                # Multi-Dimensional array object
import pandas as pd               # Data Manipulation
import matplotlib.pyplot as plt   # Data Visualization
import seaborn as sns             # Data Visualization 

# Allows the use of display() for DataFrames
from IPython.display import display 

# Handle warning messages that may occur during code execution
import warnings
warnings.filterwarnings('ignore')

# To increase memory allocation
from notebook.services.config import ConfigManager
cm = ConfigManager().update('notebook', {'max_buffer_size': 7294967296})

# Set the maximum number of rows to be displayed to 1000
pd.set_option('display.max_rows', 1163)

# %% [markdown]
# # Elimination of the unnamed columns

# %%
# Remove unwanted columns 
immunizations_train.drop('Column1',axis=1,inplace=True)

# %%
immunizations_train = immunizations_train

# %%
immunizations_train
# Out:
#        Internalpatientid  Age at immunization   Immunization date  \
# 0                 100229            68.021827 2000-09-25 23:27:52
# 1                 100229            68.021827 2000-09-25 23:27:52
# 2                 100314            64.986914 2011-07-04 17:12:36
# 3                 100399            77.128884 2001-08-23 14:34:16
# 4                 100399            78.234635 2002-10-01 18:13:15
# ...                  ...                  ...                 ...
# 13580              99143            90.632019 2012-01-15 00:04:27
# 13581               9947            67.200942 2010-10-16 22:39:38
# 13582               9947            67.200942 2010-10-16 22:39:38
# 13583              99941            76.400998 2018-12-19 13:33:08
# 13584              99944            80.397951 2012-12-01 10:49:45
#
#                                 Immunization Dose quantity Dose unit  \
# 0      PNEUMOCOCCAL, UNSPECIFIED FORMULATION          None      None
# 1         INFLUENZA, UNSPECIFIED FORMULATION          None      None
# 2         INFLUENZA, UNSPECIFIED FORMULATION          None      None
# 3         INFLUENZA, UNSPECIFIED FORMULATION          None      None
# 4          TD(ADULT) UNSPECIFIED FORMULATION          None      None
# ...                                      ...           ...       ...
# 13580     INFLUENZA, UNSPECIFIED FORMULATION          None      None
# 13581     INFLUENZA, UNSPECIFIED FORMULATION          None      None
# 13582                 INFLUENZA (HISTORICAL)          None      None
# 13583        INFLUENZA, SEASONAL, INJECTABLE          None      None
# 13584  PNEUMOCOCCAL, UNSPECIFIED FORMULATION          None      None
#
#       Administered elsewhere  Cvx code              Series doses  \
# 0                       None     109.0  Not specified (no value)
# 1                       None      88.0  Not specified (no value)
# 2                       None      88.0  Not specified (no value)
# 3                       None      88.0  Not specified (no value)
# 4                       None     139.0  Not specified (no value)
# ...                      ...       ...                       ...
# 13580                   None      88.0  Not specified (no value)
# 13581                   None      88.0  Not specified (no value)
# 13582                   None      88.0  Not specified (no value)
# 13583                   None     141.0  Not specified (no value)
# 13584                   None     109.0  Not specified (no value)
#
#                State
# 0            Arizona
# 1            Arizona
# 2           Missouri
# 3          Minnesota
# 4          Minnesota
# ...              ...
# 13580        Florida
# 13581           Ohio
# 13582           Ohio
# 13583          Maine
# 13584  Massachusetts
#
# [13585 rows x 10 columns]

# %%
immunizations_train["Internalpatientid"].nunique()
# Out:
# 939

# %% [markdown]
# # sorting out patients id and age column

# %%
# Sort the dataset based on the patientsid and 'age' column in ascending order
immunizations_train.sort_values(["Internalpatientid","Age at immunization"],inplace=True)

# %%
immunizations_train
# Out:
#        Internalpatientid  Age at immunization   Immunization date  \
# 12616                 67            48.284719 2010-08-10 01:33:24
# 12617                 67            48.284719 2010-08-10 01:33:24
# 9187                  67            48.305034 2010-08-17 11:45:26
# 9051                  67            49.301203 2011-08-16 14:09:21
# 8450                  67            49.940158 2012-04-06 03:03:52
# ...                  ...                  ...                 ...
# 5347              168899            89.554915 2012-05-17 07:42:45
# 5342              168899            90.568326 2013-05-22 17:21:10
# 11202             168899            92.401948 2015-03-23 21:53:17
# 10848             168899            93.483974 2016-04-22 09:24:59
# 10849             168899            93.483974 2016-04-22 09:24:59
#
#                                             Immunization Dose quantity  \
# 12616                             FLU,3 YRS (HISTORICAL)          None
# 12617   TDAP (Tetanus,Diphtheria,Pertussis) (HISTORICAL)          None
# 9187               PNEUMOCOCCAL, UNSPECIFIED FORMULATION          None
# 9051                              FLU,3 YRS (HISTORICAL)          None
# 8450                              FLU,3 YRS (HISTORICAL)          None
# ...                                                  ...           ...
# 5347                              FLU,3 YRS (HISTORICAL)          None
# 5342                              FLU,3 YRS (HISTORICAL)          None
# 11202                             FLU,3 YRS (HISTORICAL)          None
# 10848                      PNEUMOCOCCAL CONJUGATE PCV 13          None
# 10849  INFLUENZA, SEASONAL, INJECTABLE, PRESERVATIVE ...          None
#
#       Dose unit Administered elsewhere  Cvx code              Series doses  \
# 12616      None                   None      88.0  Not specified (no value)
# 12617      None                   None     115.0  Not specified (no value)
# 9187       None                   None     109.0  Not specified (no value)
# 9051       None                   None      88.0  Not specified (no value)
# 8450       None                   None      88.0  Not specified (no value)
# ...         ...                    ...       ...                       ...
# 5347       None                   None      88.0  Not specified (no value)
# 5342       None                   None      88.0  Not specified (no value)
# 11202      None        Non-VA Location      88.0  Not specified (no value)
# 10848      None                   None     133.0  Not specified (no value)
# 10849      None                   None     140.0  Not specified (no value)
#
#               State
# 12616    California
# 12617    California
# 9187     California
# 9051     California
# 8450     California
# ...             ...
# 5347   Pennsylvania
# 5342   Pennsylvania
# 11202  Pennsylvania
# 10848  Pennsylvania
# 10849  Pennsylvania
#
# [13585 rows x 10 columns]

# %% [markdown]
# # Checking the missing value

# %%
print("Training set missing values:\n", immunizations_train.isna().sum())
# Out:
# Training set missing values:
#  Internalpatientid             0
# Age at immunization           0
# Immunization date             0
# Immunization                  0
# Dose quantity             13558
# Dose unit                 13558
# Administered elsewhere    11640
# Cvx code                    121
# Series doses                  0
# State                         0
# dtype: int64

# %% [markdown]
# * **There are many missing values in the column "Dose quantity"(1836499),"Dose unit"(1836502),"Administered elsewhere"(1585089) "Cvx code"(121), and "Immunization" (3) And other varible have no missing values in this dataset.**
#
# **Note:Here potiential attributes is Immunization, so it will have three mising value we can remove.**

# %% [markdown]
# # Removing the missing value

# %%
# Remove rows missing values in the "Immunization" column
immunizations_train.dropna(subset=["Immunization"],inplace=True)

# %%
immunizations_train = immunizations_train

# %%
immunizations_train
# Out:
#        Internalpatientid  Age at immunization   Immunization date  \
# 12616                 67            48.284719 2010-08-10 01:33:24
# 12617                 67            48.284719 2010-08-10 01:33:24
# 9187                  67            48.305034 2010-08-17 11:45:26
# 9051                  67            49.301203 2011-08-16 14:09:21
# 8450                  67            49.940158 2012-04-06 03:03:52
# ...                  ...                  ...                 ...
# 5347              168899            89.554915 2012-05-17 07:42:45
# 5342              168899            90.568326 2013-05-22 17:21:10
# 11202             168899            92.401948 2015-03-23 21:53:17
# 10848             168899            93.483974 2016-04-22 09:24:59
# 10849             168899            93.483974 2016-04-22 09:24:59
#
#                                             Immunization Dose quantity  \
# 12616                             FLU,3 YRS (HISTORICAL)          None
# 12617   TDAP (Tetanus,Diphtheria,Pertussis) (HISTORICAL)          None
# 9187               PNEUMOCOCCAL, UNSPECIFIED FORMULATION          None
# 9051                              FLU,3 YRS (HISTORICAL)          None
# 8450                              FLU,3 YRS (HISTORICAL)          None
# ...                                                  ...           ...
# 5347                              FLU,3 YRS (HISTORICAL)          None
# 5342                              FLU,3 YRS (HISTORICAL)          None
# 11202                             FLU,3 YRS (HISTORICAL)          None
# 10848                      PNEUMOCOCCAL CONJUGATE PCV 13          None
# 10849  INFLUENZA, SEASONAL, INJECTABLE, PRESERVATIVE ...          None
#
#       Dose unit Administered elsewhere  Cvx code              Series doses  \
# 12616      None                   None      88.0  Not specified (no value)
# 12617      None                   None     115.0  Not specified (no value)
# 9187       None                   None     109.0  Not specified (no value)
# 9051       None                   None      88.0  Not specified (no value)
# 8450       None                   None      88.0  Not specified (no value)
# ...         ...                    ...       ...                       ...
# 5347       None                   None      88.0  Not specified (no value)
# 5342       None                   None      88.0  Not specified (no value)
# 11202      None        Non-VA Location      88.0  Not specified (no value)
# 10848      None                   None     133.0  Not specified (no value)
# 10849      None                   None     140.0  Not specified (no value)
#
#               State
# 12616    California
# 12617    California
# 9187     California
# 9051     California
# 8450     California
# ...             ...
# 5347   Pennsylvania
# 5342   Pennsylvania
# 11202  Pennsylvania
# 10848  Pennsylvania
# 10849  Pennsylvania
#
# [13585 rows x 10 columns]

# %%
# Checking the missing value after removing 
print("Training set missing values:\n", immunizations_train.isna().sum())
# Out:
# Training set missing values:
#  Internalpatientid             0
# Age at immunization           0
# Immunization date             0
# Immunization                  0
# Dose quantity             13558
# Dose unit                 13558
# Administered elsewhere    11640
# Cvx code                    121
# Series doses                  0
# State                         0
# dtype: int64

# %% [markdown]
# # Taking the one digit in age coulmn

# %%
# Format 'Age at measurement' values in the format 00.00
immunizations_train["Age at immunization"] = immunizations_train["Age at immunization"].map("{:.2f}".format)

# %%
immunizations_train
# Out:
#        Internalpatientid Age at immunization   Immunization date  \
# 12616                 67               48.28 2010-08-10 01:33:24
# 12617                 67               48.28 2010-08-10 01:33:24
# 9187                  67               48.31 2010-08-17 11:45:26
# 9051                  67               49.30 2011-08-16 14:09:21
# 8450                  67               49.94 2012-04-06 03:03:52
# ...                  ...                 ...                 ...
# 5347              168899               89.55 2012-05-17 07:42:45
# 5342              168899               90.57 2013-05-22 17:21:10
# 11202             168899               92.40 2015-03-23 21:53:17
# 10848             168899               93.48 2016-04-22 09:24:59
# 10849             168899               93.48 2016-04-22 09:24:59
#
#                                             Immunization Dose quantity  \
# 12616                             FLU,3 YRS (HISTORICAL)          None
# 12617   TDAP (Tetanus,Diphtheria,Pertussis) (HISTORICAL)          None
# 9187               PNEUMOCOCCAL, UNSPECIFIED FORMULATION          None
# 9051                              FLU,3 YRS (HISTORICAL)          None
# 8450                              FLU,3 YRS (HISTORICAL)          None
# ...                                                  ...           ...
# 5347                              FLU,3 YRS (HISTORICAL)          None
# 5342                              FLU,3 YRS (HISTORICAL)          None
# 11202                             FLU,3 YRS (HISTORICAL)          None
# 10848                      PNEUMOCOCCAL CONJUGATE PCV 13          None
# 10849  INFLUENZA, SEASONAL, INJECTABLE, PRESERVATIVE ...          None
#
#       Dose unit Administered elsewhere  Cvx code              Series doses  \
# 12616      None                   None      88.0  Not specified (no value)
# 12617      None                   None     115.0  Not specified (no value)
# 9187       None                   None     109.0  Not specified (no value)
# 9051       None                   None      88.0  Not specified (no value)
# 8450       None                   None      88.0  Not specified (no value)
# ...         ...                    ...       ...                       ...
# 5347       None                   None      88.0  Not specified (no value)
# 5342       None                   None      88.0  Not specified (no value)
# 11202      None        Non-VA Location      88.0  Not specified (no value)
# 10848      None                   None     133.0  Not specified (no value)
# 10849      None                   None     140.0  Not specified (no value)
#
#               State
# 12616    California
# 12617    California
# 9187     California
# 9051     California
# 8450     California
# ...             ...
# 5347   Pennsylvania
# 5342   Pennsylvania
# 11202  Pennsylvania
# 10848  Pennsylvania
# 10849  Pennsylvania
#
# [13585 rows x 10 columns]

# %%
# Convert 'Age at measurement' column from object to float
immunizations_train["Age at immunization"] = immunizations_train["Age at immunization"].astype(float)

# %%
immunizations_train
# Out:
#        Internalpatientid  Age at immunization   Immunization date  \
# 12616                 67                48.28 2010-08-10 01:33:24
# 12617                 67                48.28 2010-08-10 01:33:24
# 9187                  67                48.31 2010-08-17 11:45:26
# 9051                  67                49.30 2011-08-16 14:09:21
# 8450                  67                49.94 2012-04-06 03:03:52
# ...                  ...                  ...                 ...
# 5347              168899                89.55 2012-05-17 07:42:45
# 5342              168899                90.57 2013-05-22 17:21:10
# 11202             168899                92.40 2015-03-23 21:53:17
# 10848             168899                93.48 2016-04-22 09:24:59
# 10849             168899                93.48 2016-04-22 09:24:59
#
#                                             Immunization Dose quantity  \
# 12616                             FLU,3 YRS (HISTORICAL)          None
# 12617   TDAP (Tetanus,Diphtheria,Pertussis) (HISTORICAL)          None
# 9187               PNEUMOCOCCAL, UNSPECIFIED FORMULATION          None
# 9051                              FLU,3 YRS (HISTORICAL)          None
# 8450                              FLU,3 YRS (HISTORICAL)          None
# ...                                                  ...           ...
# 5347                              FLU,3 YRS (HISTORICAL)          None
# 5342                              FLU,3 YRS (HISTORICAL)          None
# 11202                             FLU,3 YRS (HISTORICAL)          None
# 10848                      PNEUMOCOCCAL CONJUGATE PCV 13          None
# 10849  INFLUENZA, SEASONAL, INJECTABLE, PRESERVATIVE ...          None
#
#       Dose unit Administered elsewhere  Cvx code              Series doses  \
# 12616      None                   None      88.0  Not specified (no value)
# 12617      None                   None     115.0  Not specified (no value)
# 9187       None                   None     109.0  Not specified (no value)
# 9051       None                   None      88.0  Not specified (no value)
# 8450       None                   None      88.0  Not specified (no value)
# ...         ...                    ...       ...                       ...
# 5347       None                   None      88.0  Not specified (no value)
# 5342       None                   None      88.0  Not specified (no value)
# 11202      None        Non-VA Location      88.0  Not specified (no value)
# 10848      None                   None     133.0  Not specified (no value)
# 10849      None                   None     140.0  Not specified (no value)
#
#               State
# 12616    California
# 12617    California
# 9187     California
# 9051     California
# 8450     California
# ...             ...
# 5347   Pennsylvania
# 5342   Pennsylvania
# 11202  Pennsylvania
# 10848  Pennsylvania
# 10849  Pennsylvania
#
# [13585 rows x 10 columns]

# %% [markdown]
# # Max age

# %%
# Find the maximum age for each internal patient id
max_ages = immunizations_train.groupby('Internalpatientid')['Age at immunization'].max().reset_index()

# Merge with the original dataframe to get the rows with the highest age
immunizations_train = pd.merge(immunizations_train, max_ages, on =['Internalpatientid','Age at immunization'], how = 'inner')

# %% [markdown]
# # Rounding off the Age

# %%
immunizations_train['Age at immunization'] = immunizations_train['Age at immunization'].apply(lambda x: round(x,))

# %%
len(immunizations_train["Internalpatientid"].value_counts())
# Out:
# 939

# %% [markdown]
# # Adding  'Age at immunization' & 'Immunization' columns with '_'

# %%
#In this code, we create a new column called 'Lab test description_Result numeric' by concatenating the values of the 'lab test description' column, underscore ('_'), and the 'lab test results' column
#converted to a string using the `astype(str)` function(because we cant't add differnt dtype)
immunizations_train['immunization'] =  immunizations_train['Age at immunization'].astype(str) + '_' +  immunizations_train['Immunization']

# %% [markdown]
# # Dropping all unnecessary columns

# %%
# Remove columns 
immunizations_train.drop(['Age at immunization','Immunization date','Immunization','Dose quantity','Dose unit','Administered elsewhere','Cvx code','Series doses','State'], axis=1,inplace=True)

# %%
immunizations_train = immunizations_train

# %%
# Group the DataFrame by 'Internalpatientid' and concatenate the icd10 values and
#The purpose of `x.dropna()` is to remove any missing values from the Series before applying a subsequent operation,
# such as concatenation using the `join` function. By dropping the missing values,
#we ensure that only non-null values are included in the resulting concatenated string.
df_grouped = immunizations_train.groupby('Internalpatientid').agg(lambda x: ','.join(x.dropna()))
df_grouped 

# Reset the index of the grouped DataFrame
df_grouped_imm = df_grouped.reset_index()
df_grouped_imm
# Out:
#      Internalpatientid                                       immunization
# 0                   67  58_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 1                  200     87_INFLUENZA VACCINE, QUADRIVALENT, ADJUVANTED
# 2                  291  82_FLU,3 YRS (HISTORICAL),82_INFLUENZA, UNSPEC...
# 3                  330  75_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 4                  351                                            82_TDAP
# 5                  714              67_INFLUENZA, UNSPECIFIED FORMULATION
# 6                  785  78_INFLUENZA, UNSPECIFIED FORMULATION,78_FLU,3...
# 7                  960               60_TD(ADULT) UNSPECIFIED FORMULATION
# 8                 1429  81_PNEUMOCOCCAL, UNSPECIFIED FORMULATION,81_IN...
# 9                 1451  86_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 10                1477              84_INFLUENZA, UNSPECIFIED FORMULATION
# 11                1568  77_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 12                1805  83_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 13                2282              86_INFLUENZA, UNSPECIFIED FORMULATION
# 14                2500                          62_FLU,3 YRS (HISTORICAL)
# 15                2674  73_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 16                2993  85_FLU,3 YRS (HISTORICAL),85_INFLUENZA, UNSPEC...
# 17                3020              80_INFLUENZA, UNSPECIFIED FORMULATION
# 18                3450  70_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 19                3547  78_INFLUENZA, UNSPECIFIED FORMULATION,78_INFLU...
# 20                3606  64_PNEUMOCOCCAL POLYSACCHARIDE PPV23,64_INFLUE...
# 21                4128  80_PNEUMOCOCCAL, UNSPECIFIED FORMULATION,80_FL...
# 22                4177           85_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 23                4203                              69_ZOSTER RECOMBINANT
# 24                4246                   74_PNEUMOCOCCAL CONJUGATE PCV 13
# 25                4453  74_FLU,3 YRS (HISTORICAL),74_INFLUENZA, UNSPEC...
# 26                4641                              84_ZOSTER RECOMBINANT
# 27                4845                67_INFLUENZA, TRIVALENT, ADJUVANTED
# 28                5653                              73_ZOSTER RECOMBINANT
# 29                5872              48_INFLUENZA, UNSPECIFIED FORMULATION
# 30                5920                 82_INFLUENZA, SEASONAL, INJECTABLE
# 31                6318              85_INFLUENZA, UNSPECIFIED FORMULATION
# 32                6370  104_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 M...
# 33                6400              77_INFLUENZA, UNSPECIFIED FORMULATION
# 34                6421  71_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 35                6584  82_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 36                6830              85_INFLUENZA, UNSPECIFIED FORMULATION
# 37                6859                          78_FLU,3 YRS (HISTORICAL)
# 38                7185              87_INFLUENZA, UNSPECIFIED FORMULATION
# 39                7232              75_INFLUENZA, UNSPECIFIED FORMULATION
# 40                7320     76_INFLUENZA VACCINE, QUADRIVALENT, ADJUVANTED
# 41                7572           83_TDAP,83_INFLUENZA, HIGH DOSE SEASONAL
# 42                7792  52_TD(ADULT) UNSPECIFIED FORMULATION,52_PNEUMO...
# 43                7925                          84_FLU,3 YRS (HISTORICAL)
# 44                8281  74_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 45                8286  82_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 46                8320                   79_INFLUENZA, HIGH DOSE SEASONAL
# 47                8418                          75_INFLUENZA (HISTORICAL)
# 48                8596                          96_INFLUENZA (HISTORICAL)
# 49                9391              86_INFLUENZA, UNSPECIFIED FORMULATION
# 50                9535                    75_INFLUENZA A & B (HISTORICAL)
# 51                9929               74_TD(ADULT) UNSPECIFIED FORMULATION
# 52                9947                                    76_TDAP,76_DTAP
# 53               10351           80_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 54               10469  68_INFLUENZA, TRIVALENT, ADJUVANTED,68_INFLUEN...
# 55               10505              72_INFLUENZA, UNSPECIFIED FORMULATION
# 56               10633  69_INFLUENZA, SEASONAL, INJECTABLE, PRESERVATI...
# 57               10690                          79_FLU,3 YRS (HISTORICAL)
# 58               10948                          77_FLU,3 YRS (HISTORICAL)
# 59               11261              78_INFLUENZA, UNSPECIFIED FORMULATION
# 60               11521               85_TD(ADULT) UNSPECIFIED FORMULATION
# 61               11618                          71_FLU,3 YRS (HISTORICAL)
# 62               11644               55_TD(ADULT) UNSPECIFIED FORMULATION
# 63               11674  70_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 64               12222                          80_FLU,3 YRS (HISTORICAL)
# 65               12356                 89_INFLUENZA, SEASONAL, INJECTABLE
# 66               12457  76_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 67               12473                          89_FLU,3 YRS (HISTORICAL)
# 68               12601  87_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 69               12679                                75_INFLUENZA, WHOLE
# 70               12803  86_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 71               13257              81_INFLUENZA, UNSPECIFIED FORMULATION
# 72               13266                          78_FLU,3 YRS (HISTORICAL)
# 73               13369                          83_FLU,3 YRS (HISTORICAL)
# 74               13483              89_INFLUENZA, UNSPECIFIED FORMULATION
# 75               13494                   80_PNEUMOCOCCAL CONJUGATE PCV 13
# 76               13910  56_TET-DIP-ACELLULAR PERTUSSIS (ADULT) (HISTOR...
# 77               14169                              74_ZOSTER RECOMBINANT
# 78               14472  85_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 79               14532              74_INFLUENZA, UNSPECIFIED FORMULATION
# 80               14724              79_INFLUENZA, UNSPECIFIED FORMULATION
# 81               14910                   70_DTAP, UNSPECIFIED FORMULATION
# 82               14918                          62_FLU,3 YRS (HISTORICAL)
# 83               15168  84_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 84               15335              62_INFLUENZA, UNSPECIFIED FORMULATION
# 85               15529  99_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 86               15548                78_INFLUENZA, TRIVALENT, ADJUVANTED
# 87               15803                   82_INFLUENZA, HIGH DOSE SEASONAL
# 88               16325  78_INFLUENZA, HIGH DOSE SEASONAL,78_INFLUENZA,...
# 89               16332                          80_INFLUENZA (HISTORICAL)
# 90               16588           66_TDAP,66_PNEUMOCOCCAL CONJUGATE PCV 13
# 91               16841              90_INFLUENZA, UNSPECIFIED FORMULATION
# 92               16911                   90_PNEUMOCOCCAL CONJUGATE PCV 13
# 93               16955                                            78_TDAP
# 94               17142  74_INFLUENZA (HISTORICAL),74_INFLUENZA, UNSPEC...
# 95               17182                              76_ZOSTER RECOMBINANT
# 96               17193              65_INFLUENZA, UNSPECIFIED FORMULATION
# 97               17216              65_INFLUENZA, UNSPECIFIED FORMULATION
# 98               17326  88_PNEUMOCOCCAL CONJUGATE PCV 13,88_INFLUENZA,...
# 99               17380  81_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 100              17982  63_PNEUMOCOCCAL, UNSPECIFIED FORMULATION,63_IN...
# 101              18270                          94_INFLUENZA (HISTORICAL)
# 102              18389                    82_INFLUENZA A & B (HISTORICAL)
# 103              18599  76_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 104              18839                   75_PNEUMOCOCCAL CONJUGATE PCV 13
# 105              19318              70_INFLUENZA, UNSPECIFIED FORMULATION
# 106              19436           81_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 107              19714               76_PNEUMOCOCCAL POLYSACCHARIDE PPV23
# 108              20024  90_INFLUENZA (HISTORICAL),90_INFLUENZA, UNSPEC...
# 109              20309  74_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 110              20630                73_INFLUENZA, TRIVALENT, ADJUVANTED
# 111              20728                   90_INFLUENZA, HIGH DOSE SEASONAL
# 112              20962              87_INFLUENZA, UNSPECIFIED FORMULATION
# 113              21338       84_NOVEL INFLUENZA-H1N1-09, ALL FORMULATIONS
# 114              21360              76_INFLUENZA, UNSPECIFIED FORMULATION
# 115              21426               89_PNEUMOCOCCAL POLYSACCHARIDE PPV23
# 116              21909  64_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 117              22107              91_INFLUENZA, UNSPECIFIED FORMULATION
# 118              22154      75_FLU VACCINE NO PRESERV 3 & >  (HISTORICAL)
# 119              22214                          76_FLU,3 YRS (HISTORICAL)
# 120              22221                          75_INFLUENZA (HISTORICAL)
# 121              22263  74_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 122              23414           80_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 123              23485              80_INFLUENZA, UNSPECIFIED FORMULATION
# 124              23527                              72_ZOSTER RECOMBINANT
# 125              23626                                59_INFLUENZA, WHOLE
# 126              23694  91_INFLUENZA, SEASONAL, INJECTABLE, PRESERVATI...
# 127              23812  65_INFLUENZA, UNSPECIFIED FORMULATION,65_INFLU...
# 128              23850  66_INFLUENZA, UNSPECIFIED FORMULATION,66_INFLU...
# 129              23956              95_INFLUENZA, UNSPECIFIED FORMULATION
# 130              24374                                            86_TDAP
# 131              24552  66_PNEUMOCOCCAL, UNSPECIFIED FORMULATION,66_DT...
# 132              24984                          60_INFLUENZA (HISTORICAL)
# 133              25241             80_INFLUENZA, INJECTABLE, QUADRIVALENT
# 134              25290  72_PNEUMOCOCCAL POLYSACCHARIDE PPV23,72_PNEUMO...
# 135              25516  70_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 136              25654  87_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 137              26517               70_PNEUMOCOCCAL POLYSACCHARIDE PPV23
# 138              26762      72_INFLUENZA, WHOLE,72_FLU,3 YRS (HISTORICAL)
# 139              26897           77_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 140              26981                   77_INFLUENZA, HIGH DOSE SEASONAL
# 141              27031                                            81_TDAP
# 142              27099                              76_ZOSTER RECOMBINANT
# 143              27204  88_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 144              27426                          79_FLU,3 YRS (HISTORICAL)
# 145              27752       79_INFLUENZA, PRESERVATIVE FREE (HISTORICAL)
# 146              27819  78_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 147              27878  56_INFLUENZA (HISTORICAL),56_PNEUMOCOCCAL POLY...
# 148              27940  74_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 149              28154               71_TD(ADULT) UNSPECIFIED FORMULATION
# 150              28186              75_INFLUENZA, UNSPECIFIED FORMULATION
# 151              28319                          82_FLU,3 YRS (HISTORICAL)
# 152              28682                 60_INFLUENZA, SEASONAL, INJECTABLE
# 153              28878  68_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 154              28938  69_INFLUENZA, UNSPECIFIED FORMULATION,69_FLU,3...
# 155              28954              69_INFLUENZA, UNSPECIFIED FORMULATION
# 156              29315                   90_INFLUENZA, HIGH DOSE SEASONAL
# 157              29346                          78_FLU,3 YRS (HISTORICAL)
# 158              29412  76_INFLUENZA, SEASONAL, INJECTABLE, PRESERVATI...
# 159              29488  81_INFLUENZA, UNSPECIFIED FORMULATION,81_FLU,3...
# 160              29765              67_INFLUENZA, UNSPECIFIED FORMULATION
# 161              29798  68_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 162              29913              84_INFLUENZA, UNSPECIFIED FORMULATION
# 163              30073              76_INFLUENZA, UNSPECIFIED FORMULATION
# 164              30137  65_INFLUENZA, UNSPECIFIED FORMULATION,65_FLU,3...
# 165              30416                          84_FLU,3 YRS (HISTORICAL)
# 166              30772  74_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 167              30868                          76_FLU,3 YRS (HISTORICAL)
# 168              30933                          67_FLU,3 YRS (HISTORICAL)
# 169              31319  55_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 170              31356               88_PNEUMOCOCCAL POLYSACCHARIDE PPV23
# 171              31385                          80_INFLUENZA (HISTORICAL)
# 172              31586              81_INFLUENZA, UNSPECIFIED FORMULATION
# 173              31806               70_PNEUMOCOCCAL POLYSACCHARIDE PPV23
# 174              31828              65_INFLUENZA, UNSPECIFIED FORMULATION
# 175              31905              76_INFLUENZA, UNSPECIFIED FORMULATION
# 176              32252                                83_INFLUENZA, WHOLE
# 177              32615  76_TD(ADULT) UNSPECIFIED FORMULATION,76_INFLUE...
# 178              32652  71_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 179              32970  67_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 180              33411  79_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 181              34282                              73_ZOSTER RECOMBINANT
# 182              34287               85_PNEUMOCOCCAL POLYSACCHARIDE PPV23
# 183              34385              85_INFLUENZA, UNSPECIFIED FORMULATION
# 184              34799                          60_FLU,3 YRS (HISTORICAL)
# 185              35012  87_INFLUENZA, SEASONAL, INJECTABLE, PRESERVATI...
# 186              35076  77_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 187              35087  81_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 188              35332       66_NOVEL INFLUENZA-H1N1-09, ALL FORMULATIONS
# 189              35361                          90_INFLUENZA (HISTORICAL)
# 190              36160              94_INFLUENZA, UNSPECIFIED FORMULATION
# 191              36281               73_TD(ADULT) UNSPECIFIED FORMULATION
# 192              36414                              64_ZOSTER RECOMBINANT
# 193              36434                71_INFLUENZA, TRIVALENT, ADJUVANTED
# 194              36766              70_INFLUENZA, UNSPECIFIED FORMULATION
# 195              36905              82_INFLUENZA, UNSPECIFIED FORMULATION
# 196              37010  80_INFLUENZA, RECOMBINANT, QUADRIVALENT,INJECT...
# 197              37156                                            79_TDAP
# 198              37286              82_INFLUENZA, UNSPECIFIED FORMULATION
# 199              37366  75_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 200              37508  64_ZOSTER RECOMBINANT,64_PNEUMOCOCCAL POLYSACC...
# 201              37682  66_INFLUENZA, UNSPECIFIED FORMULATION,66_FLU,3...
# 202              38043                              65_ZOSTER RECOMBINANT
# 203              38452                                            72_TDAP
# 204              38493                                            81_TDAP
# 205              38585  84_INFLUENZA, WHOLE,84_PNEUMOCOCCAL, UNSPECIFI...
# 206              38696  78_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 207              38785  77_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 208              38910              84_INFLUENZA, UNSPECIFIED FORMULATION
# 209              39161                                53_INFLUENZA, WHOLE
# 210              39394               50_PNEUMOCOCCAL POLYSACCHARIDE PPV23
# 211              39490               71_PNEUMOCOCCAL POLYSACCHARIDE PPV23
# 212              39531              75_INFLUENZA, UNSPECIFIED FORMULATION
# 213              39707  95_TD (ADULT), 2 LF TETANUS TOXOID, PRESERVATI...
# 214              39771  78_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 215              39909  57_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 216              39975              99_INFLUENZA, UNSPECIFIED FORMULATION
# 217              40058       65_NOVEL INFLUENZA-H1N1-09, ALL FORMULATIONS
# 218              40152  71_PNEUMOCOCCAL, UNSPECIFIED FORMULATION,71_IN...
# 219              40532  87_INFLUENZA VACCINE, QUADRIVALENT, ADJUVANTED...
# 220              41041                    93_INFLUENZA A & B (HISTORICAL)
# 221              41309               68_PNEUMOCOCCAL POLYSACCHARIDE PPV23
# 222              41407                54_INFLUENZA 2006-2007 (HISTORICAL)
# 223              41595  71_COVID-19 (JANSSEN), VECTOR-NR, RS-AD26, PF,...
# 224              41667              74_INFLUENZA, UNSPECIFIED FORMULATION
# 225              41761  56_INFLUENZA (HISTORICAL),56_INFLUENZA, UNSPEC...
# 226              42402              81_INFLUENZA, UNSPECIFIED FORMULATION
# 227              42814              84_INFLUENZA, UNSPECIFIED FORMULATION
# 228              42933       59_TDAP,59_TD(ADULT) UNSPECIFIED FORMULATION
# 229              42951                    75_INFLUENZA A & B (HISTORICAL)
# 230              43104                          84_FLU,3 YRS (HISTORICAL)
# 231              43141     80_INFLUENZA VACCINE, QUADRIVALENT, ADJUVANTED
# 232              43238  83_INFLUENZA, SEASONAL, INJECTABLE, PRESERVATI...
# 233              43268  71_COVID-19 (JANSSEN), VECTOR-NR, RS-AD26, PF,...
# 234              43476  70_INFLUENZA, SEASONAL, INJECTABLE, PRESERVATI...
# 235              43740                          91_FLU,3 YRS (HISTORICAL)
# 236              43802              71_INFLUENZA, HIGH-DOSE, QUADRIVALENT
# 237              43829  37_COVID-19 (JANSSEN), VECTOR-NR, RS-AD26, PF,...
# 238              44003  63_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 239              44393              87_INFLUENZA, UNSPECIFIED FORMULATION
# 240              44508  86_INFLUENZA, SEASONAL, INJECTABLE,86_INFLUENZ...
# 241              44835  86_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 242              44836  77_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 243              45161           56_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 244              45285                          77_FLU,3 YRS (HISTORICAL)
# 245              45342  71_TD (ADULT), 5 LF TETANUS TOXOID, PRESERVATI...
# 246              45742  70_INFLUENZA, UNSPECIFIED FORMULATION,70_INFLU...
# 247              45762  85_PNEUMOCOCCAL CONJUGATE PCV 13,85_FLU,3 YRS ...
# 248              46025  79_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 249              46039  76_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 250              46107  72_FLU,3 YRS (HISTORICAL),72_INFLUENZA, UNSPEC...
# 251              46131  55_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 252              46154                   94_INFLUENZA, HIGH DOSE SEASONAL
# 253              46177   93_ZOSTER (HISTORICAL),93_FLU,3 YRS (HISTORICAL)
# 254              46189              67_INFLUENZA, UNSPECIFIED FORMULATION
# 255              46415           81_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 256              47012  41_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 257              47138              74_INFLUENZA, UNSPECIFIED FORMULATION
# 258              47454     92_INFLUENZA VACCINE, QUADRIVALENT, ADJUVANTED
# 259              48643                                            92_TDAP
# 260              48647               86_TD(ADULT) UNSPECIFIED FORMULATION
# 261              48749              87_INFLUENZA, UNSPECIFIED FORMULATION
# 262              48962              88_INFLUENZA, UNSPECIFIED FORMULATION
# 263              49014  74_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 264              49127  78_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 265              49589              81_INFLUENZA, UNSPECIFIED FORMULATION
# 266              49802                          88_FLU,3 YRS (HISTORICAL)
# 267              49978  93_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 268              50020  78_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 269              50264  93_INFLUENZA, UNSPECIFIED FORMULATION,93_INFLU...
# 270              50323           71_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 271              50345                          59_FLU,3 YRS (HISTORICAL)
# 272              50738                   78_INFLUENZA, HIGH DOSE SEASONAL
# 273              51070  91_INFLUENZA, UNSPECIFIED FORMULATION,91_ZZZIN...
# 274              51180               54_PNEUMOCOCCAL POLYSACCHARIDE PPV23
# 275              51215              87_INFLUENZA, UNSPECIFIED FORMULATION
# 276              51456               70_PNEUMOCOCCAL POLYSACCHARIDE PPV23
# 277              51551  54_NOVEL INFLUENZA-H1N1-09, ALL FORMULATIONS,5...
# 278              52128  81_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 279              52143                      82_FLU TRIVALENT (HISTORICAL)
# 280              52256  74_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 281              52608  82_INFLUENZA, UNSPECIFIED FORMULATION,82_INFLU...
# 282              52681                          84_FLU,3 YRS (HISTORICAL)
# 283              52689              77_INFLUENZA, UNSPECIFIED FORMULATION
# 284              52752  81_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 285              52767                                            78_TDAP
# 286              52886  75_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 287              52942                   96_INFLUENZA, HIGH DOSE SEASONAL
# 288              52973                76_FLU GIVEN ELSEWHERE (HISTORICAL)
# 289              53075  85_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 290              53150  72_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 291              53236  72_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 292              53312  81_INFLUENZA (HISTORICAL),81_FLU,3 YRS (HISTOR...
# 293              53457  72_INFLUENZA, UNSPECIFIED FORMULATION,72_FLU,3...
# 294              53548                84_INFLUENZA, TRIVALENT, ADJUVANTED
# 295              53681                 92_INFLUENZA, SEASONAL, INJECTABLE
# 296              53703  76_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 297              53818              97_INFLUENZA, UNSPECIFIED FORMULATION
# 298              53843           72_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 299              53884           67_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 300              54446           61_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 301              54638                   91_PNEUMOCOCCAL CONJUGATE PCV 13
# 302              54669           66_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 303              54993  72_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 304              55203              92_INFLUENZA, UNSPECIFIED FORMULATION
# 305              55398  79_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 306              55492  78_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 307              55955  80_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 308              56035       60_NOVEL INFLUENZA-H1N1-09, ALL FORMULATIONS
# 309              56635  69_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 310              56968  50_FLU,3 YRS (HISTORICAL),50_INFLUENZA, UNSPEC...
# 311              57173  86_FLU,3 YRS (HISTORICAL),86_INFLUENZA, UNSPEC...
# 312              57404                   87_PNEUMOCOCCAL CONJUGATE PCV 13
# 313              57509              78_INFLUENZA, UNSPECIFIED FORMULATION
# 314              57943              80_INFLUENZA, UNSPECIFIED FORMULATION
# 315              57987              85_INFLUENZA, UNSPECIFIED FORMULATION
# 316              58622              73_INFLUENZA, UNSPECIFIED FORMULATION
# 317              58641  38_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 318              58777               52_TD(ADULT) UNSPECIFIED FORMULATION
# 319              59112  85_INFLUENZA, UNSPECIFIED FORMULATION,85_FLU,3...
# 320              59183              77_INFLUENZA, UNSPECIFIED FORMULATION
# 321              59447              81_INFLUENZA, UNSPECIFIED FORMULATION
# 322              59471  86_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 323              59545     75_INFLUENZA VACCINE, QUADRIVALENT, ADJUVANTED
# 324              59735                   67_INFLUENZA, HIGH DOSE SEASONAL
# 325              59856  88_INFLUENZA, SPLIT VIRUS, PERSERVATIVE FREE (...
# 326              60206               72_TD(ADULT) UNSPECIFIED FORMULATION
# 327              60339              84_INFLUENZA, UNSPECIFIED FORMULATION
# 328              61061              78_INFLUENZA, UNSPECIFIED FORMULATION
# 329              61071              68_INFLUENZA, UNSPECIFIED FORMULATION
# 330              61375                   90_INFLUENZA, HIGH DOSE SEASONAL
# 331              61468                          62_INFLUENZA (HISTORICAL)
# 332              61548              82_INFLUENZA, UNSPECIFIED FORMULATION
# 333              61583                73_INFLUENZA, TRIVALENT, ADJUVANTED
# 334              61719                   66_INFLUENZA, HIGH DOSE SEASONAL
# 335              61749     75_INFLUENZA VACCINE, QUADRIVALENT, ADJUVANTED
# 336              61795              73_INFLUENZA, UNSPECIFIED FORMULATION
# 337              62143  74_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 338              62241              69_INFLUENZA, UNSPECIFIED FORMULATION
# 339              62249              74_INFLUENZA, UNSPECIFIED FORMULATION
# 340              62334              77_INFLUENZA, UNSPECIFIED FORMULATION
# 341              62460  89_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 342              62821                          78_FLU,3 YRS (HISTORICAL)
# 343              62987              75_INFLUENZA, UNSPECIFIED FORMULATION
# 344              63206              88_INFLUENZA, UNSPECIFIED FORMULATION
# 345              63564              91_INFLUENZA, UNSPECIFIED FORMULATION
# 346              63615               71_TD(ADULT) UNSPECIFIED FORMULATION
# 347              63963           55_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 348              64006  75_INFLUENZA, HIGH-DOSE, QUADRIVALENT,75_INFLU...
# 349              64257  65_FLU,3 YRS (HISTORICAL),65_INFLUENZA, UNSPEC...
# 350              64295              76_INFLUENZA, UNSPECIFIED FORMULATION
# 351              64303                          85_INFLUENZA (HISTORICAL)
# 352              64393              77_INFLUENZA, UNSPECIFIED FORMULATION
# 353              64450                82_INFLUENZA, TRIVALENT, ADJUVANTED
# 354              65342  59_PNEUMOVAX POLYSACCHARIDE PPSV23 (HISTORICAL...
# 355              65684  69_PNEUMOCOCCAL POLYSACCHARIDE PPV23,69_PNEUMO...
# 356              65973                          61_FLU,3 YRS (HISTORICAL)
# 357              66263                              94_ZOSTER RECOMBINANT
# 358              66379  77_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 359              66497                          91_FLU WHOLE (HISTORICAL)
# 360              66508                          77_INFLUENZA (HISTORICAL)
# 361              66655              83_INFLUENZA, UNSPECIFIED FORMULATION
# 362              66821  96_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 363              67211                              72_ZOSTER RECOMBINANT
# 364              67383  74_INFLUENZA (HISTORICAL),74_INFLUENZA, UNSPEC...
# 365              67484              87_INFLUENZA, UNSPECIFIED FORMULATION
# 366              67582                          77_FLU,3 YRS (HISTORICAL)
# 367              68005              77_INFLUENZA, HIGH-DOSE, QUADRIVALENT
# 368              68239  75_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 369              68454  80_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 370              68636                          62_FLU,3 YRS (HISTORICAL)
# 371              68790  72_INFLUENZA, UNSPECIFIED FORMULATION,72_INFLU...
# 372              68858  76_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 373              69283              74_INFLUENZA, UNSPECIFIED FORMULATION
# 374              69390                    41_INFLUENZA A & B (HISTORICAL)
# 375              69918           83_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 376              70201           89_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 377              70618           70_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 378              70746  67_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 379              70974  72_INFLUENZA VACCINE, QUADRIVALENT, ADJUVANTED...
# 380              71312              79_INFLUENZA, UNSPECIFIED FORMULATION
# 381              71452  74_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 382              71469              84_INFLUENZA, UNSPECIFIED FORMULATION
# 383              72208                              69_ZOSTER RECOMBINANT
# 384              72308                              84_ZOSTER RECOMBINANT
# 385              72812  74_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 386              73063               67_PNEUMOCOCCAL POLYSACCHARIDE PPV23
# 387              73165  85_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 388              73167  73_INFLUENZA, UNSPECIFIED FORMULATION,73_PNEUM...
# 389              73411  56_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 390              73466                                62_INFLUENZA, WHOLE
# 391              73600                          89_INFLUENZA (HISTORICAL)
# 392              73855      85_INFLUENZA, WHOLE,85_INFLUENZA (HISTORICAL)
# 393              73980              78_INFLUENZA, UNSPECIFIED FORMULATION
# 394              74273                          80_FLU,3 YRS (HISTORICAL)
# 395              74303              80_INFLUENZA, UNSPECIFIED FORMULATION
# 396              74317              77_INFLUENZA, UNSPECIFIED FORMULATION
# 397              74613  61_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 398              74825              84_INFLUENZA, UNSPECIFIED FORMULATION
# 399              75157                              77_ZOSTER RECOMBINANT
# 400              75275                                            74_TDAP
# 401              75462                 73_IM V9 PNEUMOCOCCAL (HISTORICAL)
# 402              75484       90_NOVEL INFLUENZA-H1N1-09, ALL FORMULATIONS
# 403              75714              84_INFLUENZA, UNSPECIFIED FORMULATION
# 404              76007     55_MENINGOCOCCAL ACWY, UNSPECIFIED FORMULATION
# 405              76196                          73_INFLUENZA (HISTORICAL)
# 406              76555               74_PNEUMOCOCCAL POLYSACCHARIDE PPV23
# 407              76591                          91_FLU,3 YRS (HISTORICAL)
# 408              76680               67_PNEUMOCOCCAL POLYSACCHARIDE PPV23
# 409              76744              68_INFLUENZA, UNSPECIFIED FORMULATION
# 410              77137                 85_INFLUENZA, SEASONAL, INJECTABLE
# 411              77142              57_INFLUENZA, UNSPECIFIED FORMULATION
# 412              77592  86_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 413              77665     93_INFLUENZA VACCINE, QUADRIVALENT, ADJUVANTED
# 414              77723              96_INFLUENZA, UNSPECIFIED FORMULATION
# 415              77747           85_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 416              77919  86_INFLUENZA, UNSPECIFIED FORMULATION,86_FLU I...
# 417              78039  70_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 418              78353  71_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 419              78424  64_INFLUENZA, UNSPECIFIED FORMULATION,64_FLU,3...
# 420              78626  63_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 421              79413              69_INFLUENZA, UNSPECIFIED FORMULATION
# 422              79491              83_INFLUENZA, UNSPECIFIED FORMULATION
# 423              79736                          94_FLU,3 YRS (HISTORICAL)
# 424              79859               80_TD(ADULT) UNSPECIFIED FORMULATION
# 425              80030                          85_FLU, 3YRS (HISTORICAL)
# 426              80242               46_TD(ADULT) UNSPECIFIED FORMULATION
# 427              80319                   75_BCG,INTRAVESICAL (HISTORICAL)
# 428              80713                          77_FLU,3 YRS (HISTORICAL)
# 429              81165  62_COVID-19 (JANSSEN), VECTOR-NR, RS-AD26, PF,...
# 430              81280                          87_INFLUENZA (HISTORICAL)
# 431              82054              90_INFLUENZA, UNSPECIFIED FORMULATION
# 432              82070  89_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 433              82176  73_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 434              82267              90_INFLUENZA, UNSPECIFIED FORMULATION
# 435              82273                              73_ZOSTER RECOMBINANT
# 436              82314  47_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 437              82368                                72_INFLUENZA, WHOLE
# 438              82860  92_PNEUMOCOCCAL POLYSACCHARIDE PPV23,92_INFLUE...
# 439              82915  64_TD(ADULT) UNSPECIFIED FORMULATION,64_PNEUMO...
# 440              82968  61_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 441              83577       78_NOVEL INFLUENZA-H1N1-09, ALL FORMULATIONS
# 442              83601    65_PNEUMOCOCCAL PCV13 (PREVNAR-13) (HISTORICAL)
# 443              83710  61_PNEUMOVAX POLYSACCHARIDE PPSV23  (HISTORICA...
# 444              83748                              67_ZOSTER RECOMBINANT
# 445              83792  86_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 446              83822              83_INFLUENZA, UNSPECIFIED FORMULATION
# 447              83926                          88_FLU,3 YRS (HISTORICAL)
# 448              84217           71_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 449              84245                                69_INFLUENZA, WHOLE
# 450              84251  85_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 451              84262  55_PNEUMOCOCCAL, UNSPECIFIED FORMULATION,55_PN...
# 452              84301  72_PNEUMOCOCCAL POLYSACCHARIDE PPV23,72_PNEUMO...
# 453              84413  58_INFLUENZA(NYH) (HISTORICAL),58_INFLUENZA, S...
# 454              84436  84_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 455              84501              92_INFLUENZA, UNSPECIFIED FORMULATION
# 456              84661                 75_INFLUENZA, SEASONAL, INJECTABLE
# 457              84682                          70_INFLUENZA (HISTORICAL)
# 458              84815              93_INFLUENZA, UNSPECIFIED FORMULATION
# 459              84821  49_COVID-19 (JANSSEN), VECTOR-NR, RS-AD26, PF,...
# 460              84990               66_PNEUMOCOCCAL POLYSACCHARIDE PPV23
# 461              85298                    82_TETANUS REFUSED (HISTORICAL)
# 462              85484                          66_INFLUENZA (HISTORICAL)
# 463              85960                                58_INFLUENZA, WHOLE
# 464              85966  41_PNEUMOCOCCAL CONJUGATE PCV20, POLYSACCHARID...
# 465              85968  91_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 466              86140  67_INFLUENZA (HISTORICAL),67_PNEUMOCOCCAL, UNS...
# 467              86376  77_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 468              86632  83_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 469              87131              89_INFLUENZA, UNSPECIFIED FORMULATION
# 470              87166     77_INFLUENZA VACCINE, QUADRIVALENT, ADJUVANTED
# 471              87579                                     70_ZOSTER LIVE
# 472              87910              71_INFLUENZA, UNSPECIFIED FORMULATION
# 473              88033                75_INFLUENZA, TRIVALENT, ADJUVANTED
# 474              88042                          67_FLU,3 YRS (HISTORICAL)
# 475              88068                75_INFLUENZA, TRIVALENT, ADJUVANTED
# 476              88071  82_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 477              88289  93_FLU,3 YRS (HISTORICAL),93_INFLUENZA, UNSPEC...
# 478              88457                   85_PNEUMOCOCCAL CONJUGATE PCV 13
# 479              88474                                67_INFLUENZA, WHOLE
# 480              88537              78_INFLUENZA, UNSPECIFIED FORMULATION
# 481              88776      70_INFLUENZA, WHOLE,70_INFLUENZA (HISTORICAL)
# 482              88802                          66_FLU, 3YRS (HISTORICAL)
# 483              88819              88_INFLUENZA, UNSPECIFIED FORMULATION
# 484              88886                   92_INFLUENZA, HIGH DOSE SEASONAL
# 485              88951              82_INFLUENZA, UNSPECIFIED FORMULATION
# 486              88977  89_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 487              89178  93_INFLUENZA, UNSPECIFIED FORMULATION,93_INFLU...
# 488              89271                                68_INFLUENZA, WHOLE
# 489              89286                          86_FLU,3 YRS (HISTORICAL)
# 490              89300                  51_HEP A, UNSPECIFIED FORMULATION
# 491              89621  76_INFLUENZA, SEASONAL, INJECTABLE, PRESERVATI...
# 492              89673                          87_INFLUENZA (HISTORICAL)
# 493              89709  74_INFLUENZA, SEASONAL, INJECTABLE, PRESERVATI...
# 494              89715              85_INFLUENZA, UNSPECIFIED FORMULATION
# 495              89831  68_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 496              89854              87_INFLUENZA, UNSPECIFIED FORMULATION
# 497              89989                              56_ZOSTER RECOMBINANT
# 498              90028              75_INFLUENZA, UNSPECIFIED FORMULATION
# 499              90052              61_INFLUENZA, UNSPECIFIED FORMULATION
# 500              90132  66_FLU,3 YRS (HISTORICAL),66_INFLUENZA, HIGH D...
# 501              90338                          82_FLU,3 YRS (HISTORICAL)
# 502              90367              79_INFLUENZA, UNSPECIFIED FORMULATION
# 503              90472     74_INFLUENZA VACCINE, QUADRIVALENT, ADJUVANTED
# 504              90535  57_TD(ADULT) UNSPECIFIED FORMULATION,57_TD(ADU...
# 505              90608              88_INFLUENZA, UNSPECIFIED FORMULATION
# 506              90832  90_INFLUENZA, SEASONAL, INJECTABLE, PRESERVATI...
# 507              90911              65_INFLUENZA, UNSPECIFIED FORMULATION
# 508              91447                          75_INFLUENZA (HISTORICAL)
# 509              91519                 87_INFLUENZA, SEASONAL, INJECTABLE
# 510              91548  89_COVID-19 (JANSSEN), VECTOR-NR, RS-AD26, PF,...
# 511              91664                          85_FLU,3 YRS (HISTORICAL)
# 512              91683                   78_PNEUMOCOCCAL CONJUGATE PCV 13
# 513              91717                                62_INFLUENZA, WHOLE
# 514              92031              81_INFLUENZA, UNSPECIFIED FORMULATION
# 515              92079  70_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 516              92189  90_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 517              92288       61_PNEUMOCOCCAL POLYSACCHARIDE PPV23,61_TDAP
# 518              92921              67_INFLUENZA, UNSPECIFIED FORMULATION
# 519              93205              86_INFLUENZA, UNSPECIFIED FORMULATION
# 520              93533  95_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 521              93550              91_INFLUENZA, UNSPECIFIED FORMULATION
# 522              93680  72_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 523              93917  68_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 524              94080  76_INFLUENZA, SEASONAL, INJECTABLE,76_PNEUMOCO...
# 525              94450              89_INFLUENZA, UNSPECIFIED FORMULATION
# 526              94720  46_INFLUENZA, SEASONAL, INJECTABLE, PRESERVATI...
# 527              94935  83_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 528              95041  87_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 529              95448              50_INFLUENZA, UNSPECIFIED FORMULATION
# 530              95477              63_INFLUENZA, UNSPECIFIED FORMULATION
# 531              95734  89_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 532              95750                                            70_TDAP
# 533              95817                          65_FLU,3 YRS (HISTORICAL)
# 534              96711                          94_FLU,3 YRS (HISTORICAL)
# 535              96816  86_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 536              96917                          71_FLU,3 YRS (HISTORICAL)
# 537              97021  62_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 538              97370                          46_INFLUENZA (HISTORICAL)
# 539              97868                  78_INFLUENZA VACCINE (HISTORICAL)
# 540              98416  79_INFLUENZA, UNSPECIFIED FORMULATION,79_FLU,3...
# 541              98439  84_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 542              99024                          69_FLU,3 YRS (HISTORICAL)
# 543              99137                   88_INFLUENZA, HIGH DOSE SEASONAL
# 544              99143              91_INFLUENZA, UNSPECIFIED FORMULATION
# 545              99870                                     86_ZOSTER LIVE
# 546              99941                 76_INFLUENZA, SEASONAL, INJECTABLE
# 547              99944           80_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 548             100012  74_INFLUENZA, UNSPECIFIED FORMULATION,74_COVID...
# 549             100223             87_INFLUENZA, INJECTABLE, QUADRIVALENT
# 550             100229  82_INFLUENZA, UNSPECIFIED FORMULATION,82_INFLU...
# 551             100314  74_INFLUENZA VACCINE, QUADRIVALENT, ADJUVANTED...
# 552             100399              87_INFLUENZA, UNSPECIFIED FORMULATION
# 553             100681                          72_FLU,3 YRS (HISTORICAL)
# 554             100694     90_INFLUENZA VACCINE, QUADRIVALENT, ADJUVANTED
# 555             101225  69_INFLUENZA, SEASONAL, INJECTABLE, PRESERVATI...
# 556             101407                   89_INFLUENZA, HIGH DOSE SEASONAL
# 557             101530                          90_FLU,3 YRS (HISTORICAL)
# 558             101600              83_INFLUENZA, UNSPECIFIED FORMULATION
# 559             101984  64_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 560             102273  77_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 561             102450                          49_FLU,3 YRS (HISTORICAL)
# 562             102467  75_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 563             102468  70_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 564             102788  73_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 565             102857              57_INFLUENZA, UNSPECIFIED FORMULATION
# 566             103112  76_INFLUENZA, SEASONAL, INJECTABLE, PRESERVATI...
# 567             103133                  100_INFLUENZA, HIGH DOSE SEASONAL
# 568             103169  73_INFLUENZA, UNSPECIFIED FORMULATION,73_FLU,3...
# 569             103190              88_INFLUENZA, UNSPECIFIED FORMULATION
# 570             103335     88_INFLUENZA VACCINE, QUADRIVALENT, ADJUVANTED
# 571             103421  70_COVID-19 (JANSSEN), VECTOR-NR, RS-AD26, PF,...
# 572             103462  70_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 573             103513                85_INFLUENZA, TRIVALENT, ADJUVANTED
# 574             104244  62_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 575             104339              85_INFLUENZA, UNSPECIFIED FORMULATION
# 576             104362  63_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 577             104480  93_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 578             104616               66_PNEUMOCOCCAL POLYSACCHARIDE PPV23
# 579             105005  65_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 580             105077                          82_FLU,3 YRS (HISTORICAL)
# 581             105402           66_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 582             105425                              72_ZOSTER RECOMBINANT
# 583             105769  49_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 584             105907  74_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 585             105947  85_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 586             106023              70_INFLUENZA, UNSPECIFIED FORMULATION
# 587             106030                                            72_TDAP
# 588             106149  89_INFLUENZA, UNSPECIFIED FORMULATION,89_INFLU...
# 589             106243                              62_ZOSTER RECOMBINANT
# 590             106440  66_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 591             106576              77_INFLUENZA, UNSPECIFIED FORMULATION
# 592             106715     94_INFLUENZA VACCINE, QUADRIVALENT, ADJUVANTED
# 593             106818         48_TETANUS TOXOID, UNSPECIFIED FORMULATION
# 594             106827       88_NOVEL INFLUENZA-H1N1-09, ALL FORMULATIONS
# 595             106828  73_FLU VACCINE NO PRESERV 3 & >  (HISTORICAL),...
# 596             107249  92_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 597             107471              80_INFLUENZA, UNSPECIFIED FORMULATION
# 598             107645                 84_INFLUENZA, SEASONAL, INJECTABLE
# 599             107792      64_INFLUENZA (HISTORICAL),64_PPD (HISTORICAL)
# 600             107797  73_PNEUMOCOCCAL CONJUGATE PCV 13,73_INFLUENZA,...
# 601             107880  74_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 602             108043  72_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 603             108047                   86_INFLUENZA, HIGH DOSE SEASONAL
# 604             108054  62_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 605             108167                67_INFLUENZA, TRIVALENT, ADJUVANTED
# 606             108210              81_INFLUENZA, UNSPECIFIED FORMULATION
# 607             108307           75_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 608             108502                          75_FLU,3 YRS (HISTORICAL)
# 609             108611              91_INFLUENZA, UNSPECIFIED FORMULATION
# 610             108668                   88_INFLUENZA, HIGH DOSE SEASONAL
# 611             108901                          63_FLU,3 YRS (HISTORICAL)
# 612             109204                          73_FLU,3 YRS (HISTORICAL)
# 613             109675              79_INFLUENZA, UNSPECIFIED FORMULATION
# 614             110734              80_INFLUENZA, UNSPECIFIED FORMULATION
# 615             111360               84_PNEUMOCOCCAL POLYSACCHARIDE PPV23
# 616             111865              58_INFLUENZA, UNSPECIFIED FORMULATION
# 617             111922                              75_ZOSTER RECOMBINANT
# 618             111947  71_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 619             112212                                     66_HEP A-HEP B
# 620             112457  63_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 621             112459              72_INFLUENZA, UNSPECIFIED FORMULATION
# 622             112511  64_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 623             112675  82_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 624             112807     77_INFLUENZA VACCINE, QUADRIVALENT, ADJUVANTED
# 625             113606     68_INFLUENZA VACCINE, QUADRIVALENT, ADJUVANTED
# 626             113626  77_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 627             114033     83_INFLUENZA VACCINE, QUADRIVALENT, ADJUVANTED
# 628             114062  66_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 629             114205                          94_FLU,3 YRS (HISTORICAL)
# 630             114383                                            73_TDAP
# 631             114425           85_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 632             114689  72_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 633             114715                                            92_TDAP
# 634             114805                  78_INFLUENZA VACCINE (HISTORICAL)
# 635             114818  95_INFLUENZA, UNSPECIFIED FORMULATION,95_FLU,3...
# 636             114884                 69_INFLUENZA, SEASONAL, INJECTABLE
# 637             114976              73_INFLUENZA, UNSPECIFIED FORMULATION
# 638             115075              71_INFLUENZA, UNSPECIFIED FORMULATION
# 639             115142              79_INFLUENZA, HIGH-DOSE, QUADRIVALENT
# 640             115167                              66_ZOSTER RECOMBINANT
# 641             115675           74_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 642             115818  83_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 643             115904  88_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 644             116482                          71_FLU,3 YRS (HISTORICAL)
# 645             116508  67_ZOSTER RECOMBINANT,67_PNEUMOCOCCAL POLYSACC...
# 646             116882  91_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# ...
# 723             130264  80_INFLUENZA, SEASONAL, INJECTABLE, PRESERVATI...
# 724             130294  78_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 725             130442               79_TD(ADULT) UNSPECIFIED FORMULATION
# 726             130476  81_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 727             131065              85_INFLUENZA, UNSPECIFIED FORMULATION
# 728             131301     71_INFLUENZA VACCINE, QUADRIVALENT, ADJUVANTED
# 729             131408  63_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 730             131489  93_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 731             131516                   56_PNEUMOCOCCAL CONJUGATE PCV 13
# 732             131548  85_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 733             131776                   94_PNEUMOCOCCAL CONJUGATE PCV 13
# 734             131865                   96_INFLUENZA, HIGH DOSE SEASONAL
# 735             132010                              79_ZOSTER RECOMBINANT
# 736             132018  86_INFLUENZA, SEASONAL, INJECTABLE, PRESERVATI...
# 737             132165  46_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 738             132647              87_INFLUENZA, UNSPECIFIED FORMULATION
# 739             133437  78_INFLUENZA, UNSPECIFIED FORMULATION,78_INFLU...
# 740             133446              82_INFLUENZA, UNSPECIFIED FORMULATION
# 741             133523              82_INFLUENZA, UNSPECIFIED FORMULATION
# 742             133583  75_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 743             133681              80_INFLUENZA, UNSPECIFIED FORMULATION
# 744             133752  74_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 745             133861              85_INFLUENZA, UNSPECIFIED FORMULATION
# 746             133943  81_INFLUENZA, SEASONAL, INJECTABLE, PRESERVATI...
# 747             134019                                80_INFLUENZA, WHOLE
# 748             134341  69_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 749             134490                              57_ZOSTER RECOMBINANT
# 750             134549              87_INFLUENZA, UNSPECIFIED FORMULATION
# 751             134627                 90_INFLUENZA, SEASONAL, INJECTABLE
# 752             134663  79_INFLUENZA, UNSPECIFIED FORMULATION,79_INFLU...
# 753             135090  68_INFLUENZA, INJECTABLE, QUADRIVALENT,68_PNEU...
# 754             135216              51_INFLUENZA, UNSPECIFIED FORMULATION
# 755             135293                          83_FLU,3 YRS (HISTORICAL)
# 756             135390  75_INFLUENZA, SEASONAL, INJECTABLE,75_INFLUENZ...
# 757             135461  83_INFLUENZA VIRUS VACCINE, 3YR AND OLDER (HIS...
# 758             135685                72_INFLUENZA, TRIVALENT, ADJUVANTED
# 759             135750  71_INFLUENZA, SEASONAL, INJECTABLE, PRESERVATI...
# 760             135917                          87_FLU,3 YRS (HISTORICAL)
# 761             136230                   56_PNEUMOCOCCAL CONJUGATE PCV 13
# 762             136451  67_FLU,3 YRS (HISTORICAL),67_INFLUENZA A & B (...
# 763             136502  66_INFLUENZA, SEASONAL, INJECTABLE,66_PNEUMOCO...
# 764             136533  52_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 765             136544  69_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 766             136590                   81_INFLUENZA, HIGH DOSE SEASONAL
# 767             136628              76_INFLUENZA, UNSPECIFIED FORMULATION
# 768             136730                   63_PNEUMOCOCCAL CONJUGATE PCV 13
# 769             137040                                            53_TDAP
# 770             137111  59_Tetanus/Diptheria/Acellular Pertussis (TDAP...
# 771             137294              70_INFLUENZA, UNSPECIFIED FORMULATION
# 772             137322                   67_PNEUMOCOCCAL CONJUGATE PCV 13
# 773             137433                 67_INFLUENZA, SEASONAL, INJECTABLE
# 774             137771  40_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 775             137888              90_INFLUENZA, UNSPECIFIED FORMULATION
# 776             137973  59_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 777             138177           87_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 778             138195              42_INFLUENZA, UNSPECIFIED FORMULATION
# 779             138266  77_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 780             138450                          80_FLU,3 YRS (HISTORICAL)
# 781             138567                          70_FLU,3 YRS (HISTORICAL)
# 782             138579                              78_ZOSTER RECOMBINANT
# 783             138631                          67_FLU,3 YRS (HISTORICAL)
# 784             138941              65_INFLUENZA, UNSPECIFIED FORMULATION
# 785             138942              83_INFLUENZA, UNSPECIFIED FORMULATION
# 786             139521  87_INFLUENZA, HIGH-DOSE, QUADRIVALENT,87_INFLU...
# 787             139741  64_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 788             139877  70_INFLUENZA, SEASONAL, INJECTABLE, PRESERVATI...
# 789             139982  83_NOVEL INFLUENZA-H1N1-09, ALL FORMULATIONS,8...
# 790             140280  80_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 791             140430                 72_INFLUENZA, SEASONAL, INJECTABLE
# 792             140556                          64_FLU,3 YRS (HISTORICAL)
# 793             140757           75_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 794             141344                 74_INFLUENZA, SEASONAL, INJECTABLE
# 795             141895              90_INFLUENZA, UNSPECIFIED FORMULATION
# 796             141925                          89_FLU,3 YRS (HISTORICAL)
# 797             142117  79_INFLUENZA (HISTORICAL),79_INFLUENZA, UNSPEC...
# 798             142259                              86_ZOSTER RECOMBINANT
# 799             143048                          71_FLU,3 YRS (HISTORICAL)
# 800             143290  81_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 801             143291              79_INFLUENZA, UNSPECIFIED FORMULATION
# 802             143470                              70_ZOSTER RECOMBINANT
# 803             143492  93_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 804             143583               43_TD(ADULT) UNSPECIFIED FORMULATION
# 805             143766  89_FLU 3YRS DONE ELSEWHERE (HISTORICAL),89_NOV...
# 806             143885              65_INFLUENZA, UNSPECIFIED FORMULATION
# 807             144349               61_PNEUMOCOCCAL POLYSACCHARIDE PPV23
# 808             144351              92_INFLUENZA, UNSPECIFIED FORMULATION
# 809             144395  63_FLU,3 YRS (HISTORICAL),63_NOVEL INFLUENZA-H...
# 810             144994      81_INFLUENZA, WHOLE,81_INFLUENZA (HISTORICAL)
# 811             145086  61_INFLUENZA (HISTORICAL),61_INFLUENZA, UNSPEC...
# 812             145249                   87_INFLUENZA, HIGH DOSE SEASONAL
# 813             145807              85_INFLUENZA, UNSPECIFIED FORMULATION
# 814             145995                   80_INFLUENZA, HIGH DOSE SEASONAL
# 815             146092                          73_FLU,3 YRS (HISTORICAL)
# 816             146246  95_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 817             146366  83_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 818             146435              72_INFLUENZA, UNSPECIFIED FORMULATION
# 819             146481               73_TD(ADULT) UNSPECIFIED FORMULATION
# 820             146483                          67_FLU,3 YRS (HISTORICAL)
# 821             146487                                57_INFLUENZA, WHOLE
# 822             146510              78_INFLUENZA, UNSPECIFIED FORMULATION
# 823             146612  90_INFLUENZA (HISTORICAL),90_INFLUENZA, UNSPEC...
# 824             147237  75_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 825             147420                          84_INFLUENZA (HISTORICAL)
# 826             147606                          89_FLU,3 YRS (HISTORICAL)
# 827             147971  88_PNEUMOCOCCAL CONJUGATE PCV 13,88_INFLUENZA,...
# 828             148042              79_INFLUENZA, UNSPECIFIED FORMULATION
# 829             148654              67_INFLUENZA, UNSPECIFIED FORMULATION
# 830             148893  60_INFLUENZA, SEASONAL, INJECTABLE, PRESERVATI...
# 831             149040              89_INFLUENZA, UNSPECIFIED FORMULATION
# 832             149417                                     83_ZOSTER LIVE
# 833             149483           96_PNEUMOCOCCAL, UNSPECIFIED FORMULATION
# 834             149757  89_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 835             149787                                    63_HEP B, ADULT
# 836             150157  71_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 837             150783  71_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 838             151159  72_INFLUENZA (FLU SHOT) (HISTORICAL),72_INFLUE...
# 839             151180                          65_FLU,3 YRS (HISTORICAL)
# 840             151359  88_COVID-19 (JANSSEN), VECTOR-NR, RS-AD26, PF,...
# 841             151375               67_TD(ADULT) UNSPECIFIED FORMULATION
# 842             151867  101_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 M...
# 843             151921              74_INFLUENZA, UNSPECIFIED FORMULATION
# 844             152040  71_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 845             152061                          84_INFLUENZA (HISTORICAL)
# 846             152238  71_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 847             152587                          92_FLU,3 YRS (HISTORICAL)
# 848             152768                                            66_TDAP
# 849             152816              83_INFLUENZA, UNSPECIFIED FORMULATION
# 850             153055              82_INFLUENZA, UNSPECIFIED FORMULATION
# 851             153129  64_FLU VACCINE NO PRESERV 3 & >  (HISTORICAL),...
# 852             153146              83_INFLUENZA, UNSPECIFIED FORMULATION
# 853             153207  85_INFLUENZA, HIGH DOSE SEASONAL, PRESERV-FREE...
# 854             153265               77_TD(ADULT) UNSPECIFIED FORMULATION
# 855             153684                              71_ZOSTER RECOMBINANT
# 856             153870              82_INFLUENZA, UNSPECIFIED FORMULATION
# 857             153925  94_INFLUENZA (HISTORICAL),94_INFLUENZA, UNSPEC...
# 858             154137  78_INFLUENZA VACCINE (HISTORICAL),78_FLU,3 YRS...
# 859             154561             83_INFLUENZA, INJECTABLE, QUADRIVALENT
# 860             154720              58_INFLUENZA, UNSPECIFIED FORMULATION
# 861             154784  71_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 862             154957  81_INFLUENZA, UNSPECIFIED FORMULATION,81_INFLU...
# 863             155331               94_TD(ADULT) UNSPECIFIED FORMULATION
# 864             155332                   91_PNEUMOCOCCAL CONJUGATE PCV 13
# 865             156508  56_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 866             156560  75_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 867             156667              87_INFLUENZA, UNSPECIFIED FORMULATION
# 868             156705  83_INFLUENZA (HISTORICAL),83_INFLUENZA, UNSPEC...
# 869             156719            65_Pneumo-Vac Immunization (HISTORICAL)
# 870             156832  72_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 871             156956              81_INFLUENZA, UNSPECIFIED FORMULATION
# 872             157002                                     77_ZOSTER LIVE
# 873             157362              82_INFLUENZA, UNSPECIFIED FORMULATION
# 874             157826                 54_INFLUENZA, SEASONAL, INJECTABLE
# 875             157903  90_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 876             157947                                            85_TDAP
# 877             157952               77_TD(ADULT) UNSPECIFIED FORMULATION
# 878             157987  66_INFLUENZA, UNSPECIFIED FORMULATION,66_FLU,3...
# 879             158264               70_TD(ADULT) UNSPECIFIED FORMULATION
# 880             158472  77_FLU,3 YRS (HISTORICAL),77_FLU,3 YRS (HISTOR...
# 881             158742  75_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 882             158889  62_HEP B, ADULT,62_PNEUMOCOCCAL POLYSACCHARIDE...
# 883             159062  82_INFLUENZA (HISTORICAL),82_INFLUENZA, UNSPEC...
# 884             159640  79_TD(ADULT) UNSPECIFIED FORMULATION,79_PNEUMO...
# 885             159755  71_INFLUENZA, SEASONAL, INJECTABLE, PRESERVATI...
# 886             160058               83_TD(ADULT) UNSPECIFIED FORMULATION
# 887             160193  67_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 888             160215              81_INFLUENZA, UNSPECIFIED FORMULATION
# 889             161317                 89_INFLUENZA, SEASONAL, INJECTABLE
# 890             161353  53_INFLUENZA (HISTORICAL),53_INFLUENZA, UNSPEC...
# 891             161449              98_INFLUENZA, UNSPECIFIED FORMULATION
# 892             161539  86_INFLUENZA, INJECTABLE, QUADRIVALENT, PRESER...
# 893             161807  52_INFLUENZA, SEASONAL, INJECTABLE, PRESERVATI...
# 894             161864                     97_INFLUENZA(NYH) (HISTORICAL)
# 895             161905  88_INFLUENZA (HISTORICAL),88_H1N1 (HISTORICAL)...
# 896             161933  56_PNEUMOCOCCAL POLYSACCHARIDE PPV23,56_PNEUMO...
# 897             161971  69_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 898             162002  76_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 899             162077              82_INFLUENZA, UNSPECIFIED FORMULATION
# 900             162217                      85_ZOSTER RECOMBINANT,85_TDAP
# 901             162316                 56_IM V9 PNEUMOCOCCAL (HISTORICAL)
# 902             162328  80_INFLUENZA, UNSPECIFIED FORMULATION,80_INFLU...
# 903             162355              61_INFLUENZA, UNSPECIFIED FORMULATION
# 904             162404                                    73_HEP B, ADULT
# 905             162507               43_TD(ADULT) UNSPECIFIED FORMULATION
# 906             162727              85_INFLUENZA, UNSPECIFIED FORMULATION
# 907             162755              58_INFLUENZA, UNSPECIFIED FORMULATION
# 908             163120  82_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 909             163598                 48_INFLUENZA, SEASONAL, INJECTABLE
# 910             163686           64_PNEUMOCOCCAL CONJUGATE PCV 13,64_TDAP
# 911             163867  79_INFLUENZA, UNSPECIFIED FORMULATION,79_INFLU...
# 912             163951  82_COVID-19 (MODERNA), MRNA, LNP-S, PF, 100 MC...
# 913             164176                          82_FLU,3 YRS (HISTORICAL)
# 914             164385                93_INFLUENZA, TRIVALENT, ADJUVANTED
# 915             164582              82_INFLUENZA, UNSPECIFIED FORMULATION
# 916             164617       77_NOVEL INFLUENZA-H1N1-09, ALL FORMULATIONS
# 917             165235  69_COVID-19 (JANSSEN), VECTOR-NR, RS-AD26, PF,...
# 918             165265  84_INFLUENZA, SEASONAL, INJECTABLE, PRESERVATI...
# 919             165284              69_INFLUENZA, UNSPECIFIED FORMULATION
# 920             165445              58_INFLUENZA, UNSPECIFIED FORMULATION
# 921             165517              80_INFLUENZA, UNSPECIFIED FORMULATION
# 922             165904  86_PNEUMOCOCCAL CONJUGATE PCV 13,86_INFLUENZA,...
# 923             166007                          67_FLU,3 YRS (HISTORICAL)
# 924             166169              81_INFLUENZA, UNSPECIFIED FORMULATION
# 925             166211               78_TD(ADULT) UNSPECIFIED FORMULATION
# 926             166229                                40_INFLUENZA, WHOLE
# 927             166535  75_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 928             166603         83_TETANUS TOXOID, UNSPECIFIED FORMULATION
# 929             166671              81_INFLUENZA, UNSPECIFIED FORMULATION
# 930             166856                          65_FLU,3 YRS (HISTORICAL)
# 931             166881  76_FLU,3 YRS (HISTORICAL),76_INFLUENZA, UNSPEC...
# 932             167102  81_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 933             167842              73_INFLUENZA, UNSPECIFIED FORMULATION
# 934             167907                                     87_ZOSTER LIVE
# 935             167917  51_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/...
# 936             168008                   73_INFLUENZA, HIGH DOSE SEASONAL
# 937             168496     99_INFLUENZA VACCINE, QUADRIVALENT, ADJUVANTED
# 938             168899  93_PNEUMOCOCCAL CONJUGATE PCV 13,93_INFLUENZA,...

# %%
# Checking row values if it is correctly printed like A, B, C...
column_value = df_grouped_imm['immunization'].values[5]
print(column_value)
# Out:
# 69_COVID-19 (PFIZER), MRNA, LNP-S, PF, 30 MCG/0.3 ML DOSE, TRIS-SUCROSE (AGES 12+ YEARS)

# %%
df_grouped_imm.to_csv('/mnt/batch/tasks/shared/LS_root/mounts/clusters/team-3-susai-gpu2/code/Users/900379/Output_files_quality/df_immunizations_quality.csv')
