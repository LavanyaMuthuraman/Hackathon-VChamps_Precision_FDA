# %%
#A class attribute that provides access to the TabularDatasetFactory methods for creating new TabularDataset objects. 
#Usage: Dataset.Tabular.from_delimited_files().
from azureml.core import Workspace, Dataset

subscription_id = 'bcfe0c62-8ebe-4df0-a46d-1efcf8739a5b' #check the launch studio there will get this id
resource_group = 'VChamp-Team3' # resource group name
workspace_name = 'vchamp-team3' # worksapce name


# storage account : Algorithmia, Resource group: VChamp-Team3 and workspace: vchamp-team3.
#Constructor
workspace = Workspace(subscription_id, resource_group, workspace_name)

# %%
import numpy as np                # Multi-Dimensional array object
import pandas as pd               # Data Manipulation
import matplotlib.pyplot as plt   # Data Visualization
import seaborn as sns             # Data Visualization 

# Allows the use of display() for DataFrames
from IPython.display import display 

# Handle warning messages that may occur during code execution
import warnings
warnings.filterwarnings('ignore')

# To increase memory allocation
from notebook.services.config import ConfigManager
cm = ConfigManager().update('notebook', {'max_buffer_size': 7294967296})

# %%
#['data_team3_synthetic_train']
datastore = workspace.datastores['data_team3_synthetic_quality_check']

# %%
#from_delimited_files (Create a TabularDataset to represent tabular data in delimited files (e.g. CSV and TSV).

dataset = Dataset.Tabular.from_delimited_files(path = [(datastore, 'outpatient_visits_qual.csv')])

# preview the first 3 rows of the dataset
# dataset.to_pandas_dataframe()

# %%
#Converting the dataset into data frame(default as dataset in Azure, thus we must convert the needed formate)
outpatient_train_data = dataset.to_pandas_dataframe()

# %%
outpatient_train_data.Internalpatientid.nunique()
# Out:
# 1000

# %% [markdown]
# # Elimination of the unnamed columns

# %%
# Remove unwanted columns 
outpatient_train_data.drop('Column1',axis=1,inplace=True)

# %%
outpatient_train_data
# Out:
#         Internalpatientid  Age at visit    Visit start date  \
# 0                  100012     52.440184 2001-12-08 21:17:36
# 1                  100012     52.570897 2002-01-25 15:54:35
# 2                  100012     52.603491 2002-02-06 13:49:30
# 3                  100012     52.678927 2002-03-06 03:32:37
# 4                  100012     52.706935 2002-03-16 09:14:15
# ...                   ...           ...                 ...
# 627697              99944     79.489989 2012-01-04 14:10:45
# 627698              99944     80.012876 2012-07-13 16:57:06
# 627699              99944     80.320453 2012-11-03 03:01:01
# 627700              99944     80.438034 2012-12-16 02:26:00
# 627701              99944     80.706980 2013-03-24 09:37:54
#
#        First listed diagnosis icd10 subcategory  \
# 0                                 Not specified
# 1                                 Not specified
# 2                                 Not specified
# 3                                 Not specified
# 4                                 Not specified
# ...                                         ...
# 627697                            Not specified
# 627698                            Not specified
# 627699                            Not specified
# 627700                            Not specified
# 627701                            Not specified
#
#        Second listed diagnosis icd10 subcategory               Stop code  \
# 0                                  Not specified        TELEPHONE TRIAGE
# 1                                  Not specified          EMERGENCY UNIT
# 2                                  Not specified   PRIMARY CARE/MEDICINE
# 3                                  Not specified        TELEPHONE TRIAGE
# 4                                  Not specified        TELEPHONE TRIAGE
# ...                                          ...                     ...
# 627697                             Not specified    OCCUPATIONAL THERAPY
# 627698                             Not specified    HBPC - SOCIAL WORKER
# 627699                             Not specified  HBPC Nursing (RN / LP)
# 627700                             Not specified  HBPC Nursing (RN / LP)
# 627701                             Not specified  HBPC Nursing (RN / LP)
#
#        Agentorangeflag Combatflag Ionizingradiationflag Serviceconnectedflag  \
# 0                 None       None                  None                False
# 1                 None       None                  None                 None
# 2                 None       None                  None                False
# 3                 None       None                  None                 None
# 4                 None       None                  None                False
# ...                ...        ...                   ...                  ...
# 627697            None       None                  None                 None
# 627698            None       None                  None                 None
# 627699            None       None                  None                 None
# 627700            None       None                  None                 None
# 627701            None       None                  None                 None
#
#        Swasiaconditionsflag          State
# 0                      None          Texas
# 1                      None     New Mexico
# 2                      None     New Mexico
# 3                      None     New Mexico
# 4                      None     New Mexico
# ...                     ...            ...
# 627697                 None  Massachusetts
# 627698                 None  Massachusetts
# 627699                 None  Massachusetts
# 627700                 None  Massachusetts
# 627701                 None  Massachusetts
#
# [627702 rows x 12 columns]

# %% [markdown]
# # sorting out patients id and age column

# %%
# Sort the dataset based on the patientsid and 'age' column in ascending order
outpatient_train_data.sort_values(["Internalpatientid","Age at visit"],inplace=True)

# %%
outpatient_train_data
# Out:
#         Internalpatientid  Age at visit    Visit start date  \
# 574990                 67     48.273610 2010-08-06 00:06:10
# 390106                 67     48.278791 2010-08-07 21:33:09
# 390107                 67     48.278793 2010-08-07 21:34:08
# 390108                 67     48.278793 2010-08-07 21:34:08
# 390791                 67     48.284581 2010-08-10 00:20:48
# ...                   ...           ...                 ...
# 452341             168899     96.897697 2019-09-22 02:35:38
# 218992             168899     96.905469 2019-09-24 22:46:28
# 452342             168899     96.969163 2019-10-18 05:30:02
# 219223             168899     97.039824 2019-11-13 01:20:01
# 443225             168899     97.059213 2019-11-20 03:24:47
#
#        First listed diagnosis icd10 subcategory  \
# 574990                            Not specified
# 390106                            Not specified
# 390107                            Not specified
# 390108                            Not specified
# 390791                            Not specified
# ...                                         ...
# 452341                            Not specified
# 218992  Encounter for other specified aftercare
# 452342                            Not specified
# 219223                            Not specified
# 443225                            Not specified
#
#                 Second listed diagnosis icd10 subcategory  \
# 574990                                      Not specified
# 390106                                      Not specified
# 390107                                      Not specified
# 390108                                      Not specified
# 390791                                      Not specified
# ...                                                   ...
# 452341                                      Not specified
# 218992  Unspecified atrial fibrillation and atrial flu...
# 452342                                      Not specified
# 219223                                      Not specified
# 443225                                      Not specified
#
#                              Stop code Agentorangeflag Combatflag  \
# 574990           PRIMARY CARE/MEDICINE            None       None
# 390106                      LABORATORY            None       None
# 390107                      LABORATORY            None       None
# 390108                      LABORATORY            None       None
# 390791       GENERAL INTERNAL MEDICINE            None       None
# ...                                ...             ...        ...
# 452341  ADMIN PAT ACTIVTIES (MASNONCT)            None       None
# 218992         ANTI-COAGULATION CLINIC            None       None
# 452342          TELEPHONE PRIMARY CARE            None       None
# 219223          TELEPHONE PRIMARY CARE            None       None
# 443225  ADMIN PAT ACTIVTIES (MASNONCT)            None       None
#
#        Ionizingradiationflag Serviceconnectedflag Swasiaconditionsflag  \
# 574990                  None                 None                 None
# 390106                  None                 None                 None
# 390107                  None                 None                 None
# 390108                  None                 None                 None
# 390791                  None                 None                 None
# ...                      ...                  ...                  ...
# 452341                  None                 None                 None
# 218992                  None                 None                 None
# 452342                  None                 None                 None
# 219223                  None                 None                 None
# 443225                  None                 None                 None
#
#                State
# 574990    California
# 390106    California
# 390107    California
# 390108    California
# 390791    California
# ...              ...
# 452341  Pennsylvania
# 218992  Pennsylvania
# 452342  Pennsylvania
# 219223  Pennsylvania
# 443225  Pennsylvania
#
# [627702 rows x 12 columns]

# %% [markdown]
# # checking the missing valuses

# %%
print("set missing values:\n", outpatient_train_data.isna().sum())
# Out:
# set missing values:
#  Internalpatientid                                 0
# Age at visit                                      0
# Visit start date                                  0
# First listed diagnosis icd10 subcategory          0
# Second listed diagnosis icd10 subcategory         0
# Stop code                                         0
# Agentorangeflag                              603925
# Combatflag                                   626916
# Ionizingradiationflag                        625932
# Serviceconnectedflag                         486950
# Swasiaconditionsflag                         625217
# State                                             0
# dtype: int64

# %% [markdown]
# * There is no missing value in the potential attributes,but lot of "Not specified" values in PA

# %%
#Checking the values each category in condition type

# Count the occurrences of each label
first_list = outpatient_train_data["First listed diagnosis icd10 subcategory"].value_counts().loc[lambda x: x>200]
first_list
# Out:
# Not specified                                                   534964
# Other specified counseling                                        5571
# Encounter for other specified aftercare                           3129
# Counseling, unspecified                                           2471
# Essential (primary) hypertension                                  2184
#                                                                  ...
# Other problems related to housing and economic circumstances       221
# Partial loss of teeth                                              218
# Hyperlipidemia, unspecified                                        217
# Age-related physical debility                                      210
# Deposits [accretions] on teeth                                     204
# Name: First listed diagnosis icd10 subcategory, Length: 79, dtype: int64

# %%
#Checking the values each category in condition type

# Count the occurrences of each label
sec_list = outpatient_train_data["Second listed diagnosis icd10 subcategory"].value_counts().loc[lambda x: x>200]
sec_list
# Out:
# Not specified                                                                      594477
# Essential (primary) hypertension                                                     1551
# Unspecified atrial fibrillation and atrial flutter                                   1466
# Long term (current) use of anticoagulants and antithrombotics/antiplatelets           874
# Type 2 diabetes mellitus without complications                                        846
# Encounter for other specified aftercare                                               647
# Post-traumatic stress disorder (PTSD)                                                 586
# Hyperlipidemia, unspecified                                                           449
# Chronic obstructive pulmonary disease, unspecified                                    448
# Atherosclerotic heart disease of native coronary artery                               410
# Other long term (current) drug therapy                                                336
# Systolic (congestive) heart failure                                                   334
# Sleep apnea                                                                           311
# Encounter for observation for other suspected diseases and conditions ruled out       299
# Pain in joint                                                                         277
# Presbyopia                                                                            268
# Type 2 diabetes mellitus with neurological complications                              267
# Major depressive disorder, recurrent, moderate                                        256
# Chronic atrial fibrillation                                                           252
# Other specified counseling                                                            251
# Low back pain                                                                         247
# Encounter for immunization                                                            242
# Personal history of diseases of the circulatory system                                225
# Encounter for palliative care                                                         225
# Heart failure, unspecified                                                            221
# Obesity, unspecified                                                                  214
# Alcohol dependence                                                                    212
# Gastro-esophageal reflux disease without esophagitis                                  207
# Name: Second listed diagnosis icd10 subcategory, dtype: int64

# %%
# Remove the rows where both columns contain "Not Specified"

outpatient_train_data = outpatient_train_data.drop(outpatient_train_data[(outpatient_train_data['First listed diagnosis icd10 subcategory'] == 'Not specified') & (outpatient_train_data['Second listed diagnosis icd10 subcategory'] == 'Not specified')].index)

# %%
outpatient_train_data.Internalpatientid.nunique()
# Out:
# 524

# %% [markdown]
# # Taking the digit in age coulmn

# %%
# Format 'Age at measurement' values in the format 00.00
outpatient_train_data["Age at visit"] = outpatient_train_data["Age at visit"].map("{:.2f}".format)

# %%
outpatient_train_data
# Out:
#         Internalpatientid Age at visit    Visit start date  \
# 390118                 67        52.29 2014-08-14 15:51:06
# 573223                 67        52.29 2014-08-14 15:55:09
# 391029                 67        52.30 2014-08-15 14:03:05
# 391030                 67        52.34 2014-08-31 03:47:06
# 574998                 67        52.81 2015-02-18 03:14:42
# ...                   ...          ...                 ...
# 445586             168899        96.39 2019-03-18 18:54:32
# 443615             168899        96.48 2019-04-23 16:50:17
# 218991             168899        96.75 2019-07-31 14:05:25
# 443617             168899        96.87 2019-09-13 03:48:33
# 218992             168899        96.91 2019-09-24 22:46:28
#
#        First listed diagnosis icd10 subcategory  \
# 390118         Essential (primary) hypertension
# 573223               Encounter for immunization
# 391029                    Other sleep disorders
# 391030         Essential (primary) hypertension
# 574998         Essential (primary) hypertension
# ...                                         ...
# 445586  Encounter for other specified aftercare
# 443615               Other specified counseling
# 218991  Encounter for other specified aftercare
# 443617  Encounter for other specified aftercare
# 218992  Encounter for other specified aftercare
#
#                 Second listed diagnosis icd10 subcategory  \
# 390118                Chronic kidney disease, unspecified
# 573223                                      Not specified
# 391029                                      Not specified
# 391030                                      Not specified
# 574998                                      Low back pain
# ...                                                   ...
# 445586  Unspecified atrial fibrillation and atrial flu...
# 443615                                      Not specified
# 218991  Unspecified atrial fibrillation and atrial flu...
# 443617  Unspecified atrial fibrillation and atrial flu...
# 218992  Unspecified atrial fibrillation and atrial flu...
#
#                              Stop code Agentorangeflag Combatflag  \
# 390118           PRIMARY CARE/MEDICINE            None       None
# 573223  ADMIN PAT ACTIVTIES (MASNONCT)            None       None
# 391029                  SLEEP MEDICINE            None       None
# 391030           PRIMARY CARE/MEDICINE            None       None
# 574998           PRIMARY CARE/MEDICINE            None       None
# ...                                ...             ...        ...
# 445586         ANTI-COAGULATION CLINIC            None       None
# 443615          TELEPHONE PRIMARY CARE            None       None
# 218991         ANTI-COAGULATION CLINIC            None       None
# 443617         ANTI-COAGULATION CLINIC            None       None
# 218992         ANTI-COAGULATION CLINIC            None       None
#
#        Ionizingradiationflag Serviceconnectedflag Swasiaconditionsflag  \
# 390118                  None                 None                 None
# 573223                  None                 None                 None
# 391029                  None                 None                 None
# 391030                  None                 None                 None
# 574998                  None                 None                 None
# ...                      ...                  ...                  ...
# 445586                  None                 None                 None
# 443615                  None                 None                 None
# 218991                  None                 None                 None
# 443617                  None                 None                 None
# 218992                  None                 None                 None
#
#                State
# 390118    California
# 573223    California
# 391029    California
# 391030    California
# 574998    California
# ...              ...
# 445586  Pennsylvania
# 443615  Pennsylvania
# 218991  Pennsylvania
# 443617  Pennsylvania
# 218992  Pennsylvania
#
# [92946 rows x 12 columns]

# %%
# Convert 'Age' column from object to float
outpatient_train_data["Age at visit"] = outpatient_train_data["Age at visit"].astype(float)

# %% [markdown]
# # Max age

# %%
# Find the maximum age for each internal patient id
max_ages = outpatient_train_data.groupby('Internalpatientid')['Age at visit'].max().reset_index()

# Merge with the original dataframe to get the rows with the highest age
outpatient_train_data = pd.merge(outpatient_train_data, max_ages, on =['Internalpatientid','Age at visit'], how = 'inner')

outpatient_train_data
# Out:
#      Internalpatientid  Age at visit    Visit start date  \
# 0                   67         58.48 2020-10-22 11:49:50
# 1                  200         87.80 2023-02-13 10:31:19
# 2                  330         74.66 2024-03-01 00:19:37
# 3                  351         85.56 2023-10-18 20:54:27
# 4                  714         67.66 2015-04-17 12:26:12
# ..                 ...           ...                 ...
# 880             168008         73.33 2013-04-13 23:59:08
# 881             168008         73.33 2013-04-15 23:49:32
# 882             168008         73.33 2013-04-16 06:30:58
# 883             168496         98.72 2022-11-03 09:59:52
# 884             168899         96.91 2019-09-24 22:46:28
#
#               First listed diagnosis icd10 subcategory  \
# 0                           Encounter for immunization
# 1                                    Vascular dementia
# 2                           Encounter for immunization
# 3                          Other chronic osteomyelitis
# 4    Hypertensive chronic kidney disease with stage...
# ..                                                 ...
# 880                            Counseling, unspecified
# 881                         Malignant carcinoid tumors
# 882          Pneumonia due to other specified bacteria
# 883               Diastolic (congestive) heart failure
# 884            Encounter for other specified aftercare
#
#              Second listed diagnosis icd10 subcategory  \
# 0                                        Not specified
# 1                                        Not specified
# 2                                        Not specified
# 3                                        Not specified
# 4         Panic disorder [episodic paroxysmal anxiety]
# ..                                                 ...
# 880                                      Not specified
# 881            Encounter for other specified aftercare
# 882            Encounter for other specified aftercare
# 883                   Essential (primary) hypertension
# 884  Unspecified atrial fibrillation and atrial flu...
#
#                      Stop code Agentorangeflag Combatflag  \
# 0    GENERAL INTERNAL MEDICINE            None       None
# 1             HBPC - THERAPIST            None       None
# 2        PRIMARY CARE/MEDICINE            None       None
# 3          TELEPHONE/ANCILLARY            None       None
# 4        PRIMARY CARE/MEDICINE            None       None
# ..                         ...             ...        ...
# 880           TELEPHONE TRIAGE             Yes       None
# 881            PALLIATIVE CARE              No       None
# 882            PALLIATIVE CARE            None       None
# 883         TELEPHONE/MEDICINE            None       None
# 884    ANTI-COAGULATION CLINIC            None       None
#
#     Ionizingradiationflag Serviceconnectedflag Swasiaconditionsflag  \
# 0                    None                 None                 None
# 1                    None                 None                 None
# 2                    None                False                 None
# 3                    None                False                 None
# 4                    None                False                 None
# ..                    ...                  ...                  ...
# 880                  None                False                 None
# 881                  None                False                 None
# 882                  None                 None                 None
# 883                  None                 None                 None
# 884                  None                 None                 None
#
#             State
# 0      California
# 1            Utah
# 2          Oregon
# 3            Ohio
# 4         Georgia
# ..            ...
# 880         Texas
# 881         Texas
# 882         Texas
# 883    California
# 884  Pennsylvania
#
# [885 rows x 12 columns]

# %% [markdown]
# # Rounding off the Age

# %%
outpatient_train_data['Age at visit'] = outpatient_train_data['Age at visit'].apply(lambda x: round(x,))

# %%
outpatient_train_data.Internalpatientid.nunique()
# Out:
# 524

# %%
df = outpatient_train_data["Internalpatientid"].value_counts().loc[lambda x: x>25].to_frame()

# %%
df = df.reset_index()

# %%
df.columns = ["Internalpatientid","count_outpatients"]

# %%
len(df)
# Out:
# 0

# %%
df.drop(["count_outpatients"],axis=1,inplace =True)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Internalpatientid]
# Index: []

# %%
# Merge the two dataframes based on 'Internalpatientid'
merged_df = outpatient_train_data.merge(df, on='Internalpatientid', how='left')

# Filter rows from DataFrame 1 that have matching values in DataFrame 2
filtered_df = merged_df[~merged_df['Internalpatientid'].isin(df['Internalpatientid'])]

# Print only the columns of DataFrame 1
filtered_df
# Out:
#      Internalpatientid  Age at visit    Visit start date  \
# 0                   67            58 2020-10-22 11:49:50
# 1                  200            88 2023-02-13 10:31:19
# 2                  330            75 2024-03-01 00:19:37
# 3                  351            86 2023-10-18 20:54:27
# 4                  714            68 2015-04-17 12:26:12
# ..                 ...           ...                 ...
# 880             168008            73 2013-04-13 23:59:08
# 881             168008            73 2013-04-15 23:49:32
# 882             168008            73 2013-04-16 06:30:58
# 883             168496            99 2022-11-03 09:59:52
# 884             168899            97 2019-09-24 22:46:28
#
#               First listed diagnosis icd10 subcategory  \
# 0                           Encounter for immunization
# 1                                    Vascular dementia
# 2                           Encounter for immunization
# 3                          Other chronic osteomyelitis
# 4    Hypertensive chronic kidney disease with stage...
# ..                                                 ...
# 880                            Counseling, unspecified
# 881                         Malignant carcinoid tumors
# 882          Pneumonia due to other specified bacteria
# 883               Diastolic (congestive) heart failure
# 884            Encounter for other specified aftercare
#
#              Second listed diagnosis icd10 subcategory  \
# 0                                        Not specified
# 1                                        Not specified
# 2                                        Not specified
# 3                                        Not specified
# 4         Panic disorder [episodic paroxysmal anxiety]
# ..                                                 ...
# 880                                      Not specified
# 881            Encounter for other specified aftercare
# 882            Encounter for other specified aftercare
# 883                   Essential (primary) hypertension
# 884  Unspecified atrial fibrillation and atrial flu...
#
#                      Stop code Agentorangeflag Combatflag  \
# 0    GENERAL INTERNAL MEDICINE            None       None
# 1             HBPC - THERAPIST            None       None
# 2        PRIMARY CARE/MEDICINE            None       None
# 3          TELEPHONE/ANCILLARY            None       None
# 4        PRIMARY CARE/MEDICINE            None       None
# ..                         ...             ...        ...
# 880           TELEPHONE TRIAGE             Yes       None
# 881            PALLIATIVE CARE              No       None
# 882            PALLIATIVE CARE            None       None
# 883         TELEPHONE/MEDICINE            None       None
# 884    ANTI-COAGULATION CLINIC            None       None
#
#     Ionizingradiationflag Serviceconnectedflag Swasiaconditionsflag  \
# 0                    None                 None                 None
# 1                    None                 None                 None
# 2                    None                False                 None
# 3                    None                False                 None
# 4                    None                False                 None
# ..                    ...                  ...                  ...
# 880                  None                False                 None
# 881                  None                False                 None
# 882                  None                 None                 None
# 883                  None                 None                 None
# 884                  None                 None                 None
#
#             State
# 0      California
# 1            Utah
# 2          Oregon
# 3            Ohio
# 4         Georgia
# ..            ...
# 880         Texas
# 881         Texas
# 882         Texas
# 883    California
# 884  Pennsylvania
#
# [885 rows x 12 columns]

# %%
filtered_df.Internalpatientid.nunique()
# Out:
# 524

# %%
outpatient_train_data = filtered_df  # Assinging new varible

# %% [markdown]
# # Adding  'Age at visit' & 'First listed diagnosis icd10 subcategory' columns with '_'

# %%
#In this code, we create a new column called 'Lab test description_Result numeric' by concatenating the values of the 'lab test description' column, underscore ('_'), and the 'lab test results' column
#converted to a string using the `astype(str)` function(because we cant't add differnt dtype)
outpatient_train_data['outpatients_First_listed_diagnosis_icd10_subcategory'] =  outpatient_train_data['Age at visit'].astype(str) + '_' +  outpatient_train_data['First listed diagnosis icd10 subcategory']

# %% [markdown]
# # Adding  'Age at visit' & 'Second listed diagnosis icd10 subcategory' columns with '_'

# %%
#In this code, we create a new column called 'Lab test description_Result numeric' by concatenating the values of the 'lab test description' column, underscore ('_'), and the 'lab test results' column
#converted to a string using the `astype(str)` function(because we cant't add differnt dtype)
outpatient_train_data['outpatients_Second_listed_diagnosis_icd10_subcategory'] =  outpatient_train_data['Age at visit'].astype(str) + '_' +  outpatient_train_data['Second listed diagnosis icd10 subcategory']

# %% [markdown]
# # Dropping all unnecessary columns

# %%
# Remove columns 
outpatient_train_data.drop(['Age at visit','Visit start date','First listed diagnosis icd10 subcategory','Second listed diagnosis icd10 subcategory',
                            'Stop code','Agentorangeflag','Combatflag','Ionizingradiationflag','Serviceconnectedflag','Swasiaconditionsflag','State'], axis=1,inplace=True)

# %%
outpatient_train_data = outpatient_train_data

# %%
outpatient_train_data
# Out:
#      Internalpatientid outpatients_First_listed_diagnosis_icd10_subcategory  \
# 0                   67                      58_Encounter for immunization
# 1                  200                               88_Vascular dementia
# 2                  330                      75_Encounter for immunization
# 3                  351                     86_Other chronic osteomyelitis
# 4                  714  68_Hypertensive chronic kidney disease with st...
# ..                 ...                                                ...
# 880             168008                         73_Counseling, unspecified
# 881             168008                      73_Malignant carcinoid tumors
# 882             168008       73_Pneumonia due to other specified bacteria
# 883             168496            99_Diastolic (congestive) heart failure
# 884             168899         97_Encounter for other specified aftercare
#
#     outpatients_Second_listed_diagnosis_icd10_subcategory
# 0                                     58_Not specified
# 1                                     88_Not specified
# 2                                     75_Not specified
# 3                                     86_Not specified
# 4      68_Panic disorder [episodic paroxysmal anxiety]
# ..                                                 ...
# 880                                   73_Not specified
# 881         73_Encounter for other specified aftercare
# 882         73_Encounter for other specified aftercare
# 883                99_Essential (primary) hypertension
# 884  97_Unspecified atrial fibrillation and atrial ...
#
# [885 rows x 3 columns]

# %%
# Group the DataFrame by 'Internalpatientid' and concatenate the icd10 values and
#The purpose of `x.dropna()` is to remove any missing values from the Series before applying a subsequent operation,
# such as concatenation using the `join` function. By dropping the missing values,
#we ensure that only non-null values are included in the resulting concatenated string.
df_grouped = outpatient_train_data.groupby('Internalpatientid').agg(lambda x: ','.join(x.dropna()))
df_grouped 

# Reset the index of the grouped DataFrame
df_grouped_outpatients = df_grouped.reset_index()
df_grouped_outpatients
# Out:
#      Internalpatientid outpatients_First_listed_diagnosis_icd10_subcategory  \
# 0                   67                      58_Encounter for immunization
# 1                  200                               88_Vascular dementia
# 2                  330                      75_Encounter for immunization
# 3                  351                     86_Other chronic osteomyelitis
# 4                  714  68_Hypertensive chronic kidney disease with st...
# ..                 ...                                                ...
# 519             167842  75_Other specified counseling,75_Chronic obstr...
# 520             167917  51_Presence of other cardiac and vascular impl...
# 521             168008  73_Counseling, unspecified,73_Malignant carcin...
# 522             168496            99_Diastolic (congestive) heart failure
# 523             168899         97_Encounter for other specified aftercare
#
#     outpatients_Second_listed_diagnosis_icd10_subcategory
# 0                                     58_Not specified
# 1                                     88_Not specified
# 2                                     75_Not specified
# 3                                     86_Not specified
# 4    68_Panic disorder [episodic paroxysmal anxiety...
# ..                                                 ...
# 519                  75_Not specified,75_Not specified
# 520                                   51_Not specified
# 521  73_Not specified,73_Encounter for other specif...
# 522                99_Essential (primary) hypertension
# 523  97_Unspecified atrial fibrillation and atrial ...
#
# [524 rows x 3 columns]

# %% [markdown]
# # Saving the CSV file

# %%
df_grouped_outpatients.to_csv('/mnt/batch/tasks/shared/LS_root/mounts/clusters/team-3-susai-gpu2/code/Users/900379/Output_files_quality/df_outpatients_quality.csv')

# %%
df_grouped_outpatients['outpatients_First_listed_diagnosis_icd10_subcategory'].values[1]
# Out:
# '69_Encounter for screening for other specified diseases and disorders,69_Encounter for screening for other specified diseases and disorders'

# %%
import os
cwd = os.getcwd()
cwd
# Out:
# '/mnt/batch/tasks/shared/LS_root/mounts/clusters/team-3-susai-gpu2/code/Users/2211575'
